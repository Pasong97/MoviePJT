# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ### (1) 데이터 불러오기

# %%
from gensim.models import Word2Vec
from konlpy.tag import Okt
from konlpy.tag import Kkma
import time
import os
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./data/clean_review_dataset.csv')
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#          영화                                                 리뷰    평점    site
# 0        명량                         여기에 말같잖은 평다는 놈들은 매국노 인증인 듯  10.0   naver
# 1        명량                            다 좋았어요 한산보고 나서 보니 더 좋네요  10.0   naver
# 2        명량  2번째 본 역사영화 진짜 이순신은 대단한 영웅 중에 영웅보는 내내 끝까지 긴장 놓을...  10.0   naver
# 3        명량  정말 거짓말 안 한다클레멘타인에 대한 평가를 호평으로 오해했으면 관객 수가 이리 나...   1.0   naver
# 4        명량                                        재미있게 잘 봤습니다  10.0   naver
# ...     ...                                                ...   ...     ...
# 106885  완득이                                       세상에 수호천사는 없다   2.0  watcha
# 106886  완득이                                   도대체 유아인은 영화를 찍는지   1.0  watcha
# 106887  완득이                                        나도 멘토가 있었다면   6.0  watcha
# 106888  완득이                                  가장 이상적인 한국형 성장드라마   7.0  watcha
# 106889  완득이                            멋진 조화사회 문제를 영화에 담아내긴 했다   7.0  watcha
#
# [106890 rows x 4 columns]

# %%
len(data['리뷰'].unique())
# Out:
# 103574

# %%
data.drop_duplicates(subset=['리뷰'], inplace=True) # reviews 열에서 중복인 내용이 있다면 중복 제거
print('총 샘플의 수 :',len(data))
# Out:
# 총 샘플의 수 : 103574

# %%
data.to_csv('./data/clean_review_dataset.csv', index=)
# Out:
#          영화                                                 리뷰    평점    site
# 0        명량                         여기에 말같잖은 평다는 놈들은 매국노 인증인 듯  10.0   naver
# 1        명량                            다 좋았어요 한산보고 나서 보니 더 좋네요  10.0   naver
# 2        명량  2번째 본 역사영화 진짜 이순신은 대단한 영웅 중에 영웅보는 내내 끝까지 긴장 놓을...  10.0   naver
# 3        명량  정말 거짓말 안 한다클레멘타인에 대한 평가를 호평으로 오해했으면 관객 수가 이리 나...   1.0   naver
# 4        명량                                        재미있게 잘 봤습니다  10.0   naver
# ...     ...                                                ...   ...     ...
# 106885  완득이                                       세상에 수호천사는 없다   2.0  watcha
# 106886  완득이                                   도대체 유아인은 영화를 찍는지   1.0  watcha
# 106887  완득이                                        나도 멘토가 있었다면   6.0  watcha
# 106888  완득이                                  가장 이상적인 한국형 성장드라마   7.0  watcha
# 106889  완득이                            멋진 조화사회 문제를 영화에 담아내긴 했다   7.0  watcha
#
# [103574 rows x 4 columns]

# %% [markdown]
# ### (2) Okt로 명사 단어 추출

# %%
okt = Okt() 

reviews = data['리뷰']

texts = []
for review in reviews:
    words = []
    for word, pos in okt.pos(review):
        if pos in ['Adjective', 'Verb', 'Noun']:
            words.append(word)
            
    text = ' '.join(words)
    texts.append(words)

# %%
# 측정 시작
start = time.time()
# 문장 단위로 명사만 추출해 학습 입력 데이터로 만듦
print('1) 형태소에서 명사만 추출 시작')
okt = Okt()
okt_nouns = [okt.nouns(sentence) for sentence in data['리뷰']]
print('2) 형태소에서 명사만 추출 완료', time.time() - start)
# Out:
# 1) 형태소에서 명사만 추출 시작
# 2) 형태소에서 명사만 추출 완료 174.40225839614868

# %%
okt_nouns
# Out:
# [['여기', '말', '평', '놈', '매국노', '인증', '듯'],
#  ['한산', '보고', '더'],
#  ['역사영화',
#   '진짜',
#   '이순신',
#   '영웅',
#   '중',
#   '영웅',
#   '내내',
#   '끝',
#   '긴장',
#   '수',
#   '이순신',
#   '인물',
#   '정말',
#   '영웅',
#   '임'],
#  ['정말', '거짓말', '안', '클레멘타인', '대한', '평가', '호평', '오해', '관객', '수가', '수도', '생각'],
#  [],
#  ['선용', '감'],
#  ['그냥', '지루', '자체'],
#  ['사람', '영화', '대한', '평점', '이순신', '대한', '평점', '국뽕', '눈', '것', '좀', '자제'],
#  ['루지', '마', '이름', '일본', '장수', '거', '점줌'],
#  ['척', '척', '대결', '아주', '해상전쟁', '영화'],
#  ['이순신', '모독', '영화', '대가리', '이순신', '드', '보이', '찍'],
#  ['이순신', '영화'],
#  [],
#  ['충족'],
#  ['명량해전', '하나'],
#  ['개국', '뽕', '영화', '덕', '끄덕', '수준'],
#  ['굿'],
#  ['그냥', '내내', '함', '나라'],
#  ['말모', '대한민국', '최고'],
#  ['최민식', '연기', '정말'],
#  ['가슴', '대작'],
#  ['두', '시간', '시간', '줄', '모름'],
#  ['나침반',
#   '등대',
#   '첨단',
#   '기술',
#   '옛날',
#   '자연',
#   '지형',
#   '이용',
#   '저런',
#   '전술',
#   '질',
#   '왜놈',
#   '틈',
#   '바구니',
#   '나라',
#   '구한',
#   '역사',
#   '국뽕',
#   '뇨',
#   '대해',
#   '마음',
#   '수'],
#  ['진짜', '굿재밋', '엇어', '감동', '최', '고스'],
#  ['진짜', '디테', '감상', '평', '가치'],
#  ['최근',
#   '극장',
#   '한산',
#   '보고',
#   '티빙',
#   '명량',
#   '해상',
#   '전',
#   '연출',
#   '개인',
#   '한산',
#   '더',
#   '긴장감',
#   '묘사',
#   '말',
#   '그대로',
#   '가슴',
#   '웅장',
#   '최고',
#   '승리'],
#  ['이순신', '그', '라시', '인정', '수', '것', '개인', '한산', '더', '명작'],
#  ['뜬금', '고경표', '배우', '여기'],
#  ['애국심', '영화', '자체', '앞', '김한민', '감독', '무조건', '거른다'],
#  ['산보', '명량', '정말', '연출', '면', '수작', '걸', '다시', '느낌'],
#  ['최민식', '말', '것', '뭐', '유승룡', '구루', '마', '포스'],
#  ['진짜', '가족', '보고', '번', '더', '명작'],
#  ['옛날', '노', '배'],
#  ['한산', '더', '산', '전쟁', '물이', '명량', '국뽕', '물이', '관객수', '서로'],
#  ['내내', '가슴', '웅장', '뭉', '꼭'],
#  ['영화', '봄', '거', '개봉', '때', '진짜'],
#  ['오늘',
#   '변',
#   '환',
#   '빠졋다',
#   '역시',
#   '우리나라',
#   '영화',
#   '마음',
#   '웅장',
#   '우리나라',
#   '일본',
#   '디테일',
#   '표현'],
#  ['이순신', '승리', '눈앞', '보아'],
#  ['최민식', '배우', '연기', '정말', '감동', '자체'],
#  ['애국',
#   '주의',
#   '돈벌이',
#   '이용',
#   '영화',
#   '최악',
#   '관객',
#   '반성',
#   '우리',
#   '무안',
#   '무치',
#   '중국',
#   '인민',
#   '달라'],
#  ['말'],
#  ['내내', '눈물', '영화', '목숨', '거'],
#  ['다시', '역시', '명작', '영화', '모든', '관계자', '감사'],
#  ['국뽕', '영화니', '말', '이', '정도', '볼', '만하', '영화'],
#  ['그냥'],
#  ['우리나라', '세종대왕', '이순신', '장군'],
#  ['영화', '소재', '고증', '연출', '방법', '중점', '영화', '내', '시간', '점', '더', '움'],
#  ['다시', '감동', '명작'],
#  ['목', '내', '아픔'],
#  ['움', '눈물'],
#  ['그냥',
#   '개',
#   '쩐다',
#   '영화',
#   '좀',
#   '왜',
#   '이제',
#   '거',
#   '고',
#   '나',
#   '진짜',
#   '개쩐',
#   '감동',
#   '가슴',
#   '영화',
#   '음'],
#  ['개봉', '당시', '별로', '평점', '조절', '옴'],
#  ['국뽕', '천당', '신', '영접', '함'],
#  ['이순신',
#   '장군',
#   '영화',
#   '무조건',
#   '점수',
#   '줄',
#   '수',
#   '이순신',
#   '장군',
#   '영화',
#   '로',
#   '것',
#   '뮤지컬',
#   '한국',
#   '영화',
#   '고질',
#   '문제',
#   '사운드',
#   '정말'],
#  ['스릴러', '영화인', '줄'],
#  ['우리나라', '가장', '전쟁', '영화'],
#  ['백성', '이순신', '장군', '도', '구간', '눈물', '정말', '감동', '최고', '영화'],
#  ['한산', '한번', '더', '봄', '중간', '지루함', '몇몇', '이상', '대사', '전투씬', '진짜', '잘만', '듬'],
#  ['감동', '요', '최고'],
#  ['한산', '배재', '밋'],
#  ['다시', '감동'],
#  ['최민식', '이미지', '소모', '이순신', '최민식', '조연', '연기'],
#  ['한산', '보고', '다시', '최고'],
#  ['연출',
#   '과장',
#   '신파',
#   '스토리',
#   '집약',
#   '부족',
#   '해상',
#   '전투',
#   '신의',
#   '웅장',
#   '함',
#   '영화',
#   '생명',
#   '줄'],
#  ['애국심',
#   '불타',
#   '영화',
#   '박해',
#   '읾',
#   '진짜',
#   '대사',
#   '몇',
#   '마디',
#   '최고',
#   '연기',
#   '란',
#   '거구',
#   '영화',
#   '주연',
#   '배우',
#   '찰떡',
#   '천만',
#   '축하'],
#  ['것'],
#  ['제', '한국', '영화', '중단', '연', '최고'],
#  ['나라', '나라'],
#  ['국뽕', '취한', '무엇', '그게', '제대로', '국뽕', '더', '이순신', '장군', '신'],
#  ['마지막',
#   '포졸',
#   '후손',
#   '우리',
#   '노력',
#   '뭐',
#   '소리',
#   '때',
#   '기',
#   '그',
#   '장면',
#   '거기',
#   '왜',
#   '필요',
#   '함포',
#   '졸',
#   '관객',
#   '보고',
#   '걸',
#   '소린',
#   '데',
#   '말'],
#  ['말', '그대로', '명작', '임', '안', '사람', '듯'],
#  ['한산', '보고', '다시', '보고', '생각', '등장인물', '비교', '재미'],
#  ['감동', '감동', '감동', '감동', '감동'],
#  ['대박', '감동', '요', '눈물', '이나'],
#  ['그냥', '뭐', '애국심', '재미', '듯'],
#  ['예전', '영화', '웅장'],
#  ['스토리',
#   '기',
#   '결',
#   '느낌',
#   '역사',
#   '바탕',
#   '영화',
#   '기승',
#   '전이',
#   '필요',
#   '전',
#   '연출',
#   '진짜',
#   '대박'],
#  ['한산', '보고', '다시', '명량', '여운', '최고', '작품', '인생', '두', '번', '대작'],
#  ['영상',
#   '연출',
#   '지금',
#   '진짜',
#   '이순신',
#   '장군',
#   '지금',
#   '안',
#   '역사',
#   '인물',
#   '중',
#   '하나',
#   '진짜',
#   '최고',
#   '걸작',
#   '영화'],
#  ['연출', '연기', '스토리', '영상', '미감', '포인트', '어케', '하나', '부산', '항', '왜곡'],
#  ['굿', '꼭', '편', '보고', '한산'],
#  ['진짜', '진짜', '옛날', '건데', '명작'],
#  ['최고', '몰입', '감', '쩔', '여운', '대박', '임인', '생', '영화'],
#  ['명량', '더'],
#  ['순신',
#   '이름',
#   '역사',
#   '가치',
#   '제대로',
#   '알',
#   '영화',
#   '영화',
#   '요소',
#   '움',
#   '그',
#   '시대',
#   '어쩌면',
#   '실제',
#   '절박',
#   '이야기',
#   '왜군',
#   '무',
#   '우리나라',
#   '늘'],
#  ['이건', '대작'],
#  ['성웅', '이순신', '조상', '우리나라', '대한민국'],
#  ['한산', '보고', '영화', '다시', '이', '영화', '천만', '관객', '만', '대작'],
#  ['한산', '해전', '거북선', '슬로우', '모션', '남용', '감정', '과잉', '산이', '훨배'],
#  ['최민식', '최민식', '줄', '이순신', '장군', '살', '진짜', '듯'],
#  ['영화관', '꼭'],
#  ['연기',
#   '볼',
#   '만',
#   '연출',
#   '당시',
#   '천만',
#   '영화',
#   '국뽕덕',
#   '말',
#   '어린이',
#   '수준',
#   '영화',
#   '영화사',
#   '국뽕',
#   '영화',
#   '덕분',
#   '영화',
#   '발전',
#   '동력'],
#  ['산',
#   '다시',
#   '봄',
#   '불멸',
#   '이순신',
#   '왜란',
#   '당시',
#   '난중일기',
#   '백성',
#   '조선',
#   '수군',
#   '끼니',
#   '걱정',
#   '정도',
#   '조선',
#   '상태',
#   '안',
#   '장군',
#   '퉁퉁',
#   '함'],
#  ['충무공', '이순신', '만세'],
#  ['작품', '찍기', '전', '생각', '흥행', '목적', '이순신', '영웅', '업적', '기리', '게', '목적'],
#  ['나', '안성기', '이순신', '느낌', '극장', '나들이'],
#  ['지루함'],
#  ['한산',
#   '보고',
#   '다시',
#   '복습',
#   '영화',
#   '점수',
#   '보이',
#   '기록',
#   '척',
#   '영화',
#   '극적',
#   '일',
#   '거',
#   '예상',
#   '배',
#   '만',
#   '현재',
#   '더욱',
#   '눈물'],
#  ['영화', '그냥', '지금', '가끔'],
#  ['정말'],
#  ['살짝',
#   '고어',
#   '부분',
#   '더',
#   '이순신',
#   '아들',
#   '회',
#   '겨',
#   '아버지',
#   '질문',
#   '계속',
#   '척',
#   '척',
#   '왜군',
#   '무',
#   '해전',
#   '씬',
#   '매우'],
#  ['아포칼립토', '표절', '최종', '병기', '활', '팔', '국뽕', '팔이', '카피', '김한민', '감독', '영화'],
#  ['류승룡', '허망', '함', '이정현', '오버', '전술', '오류', '등', '단점', '눈', '대첩', '대첩'],
#  ['이', '대한민국', '최', '관객', '수', '위', '영화', '게', '이해', '안감'],
#  ['내', '인생', '안', '영화'],
#  ['이순신', '장군'],
#  ['다기', '영화', '인지', '글쎄'],
#  ['개봉', '당시', '번', '봄', '연기자', '연기', '일품', '스토리', '정말', '순신', '장군'],
#  ['한산', '대첩', '눈', '보고', '명량대첩', '새삼', '깨'],
#  ['고증', '점', '인물'],
#  ['최민식', '연기', '것', '시나리오', '연출', '별로', '듯'],
#  ['음악',
#   '과잉',
#   '몰입',
#   '방해',
#   '요소',
#   '카타르',
#   '시스',
#   '영화',
#   '크게',
#   '반감',
#   '요인',
#   '작용',
#   '후속작',
#   '산',
#   '제발',
#   '실수'],
#  ['국뽕',
#   '맛',
#   '감독',
#   '연속',
#   '매니아',
#   '억지로',
#   '감동',
#   '과',
#   '최종',
#   '병기',
#   '활',
#   '감동',
#   '안',
#   '강요',
#   '옛날',
#   '무협',
#   '영화'],
#  ['마을', '주민', '치마', '절하', '억지', '장면', '말'],
#  ['성웅', '이순신', '장군', '선', '조'],
#  ['말', '필요', '영화'],
#  ['수동',
#   '배',
#   '화포',
#   '그',
#   '노고',
#   '몇',
#   '날',
#   '며칠',
#   '전진',
#   '전쟁',
#   '옛날',
#   '민족',
#   '두려움',
#   '용기',
#   '함',
#   '수'],
#  ['한산', '보고', '나니', '명량', '걸', '한번', '나'],
#  ['마지막',
#   '전투씬',
#   '리얼',
#   '웅장',
#   '연출',
#   '내내',
#   '흥분',
#   '케',
#   '가슴',
#   '건',
#   '명량',
#   '매력',
#   '포인트',
#   '생각',
#   '개봉',
#   '한산',
#   '보기',
#   '전',
#   '한번',
#   '더',
#   '명량',
#   '것',
#   '것'],
#  ['일', '오버', '판타지', '감독', '연출'],
#  ['이순신', '치트키', '이', '정도', '흥행', '듯', '감독', '순수', '창작물', '개도', '거'],
#  ['시사회',
#   '영화',
#   '보고',
#   '알',
#   '점',
#   '순신',
#   '거북선',
#   '일본',
#   '영화',
#   '공감',
#   '수',
#   '이',
#   '영화',
#   '역대',
#   '기록',
#   '거'],
#  ['영화', '역대', '흥행', '위', '현실', '촌극'],
#  ['영화', '다가', '평점'],
#  ['안', '사람', '두', '번', '볼', '사람', '번', '이해', '수작'],
#  ['한산', '이야기', '평점', '국뽕', '이야기', '영화', '자체', '평가'],
#  ['아버지', '기억', '순신', '이', '만', '신화', '국뽕', '말', '이름'],
#  ['웰', '메이드', '영화'],
#  ['한산', '개봉', '평점', '안', '집', '컴', '런가', '스크린', '진짜'],
#  ['배우', '연기', '진짜', '쓰레기'],
#  ['신파',
#   '납득',
#   '가지',
#   '인물',
#   '등장',
#   '억지',
#   '스토리',
#   '전',
#   '개',
#   '역사',
#   '사람',
#   '아쉬움',
#   '영화',
#   '화가'],
#  ['그냥', '최민식', '배우', '연기'],
#  ['존', '나', '후속작', '기대', '안'],
#  ['처음',
#   '때',
#   '사회',
#   '분위기',
#   '생각',
#   '이',
#   '역대',
#   '위인',
#   '거',
#   '중국',
#   '국뽕',
#   '흥행',
#   '카드',
#   '거'],
#  ['얘', '생각', '댓글', '시간', '역사', '공부', '해'],
#  ['오락', '영화', '정녕', '영화', '영화로', '소비', '수'],
#  ['굿', '십'],
#  ['스토리', '개연', '애국심', '호소', '정말', '영화', '볼', '수', '영화감독', '죽', '정말'],
#  ['전', '영화', '드라마'],
#  ['그냥', '명작'],
#  ['평점', '점'],
#  ['한국인', '대한민국', '사람'],
#  ['인물', '누', '과대', '평가'],
#  ['진짜'],
#  ['해전', '장면', '인상', '캐릭터', '활', '용도', '완성'],
#  ['다시', '웅장', '여운'],
#  ['연출', '진짜', '재미', '감동', '도', '그냥', '국뽕버', '프로'],
#  ['그냥', '진짜', '인지도', '관객', '수', '거품', '영화'],
#  ['연기'],
#  ['진짜', '평점', '점', '게', '어이', '마지막', '억지', '감동', '어우'],
#  ['전투씬', '소름', '닭살', '몇', '번'],
#  ['내', '알', '이순신', '장군'],
#  ['최고', '감동', '자체'],
#  ['최민식', '한국', '영화계', '보물'],
#  ['잠', '돈', '움'],
#  ['이순신', '인물', '것', '영화'],
#  ['천만', '이유'],
#  ['개봉', '당시', '감동', '영화', '역사', '물', '편', '배우', '연기력', '해상', '전도', '흥미진진'],
#  ['가슴', '웅장', '영화'],
#  ['고증', '뭐', '건', '포기', '앞', '시간', '포기', '나머지', '전투씬', '볼', '함'],
#  ['국민', '나라', '행', '민심', '거'],
#  ['볼',
#   '때',
#   '국뽕',
#   '취한',
#   '구',
#   '국',
#   '영웅',
#   '이순신',
#   '장군',
#   '부하',
#   '장수',
#   '병사',
#   '나라',
#   '정말'],
#  ['이순신', '장군', '볼', '빵빵', '연기', '글', '글국뽕덕', '영화'],
#  ['그냥', '닥치고', '말'],
#  ['볼', '때', '감동', '이예'],
#  ['앞잡이',
#   '놈',
#   '점',
#   '테러',
#   '거',
#   '흥행',
#   '이유',
#   '분명',
#   '존재',
#   '다수',
#   '다수',
#   '극찬',
#   '악평',
#   '게',
#   '스스로',
#   '생각',
#   '하나',
#   '현실',
#   '루저',
#   '명량',
#   '띵작'],
#  ['한국영', '요하', '안', '요제', '발', '예'],
#  ['영화', '평점', '이해', '안', '간다'],
#  ['무슨', '말', '더'],
#  ['전반전', '예상', '밖', '선방', '후반전', '뻔', '연발'],
#  ['이순신', '이름', '흥행', '수준', '영화'],
#  ['진짜',
#   '개',
#   '재미',
#   '연출',
#   '스토리',
#   '연기',
#   '개',
#   '기',
#   '수준',
#   '이',
#   '천만',
#   '관객',
#   '모르겄',
#   '음',
#   '국민',
#   '수준',
#   '잘만',
#   '르',
#   '지역',
#   '사',
#   '왜곡',
#   '논잼'],
#  ['그냥', '최고', '명작', '임', '연기', '음악', '모든', '것'],
#  ['우리나라', '영화', '관객', '수', '위', '영화', '생각'],
#  ['중',
#   '명',
#   '것',
#   '다행',
#   '영화',
#   '넷플릭스',
#   '시간',
#   '웟네',
#   '그냥',
#   '감독',
#   '이순신',
#   '이용',
#   '표',
#   '팔이',
#   '햇',
#   '생각',
#   '안드네',
#   '걸',
#   '영화',
#   '국뽕',
#   '좀'],
#  ['진짜', '인생', '최악', '영화', '임절', '때', '보지'],
#  ['명량', '국뽕', '영화', '완성', '정말', '영화', '일본', '척', '영화', '꼭', '내', '돈', '극장'],
#  ['진짜', '그냥', '국뽕', '상도', '이하', '게', '급', '일본', '영화', '저리', '라임'],
#  ['일본', '놈', '댓글', '좀', '못', '달', '해', '평점', '영화', '보고', '배'],
#  ['역대', '명작', '자부'],
#  ['진짜',
#   '이건',
#   '우리나라',
#   '영화계',
#   '획',
#   '그을',
#   '정도',
#   '명작',
#   '우리',
#   '역사',
#   '이유',
#   '이유',
#   '영화'],
#  ['국뽕', '범벅', '거품', '스크린', '독점', '관객', '동원'],
#  ['초등', '고학년', '아들', '진도', '후', '봣는데', '정말', '감동', '마음', '겹'],
#  ['낮', '당', '터', '주준'],
#  ['훌룡', '배우진', '역사', '재료', '못', '루즈', '연출', '스토리', '전개', '후반', '갈수록'],
#  ['수준', '영화', '걸', '명작', '이', '정신', '상태'],
#  ['이제야', '대작', '시간', '줄'],
#  ['이순신', '장군', '지금', '대한민국', '이건', '제하', '거'],
#  ['나라', '위해', '끝', '이순신', '장군', '사랑', '존경'],
#  ['배경음악'],
#  ['연기', '배경', '가족영화', '해도', '내용', '것', '약간', '감동'],
#  ['국뽕', '충만', '돼지', '눈물', '바다'],
#  ['국뽕',
#   '이순신',
#   '장군',
#   '제대로',
#   '보임',
#   '국뽕',
#   '이순신',
#   '장군',
#   '우리',
#   '생각',
#   '것',
#   '천배',
#   '더',
#   '세계',
#   '분'],
#  ['예전', '극장', '정말'],
#  ['영화',
#   '말',
#   '안',
#   '욕',
#   '사람',
#   '이',
#   '다큐',
#   '영화',
#   '영화로',
#   '전투',
#   '이제',
#   '장군',
#   '알',
#   '펄럭'],
#  ['동안', '보지', '지금', '최민식', '연기', '말', '건', '투신', '정말', '뭔가', '부분', '존재', '점'],
#  ['진짜', '이순신', '인생', '자체', '영화', '뭐', '삼류', '유치', '뽕짝', '진', '화가', '다나'],
#  ['뭐', '게', '전체', '관람객', '위'],
#  ['이순신',
#   '장군',
#   '스크린',
#   '볼',
#   '수',
#   '것',
#   '영화',
#   '완성',
#   '도',
#   '감독',
#   '이후',
#   '속편',
#   '준비',
#   '중이',
#   '데',
#   '후속',
#   '편',
#   '애국',
#   '마케팅',
#   '완성',
#   '도로',
#   '승부'],
#  ['이', '쓰레기', '이순신', '장군', '팔', '진짜', '양심'],
#  ['이', '벌써', '화란', '게', '안'],
#  ['한국', '사람', '라면', '꼭', '함', '최고', '영화', '가슴', '웅장', '것', '느낌'],
#  ['지국', '뽕', '이순신', '장군', '영화', '절대', '영화'],
#  ['내내', '심장', '영화'],
#  ['항상', '인상', '전쟁', '서린', '노', '기와', '투지', '최민식', '이순신', '가슴', '김명민', '이순신'],
#  ['영화', '대해', '사람', '단순', '재미', '도', '평점'],
#  ['영화', '의', '조선', '버전', '이순신', '장군', '성웅', '대한', '극적', '묘사', '생', '영화', '중'],
#  ['건', '실화', '게', '팩트', '영화', '더', '영화', '기적', '비현실적', '애', '도대체'],
#  ['지금', '전쟁', '누가', '수'],
#  ['인생', '영화', '최고'],
#  ['이순신', '한국', '영화', '탑', '안', '영화', '생각'],
#  ['이순신', '장군'],
#  ['말', '안', '전투', '장면', '수준', '이하', '영화'],
#  ['역시', '최민식', '연기', '일품', '이군'],
#  ['최민식', '연기력', '한국', '최고', '영화', '감동', '감동', '짝짝', '짝짝'],
#  ['광복절', '데', '감회', '나라', '위', '충신', '나라', '살'],
#  ['걸', '보고', '한국', '사람', '거지', '감동', '연기력'],
#  ['감동', '영화'],
#  ['감동', '화보', '내내', '눈물'],
#  ['이순신', '장군', '업적', '상업', '흥행', '영화', '불멸', '이순신', '드라마', '천만배', '훨'],
#  ['진짜', '국뽕', '볼', '게', '화보', '다가', '숙면', '가능'],
#  ['볼', '때', '국뽕', '눈물샘', '자극', '곳도', '한번', '꼭', '영화', '충무공', '존경'],
#  ['이', '천만', '영화', '진짜', '개'],
#  ['이순신', '장군', '아들', '덕분', '만', '번', '더', '아가', '이순신', '장군', '요', '우리나라'],
#  ['내', '걸', '이제', '개멋', '지다'],
#  ['왜구',
#   '배',
#   '로',
#   '백병',
#   '전',
#   '거',
#   '보고',
#   '어처구니',
#   '국뽕',
#   '좀비',
#   '떼',
#   '마냥',
#   '사람',
#   '동원',
#   '킬링타임',
#   '영화'],
#  ['수', '차', '약제사', '즉', '무감'],
#  ['이제야', '명장', '더', '일찍', '볼껄'],
#  ['한번', '영화'],
#  ['작품', '흥행', '순위', '순위', '건', '길이', '반증'],
#  ['해상', '전투씬'],
#  ['이순신', '장군'],
#  ['두', '번', '보', '처음', '때', '못', '감정', '장면', '보이', '꼭', '두', '번'],
#  ['영화',
#   '이건',
#   '내용',
#   '별로',
#   '무순',
#   '소린',
#   '자도',
#   '하나',
#   '서울',
#   '아빠',
#   '추천',
#   '볼',
#   '수',
#   '직원',
#   '고생',
#   '좀',
#   '주지'],
#  ['스토리',
#   '연기자',
#   '표현',
#   '영화',
#   '전반',
#   '감동',
#   '재미',
#   '역시',
#   '천만',
#   '관객',
#   '베스트',
#   '명품',
#   '영화',
#   '소장',
#   '가치'],
#  ['속편', '최고'],
#  ['영화인', '그냥', '뭔가'],
#  ['킹', '장군'],
#  ['조상', '순신', '장군'],
#  ['쥑', '다소', '오로르르름'],
#  ['졸작', '흥행', '게'],
#  ['여태', '영화', '중', '가장', '인상', '영화'],
#  ['건', '화면', '톤', '옛날', '영화', '한산', '만', '요즘', '영화', '영상'],
#  ['몰입', '영화'],
#  ['영화', '감동', '수', '영화'],
#  ['아빠', '말', '함', '점', '만점', '점'],
#  ['영화', '지난', '다시', '개봉', '해도', '찍', '것', '영화관', '게', '후회'],
#  ['불별',
#   '이순신',
#   '이순신',
#   '드라마',
#   '전쟁',
#   '나기',
#   '전',
#   '미리',
#   '일본',
#   '공격',
#   '스토리',
#   '건',
#   '역사',
#   '다음',
#   '스토리',
#   '전혀',
#   '영화'],
#  ['지국', '뽕', '영화', '평점', '거', '소름'],
#  ['볼', '끝', '맛', '되새', '김질', '감정', '호소', '장면'],
#  ['민족',
#   '성웅',
#   '이순신',
#   '그',
#   '가장',
#   '극적',
#   '전투',
#   '명량해전',
#   '소재',
#   '수준',
#   '못',
#   '감독',
#   '한국영',
#   '업계',
#   '앞',
#   '반성',
#   '애국심',
#   '팔',
#   '거',
#   '피',
#   '규어'],
#  ['감동', '존경심', '영화', '무엇', '요소'],
#  ['천만', '영화'],
#  ['국가', '국민', '이순신', '시대', '이순신', '캐릭터', '판', '영화'],
#  ['민', '식이', '형님', '개', '사랑'],
#  ['몇', '번', '다시', '명작'],
#  ['덕분', '저희'],
#  ['존', '잼', '꼭', '강력', '추천', '함'],
#  ['그냥', '말', '피료', '최고'],
#  ['천만', '영화'],
#  ['대한민국', '국민', '라면', '그냥', '점', '영화', '독립운동', '불매운동', '계속', '실천', '중'],
#  ['정말', '감동', '영화', '햇', '투신', '처음', '거'],
#  ['중국', '영화', '욕', '국뽕', '영화'],
#  ['역사', '임진왜란', '잠시', '정말'],
#  ['못', '만드', '수준'],
#  ['국뽕', '눈물'],
#  ['할머니', '것'],
#  ['감동'],
#  ['진짜', '평점', '존', '나', '씨', '발', '중간'],
#  ['감명', '최고'],
#  ['역시', '킹', '순신'],
#  ['그냥',
#   '이순신',
#   '장군',
#   '모욕',
#   '수준',
#   '중',
#   '이순신',
#   '리더',
#   '부관',
#   '회의',
#   '피',
#   '붙이',
#   '아들',
#   '몰래',
#   '작전',
#   '이야기',
#   '심지어',
#   '작전',
#   '게',
#   '두려움',
#   '용기',
#   '교환',
#   '작전'],
#  ['연기', '외', '볼', '게', '영화'],
#  ['김한민',
#   '감독',
#   '김한민',
#   '감독',
#   '자신',
#   '제일',
#   '생각',
#   '소재',
#   '선택',
#   '았',
#   '뿐',
#   '영화',
#   '자체',
#   '소재',
#   '선택',
#   '듯',
#   '그것',
#   '능력'],
#  ['이순신',
#   '장군',
#   '이야기',
#   '흥행',
#   '보증수표',
#   '이순신',
#   '장군',
#   '마음',
#   '전달',
#   '일',
#   '완전',
#   '이야기',
#   '측면',
#   '최민식',
#   '연기',
#   '높이',
#   '평가'],
#  ['국뽕', '영화', '최고봉', '다큐'],
#  ['진심', '감동'],
#  [],
#  ['말', '최고'],
#  ['몇', '번', '보아', '감동', '용기', '애국심', '불어', '대작'],
#  ['고전',
#   '느낌',
#   '애',
#   '판타지',
#   '영화',
#   '놨으',
#   '배우',
#   '전혀',
#   '이순신',
#   '장군',
#   '거',
#   '영화',
#   '영화',
#   '자체',
#   '로만'],
#  ['장점', '천만', '관객'],
#  ['저', '우리나라', '이름', '조선', '일본', '선', '조분'],
#  ['내', '지금', '영화', '중', '영화', '이순신', '죽지', '안', '액션', '아주'],
#  ['불멸', '이순신', '이', '영화', '얼마나', '작품'],
#  ['점', '아래', '점'],
#  ['규모', '비례', '계속', '헛웃음'],
#  ['스토리', '데', '디테', '일이', '증도', '별로', '고', '처음', '자꾸', '보이'],
#  ['볼', '것', '연출', '훌룡합니'],
#  ['배우',
#   '감독',
#   '작가',
#   '삼위일체',
#   '한계',
#   '랄',
#   '한반도',
#   '최고',
#   '사실',
#   '한반도',
#   '최고',
#   '영화',
#   '수',
#   '병작',
#   '수작'],
#  ['이순신', '당신', '지금', '우리나라', '정말'],
#  ['점'],
#  ['우리나라', '역사', '최고', '영화'],
#  ['인생', '영화', '임', '이순신', '장군', '만세'],
#  ['말',
#   '말',
#   '거',
#   '감동',
#   '이순신',
#   '장군',
#   '제',
#   '제일',
#   '존경',
#   '아주',
#   '장',
#   '구림',
#   '중',
#   '분',
#   '데',
#   '우리나라',
#   '천만',
#   '영화',
#   '위',
#   '명량',
#   '영화인',
#   '게'],
#  ['이순신', '장군', '인간', '비', '작품', '스토리'],
#  ['연기', '스토리', '감동', '점', '도', '역사'],
#  ['누나', '돌응', '낟', '동강'],
#  ['대체', '뭘', '말', '영화', '게', '영화', '점도'],
#  ['국뽕', '한국사', '공부'],
#  ['굿', '굿', '굿', '굿', '굿'],
#  ['전투씬',
#   '진짜',
#   '듯',
#   '전투',
#   '중',
#   '이정현',
#   '장면',
#   '몰입도',
#   '이순신',
#   '대해',
#   '시리즈',
#   '영화',
#   '개봉',
#   '요',
#   '외국',
#   '히어로',
#   '물'],
#  ['캐스팅', '실패', '그냥', '진짜', '일본인', '한국인', '발음', '일본어', '거', '듣기'],
#  ['영화', '한국', '역대', '박스오피스', '위', '것', '어이'],
#  ['명작', '명작', '명작'],
#  ['영화', '영화', '정말'],
#  ['안', '키', '쪽바리', '잔당'],
#  ['영화', '두', '번', '말', '것', '가슴', '웅장'],
#  ['영화', '명량', '대하', '사극', '불멸', '이순신', '것', '추천'],
#  ['모든', '게', '명장'],
#  ['역사', '사실', '하나', '영화', '재미'],
#  ['전투씬', '치중', '영화'],
#  ['한국영', '화의', '최대', '미스터리'],
#  ['최고', '대규모', '전쟁', '씬', '해상전쟁', '영화'],
#  ['국뽕', '벌레', '다운', '징', '역대', '영화', '관객', '순위', '위'],
#  ['영상', '연출'],
#  ['남자라면', '눈물'],
#  ['정말', '번', '감동', '인생', '연화'],
#  ['국뽕', '반일', '감정', '덕', '영화', '볼거리'],
#  ['이건', '안', '베', '표절', '수가', '똑바로'],
#  ['이', '영화', '도대체', '감독판', '언제'],
#  ['영화관',
#   '번',
#   '보고',
#   '이후',
#   '여러',
#   '번',
#   '이제',
#   '평점',
#   '정말',
#   '연기력',
#   '이순신',
#   '장군',
#   '정말',
#   '신',
#   '생각'],
#  ['한번', '볼', '만하', '타이타닉'],
#  ['집중', '보기', '오늘', '재', '눈데', '눙물'],
#  ['이건', '한국인', '이면'],
#  ['평점', '점', '영화', '쪽'],
#  ['연출', '부족', '연기력', '버드', '라마', '못', '영화'],
#  ['진짜', '이', '거', '뭐', '화보', '눈', '점', '점', '달', '수준'],
#  ['가슴', '웅장', '최고', '영화'],
#  ['역사', '자', '미래', '피죽', '조선', '툭하면', '오랑캐', '왜', '놈', '친일파'],
#  ['전쟁', '성웅', '이순신'],
#  ['과장',
#   '허구',
#   '선동',
#   '목적',
#   '위해',
#   '영화',
#   '이순신',
#   '장군',
#   '상업',
#   '이용',
#   '정치',
#   '이용',
#   '영화'],
#  ['우리나라', '영화', '역대', '명작', '중', '하나', '봄'],
#  ['목소리', '개', '누'],
#  ['보고', '계속', '눈물', '나', '영화'],
#  ['다시', '감명', '영화'],
#  ['레전드', '영화', '한국인', '라면', '꼭'],
#  ['건', '국뽕임'],
#  ['이순신', '장군', '면목', '영화'],
#  ['한국영', '중', '전투씬', '수준'],
#  ['이순신', '장군', '우리', '나라'],
#  ['스트레스', '꼭', '번', '영화'],
#  ['몇', '번', '소름', '이순신', '장군', '응'],
#  ['이제야', '요'],
#  ['굿굿귯', '수구', '수귯굿'],
#  ['영화관', '처음', '보고', '넷플릭스', '보고', '평점', '인생', '최고', '영화'],
#  ['신파', '국뽕', '향연'],
#  ['이순신', '장군', '이야기', '가지', '영화', '못'],
#  ['영화', '개판', '네'],
#  ['전투씬', '만도', '전혀'],
#  ['정말', '가슴'],
#  ['영화', '자체', '부분', '구국', '영웅', '이순신', '일본', '문화', '분', '역사'],
#  ['흙', '보검', '흑역사', '흙흙흙'],
#  ['이순신', '글자', '역사상', '가장', '장군', '백원', '리', '게'],
#  ['한국인', '국뽕', '연출', '감동'],
#  ['진짜', '최고', '영화', '보고', '감동', '적임', '최고', '임', '그냥'],
#  ['국뽕', '진심', '처음', '끝', '펑펑', '만', '재미', '하나', '액션', '치', '중', '영화'],
#  ['국뽕', '치사량', '절벽', '치마', '때', '토', '줄'],
#  ['연평해전', '점', '명량', '점', '어이'],
#  ['최고', '소재'],
#  ['최민식', '연기력', '그냥', '점', '듯', '불멸', '이순신'],
#  ['해병대',
#   '출신',
#   '이순신',
#   '장군',
#   '존경',
#   '영화',
#   '그냥',
#   '개',
#   '삼류',
#   '제',
#   '극한',
#   '직업',
#   '점',
#   '띵량',
#   '진짜',
#   '개',
#   '노잼',
#   '소재',
#   '가지',
#   '영화',
#   '분',
#   '꼭',
#   '한숨',
#   '쇼'],
#  ['이순신', '위인', '최민식', '배우', '흥행'],
#  ['이순신', '장군', '존경', '정신', '늘'],
#  ['정말', '영화'],
#  ['역시', '최고'],
#  ['최민식',
#   '열연',
#   '이',
#   '외',
#   '볼거리',
#   '전혀',
#   '한민족',
#   '각성',
#   '기용',
#   '국뽕',
#   '영화',
#   '무작정',
#   '찬양',
#   '관객',
#   '수준',
#   '뿐'],
#  ['투신', '억지', '영화', '듯'],
#  ['퀄리티', '반전', '진짜', '최고', '리', '생각', '데', '평점', '점', '생각'],
#  ['진짜'],
#  ['나라',
#   '척',
#   '왜',
#   '선',
#   '척',
#   '마치',
#   '로스트',
#   '템플',
#   '입구',
#   '칸',
#   '기',
#   '저글링',
#   '마리',
#   '거',
#   '나라',
#   '감동'],
#  ['이순신', '장군'],
#  ['말', '필요', '꼭'],
#  ['그닥', '감동', '못', '자연', '영화로', '보기'],
#  ['쓰레기', '국뽕', '영화', '댓글', '알바'],
#  ['최민식', '씨', '이순신', '장군', '역', '감동', '음향', '효과', '정말', '최고'],
#  ['극장',
#   '보고',
#   '다시',
#   '영화',
#   '그때',
#   '기억',
#   '나',
#   '데',
#   '다시',
#   '평타',
#   '영화',
#   '다한',
#   '산도',
#   '노량',
#   '기대'],
#  ['최민식',
#   '신역',
#   '지도',
#   '백병',
#   '전',
#   '이',
#   '정도',
#   '이순신',
#   '당시',
#   '조선',
#   '수군',
#   '모욕',
#   '수준',
#   '영화',
#   '상업성',
#   '기본',
#   '고증'],
#  ['나', '불멸', '이순신', '봣더', '개', '노잼'],
#  ['망', '위', '베충'],
#  ['도대체', '망작', '사람', '뭔가', '자기', '걸', '영화', '걸', '영화', '한국', '위'],
#  ['정말',
#   '최고',
#   '배우',
#   '최고',
#   '장군',
#   '최고',
#   '전쟁',
#   '마케팅',
#   '요소',
#   '영화',
#   '자체',
#   '스토리',
#   '연출',
#   '액션',
#   '것',
#   '수'],
#  ['존경', '합', '이순신', '장군'],
#  ['전쟁',
#   '구현',
#   '캐릭터',
#   '그냥',
#   '국뽕',
#   '단점',
#   '싹',
#   '커버',
#   '천만',
#   '관객',
#   '달성',
#   '영화인',
#   '듯'],
#  ['다시'],
#  ['컨텐츠', '연출', '스토리', '억지', '컨텐츠', '제대로', '영화'],
#  ['역사', '왜곡'],
#  ['전투', '긴장감', '최고'],
#  [],
#  ['충격', '정말', '다시', '번', '소름'],
#  ['다섯', '초반', '눈물', '요', '대한민국'],
#  ['이순신', '장군', '척', '배', '척', '배'],
#  ['영화로', '점', '역사', '그대로', '명작', '걸', '온갖', '클리셰', '덧칠', '누더기', '망작'],
#  ['이순신', '최고', '대한민국', '최고', '영화', '최고'],
#  ['만세'],
#  ['내', '인생', '최고', '영화'],
#  ['주연', '캐릭터', '안', '안', '보고', '오늘', '예상', '더', '참담', '영화', '분', '이순신', '장군'],
#  ['보고', '이순신', '장군', '오늘', '내', '롤', '모델', '사랑'],
#  ['조선',
#   '현',
#   '북한',
#   '만도',
#   '못',
#   '것',
#   '영화',
#   '이순신',
#   '장순',
#   '명장',
#   '조선왕조',
#   '공산당',
#   '못',
#   '역적'],
#  ['고증',
#   '따위',
#   '개',
#   '감수',
#   '성과',
#   '만기',
#   '쓰레기',
#   '뮤비',
#   '영화',
#   '이순신',
#   '장군',
#   '명성',
#   '칠',
#   '제대로',
#   '쓰레기'],
#  ['지금', '보고', '진짜', '멍하니'],
#  ['국뽕', '그냥', '줄', '때', '처'],
#  ['이',
#   '정도',
#   '걸작',
#   '역사',
#   '조금',
#   '관심',
#   '사람',
#   '라면',
#   '누구',
#   '알',
#   '내용',
#   '영화',
#   '감동',
#   '다음',
#   '작품',
#   '기대',
#   '완성'],
#  ['현충일', '이', '영화로', '역사', '알', '보기', '전', '거북선', '이순신', '장군', '줄'],
#  ['이순신',
#   '분',
#   '이',
#   '나라',
#   '분',
#   '저희',
#   '위안부',
#   '공구',
#   '끝',
#   '사과',
#   '불매운동',
#   '절대',
#   '맙시',
#   '명량',
#   '영화',
#   '볼',
#   '때',
#   '국뽕'],
#  ['리더쉽', '위기', '기회', '진짜', '리더'],
#  ['현충일', '눈', '수', '감동', '이순신', '장군', '명량', '눈물'],
#  ['영화',
#   '캐릭터',
#   '스토리',
#   '부분',
#   '지적',
#   '말',
#   '매국노',
#   '일파',
#   '지랄',
#   '해',
#   '대니',
#   '리가',
#   '병신',
#   '국뽕',
#   '차',
#   '물불',
#   '못',
#   '무작정',
#   '엄복동',
#   '왜',
#   '욕'],
#  ['못',
#   '영화',
#   '임',
#   '전술',
#   '측면',
#   '더',
#   '이순신',
#   '장군',
#   '존경',
#   '쪽',
#   '국',
#   '영화',
#   '감독',
#   '돈',
#   '연출',
#   '엉망',
#   '고',
#   '스토리',
#   '엉망'],
#  ['이순신', '장군', '웅장', '함', '표현', '최고', '영화'],
#  ['해전', '씬', '최고', '존경', '위인', '영화로', '더', '정이'],
#  ['명장',
#   '이순신',
#   '그',
#   '자체',
#   '최민식',
#   '열연',
#   '넋',
#   '회',
#   '오리',
#   '바다',
#   '속',
#   '스펙',
#   '타',
#   '투신',
#   '만날',
#   '수',
#   '심',
#   '연출',
#   '약간',
#   '아쉬움',
#   '영화'],
#  ['후편', '로', '벌써', '지남'],
#  ['그냥', '모든', '게', '최고', '이순신', '진정', '천재'],
#  ['순신', '뭐', '말'],
#  ['남', '머', '하든', '기준', '감동', '영화', '우리', '기억', '함'],
#  ['대작', '이제야'],
#  ['개쩐', '싸움', '수준', '실화', '가슴', '웅장'],
#  ['국뽕',
#   '영화',
#   '게',
#   '관객',
#   '수',
#   '위',
#   '게',
#   '우리나라',
#   '국민',
#   '수준',
#   '대변',
#   '줌',
#   '감성',
#   '팔이',
#   '통함'],
#  ['이', '영화'],
#  ['영화', '꼭', '번', '보시'],
#  ['진짜'],
#  ['진짜', '내', '원픽', '영화', '정말', '앞', '번은', '더', '느낌', '볼', '수', '듯'],
#  ['정말', '생각', '보기', '영화', '만', '영화'],
#  ['번', '번', '그냥'],
#  ['극장', '진짜'],
#  ['이', '지수', '교수', '최고'],
#  ['낮', '치킨', '장사', '밤', '잠복근무', '지금', '수사'],
#  ['영화관', '때', '별로', '다시', '보', '꽤', '코믹', '영화'],
#  ['진짜', '재미', '빵'],
#  ['한국영', '수준', '정도', '안'],
#  ['이', '거', '사람', '해안', '감'],
#  ['이제야'],
#  ['배우', '연기', '영화'],
#  ['극한', '직업', '욤', '정말', '극장', '두', '번'],
#  ['굿', '최고', '명품', '영화'],
#  ['폭력조직',
#   '보스',
#   '신하균',
#   '미스',
#   '캐스트',
#   '보스',
#   '뒷골목',
#   '조무',
#   '똘',
#   '보스',
#   '역',
#   '더',
#   '무게',
#   '관록',
#   '연기자',
#   '캐스팅'],
#  ['난', '비정상', '가정', '상인', '전혀', '재미', '못', '관객수', '진짜', '이해', '내', '사람인'],
#  ['각각', '배우', '열연', '캐릭터', '소화', '율', '최고', '영화'],
#  ['최고', '요', '완전'],
#  ['내내', '짓', '영화'],
#  ['평점', '주지', '지금', '기억', '영화'],
#  ['그냥', '말', '필요', '영화', '연출', '스토리', '개그', '요소'],
#  ['처음', '끝', '정말', '노잼', '코드', '연속'],
#  ['공짜',
#   '원래',
#   '욕',
#   '안해',
#   '상',
#   '도덕',
#   '임',
#   '노력',
#   '욕',
#   '영화',
#   '게',
#   '이건',
#   '나',
#   '돈',
#   '물귀신',
#   '작전',
#   '게',
#   '분명',
#   '함',
#   '결론',
#   '돈',
#   '안보',
#   '길',
#   '영화'],
#  ['여러', '번', '영화', '점', '만점'],
#  ['번', '만', '영화'],
#  ['재밋', '개연', '현실'],
#  ['군더더기'],
#  ['연기', '진짜', '가끔', '개그', '가끔', '진짜', '인', '생', '레전드', '영화'],
#  ['끝'],
#  ['계속', '영화', '볼', '수', '영화', '대사도', '상황', '영화'],
#  ['번', '꼭', '진짜', '웃기', '또'],
#  ['한국영', '화의', '코미디'],
#  ['지금', '맛', '것', '갈비', '통닭', '가수', '원왕', '갈비', '통닭'],
#  ['급', '보이지', '장르', '집중', '생각', '볼', '수', '영화'],
#  ['개똥', '영화', '노잼', '어거지', '무뇌', '영화'],
#  ['한국', '코미디', '영화', '별로', '극한', '직업', '첨부', '터', '끝', '억지로', '과', '강추'],
#  ['볼', '때', '최고'],
#  ['진짜', '걸', '최고다'],
#  ['번', '진짜', '내', '최애영', '연기', '진짜', '거'],
#  [],
#  ['틀'],
#  ['영화', '개', '영화', '상', '함'],
#  ['영화'],
#  ['그냥', '급', '병맛', '영화'],
#  ['내내', '계속'],
#  ['한국영', '최고'],
#  ['존', '잼', '연기', '맛깔', '남강', '츄'],
#  ['보고', '또', '보고', '또', '영화', '액션', '웃음', '포인트'],
#  ['최애영'],
#  ['볼', '수', '정말', '잼', '영화', '기준', '점'],
#  ['배우', '진짜', '것'],
#  ['관객', '흥행', '작', '나', '생각', '영화', '몇몇', '코믹', '씬', '덕분', '볼', '정도'],
#  ['재미'],
#  ['재', '개그', '남발', '치킨', '광고', '영화'],
#  ['영화', '킴', '코믹', '영화', '중', '최고', '듯'],
#  ['뭐', '개꿀잼'],
#  ['대한민국', '화보', '수준'],
#  ['이', '점'],
#  ['방금',
#   '넷플릭스',
#   '만',
#   '다시',
#   '거',
#   '하나',
#   '짱',
#   '원래',
#   '집중',
#   '집',
#   '영화',
#   '한편',
#   '끝',
#   '적',
#   '이건',
#   '영환',
#   '데',
#   '틈',
#   '끝',
#   '존잼'],
#  ['정말',
#   '그냥',
#   '사전',
#   '지식',
#   '영화',
#   '멍하니',
#   '보고',
#   '계속',
#   '억지',
#   '감정',
#   '놨다간',
#   '한국',
#   '영화',
#   '조폭'],
#  ['창의',
#   '스토리',
#   '코믹',
#   '연출',
#   '제작',
#   '생각',
#   '함',
#   '영화',
#   '중후',
#   '부로',
#   '면',
#   '자진',
#   '별',
#   '그대',
#   '스토브',
#   '리그',
#   '것'],
#  ['진짜', '영화', '멘트', '대사', '전혀'],
#  ['굿굿굿', '자꾸', '보고', '보고', '때', '재밋'],
#  ['스토리', '무엇', '신파'],
#  ['이', '코미디', '점'],
#  ['몇', '번', '오정세'],
#  ['몇', '번', '모름', '등장인물', '마스트', '정도', '임'],
#  ['손', '꼽', '화예', '요'],
#  ['급', '육질', '간', '닭', '마리', '느글거리'],
#  ['볼', '때', '치킨', '집', '범인', '거임'],
#  ['코미디', '액션', '정석'],
#  ['단언컨대', '내', '인생', '영화'],
#  ['걱정', '근심', '스트레스', '기분', '공포', '생각', '마음', '가득', '진짜', '짱', '게', '음'],
#  [],
#  ['진짜', '연기', '감상', '습'],
#  ['진짜', '웃기', '잼', '용'],
#  ['장면', '그냥'],
#  ['첨', '여러', '번', '웃기', '이병헌', '감독', '배우', '연기', '찰떡', '대사', '빈틈'],
#  ['어우', '흥행', '게', '점', '만점', '점'],
#  ['웃음'],
#  ['킬링타임',
#   '용',
#   '재밋었다',
#   '한국',
#   '코',
#   '영화',
#   '특유',
#   '정말',
#   '수가',
#   '건가',
#   '특유',
#   '오버',
#   '연출',
#   '등',
#   '예전',
#   '코',
#   '영화',
#   '크게',
#   '발전'],
#  ['개', '덕붓', '듯이'],
#  [],
#  ['그냥', '듯', '바', '연기', '디테일', '술'],
#  ['진짜', '뻥', '안', '내용', '다시'],
#  ['처음', '끝', '새'],
#  ['항상', '항상', '영화'],
#  ['첫째',
#   '명량',
#   '둘째',
#   '번방',
#   '거품',
#   '렉',
#   '장의',
#   '막내',
#   '개그',
#   '코드',
#   '말',
#   '한국',
#   '흥행',
#   '코메디',
#   '절망',
#   '영화',
#   '희망',
#   '보고',
#   '최근',
#   '영화',
#   '인',
#   '시트',
#   '추천',
#   '함'],
#  ['그냥', '최고'],
#  ['다시', '연기', '듯'],
#  ['막판', '현실', '설정', '근래', '화주', '가장', '웃', '수'],
#  ['이병헌', '감독', '화가', '영화'],
#  ['극한', '직업', '니', '짱', '집', '불', '면서', '땀', '게', '극한', '겨'],
#  ['생각'],
#  ['처음', '끝', '코믹', '구성', '국', '코믹', '영화', '표본'],
#  ['초', '중반', '정말', '데', '이후', '힘', '쭉쭉'],
#  ['도대체', '영화', '흥행'],
#  ['한국영'],
#  ['이', '점', '관객', '한국영', '수준'],
#  ['아무',
#   '생각',
#   '보기',
#   '영화',
#   '다시',
#   '더',
#   '코믹',
#   '액션',
#   '영화',
#   '액션',
#   '연기',
#   '대사',
#   '하나',
#   '배우',
#   '연기',
#   '박수'],
#  ['극장', '돈', '한번', '두', '번', '대도', '한참', '영화'],
#  ['예능', '더', '이병헌', '감독', '대박'],
#  ['코믹', '액션', '만', '데'],
#  ['치킨', '가족'],
#  ['대사도', '웃기'],
#  ['재미', '재미', '재미', '재미', '존잼'],
#  ['경찰', '코미디', '패', '시브', '인', '허세', '손', '정도'],
#  ['영화'],
#  ['영화', '영화', '낼', '수', '최고', '품질'],
#  ['보고', '또', '네'],
#  ['하늬', '진국'],
#  ['번'],
#  ['한국영',
#   '화의',
#   '교과서',
#   '한국',
#   '나라',
#   '액션',
#   '코믹',
#   '배우',
#   '연기',
#   '영화',
#   '그게',
#   '극한',
#   '직업',
#   '각본',
#   '감독',
#   '영화'],
#  ['영화', '로써', '코미디', '끝', '예고편', '안', '보고', '배꼽', '영화'],
#  ['기대', '안', '처음', '끝'],
#  ['한국영', '화의', '한계'],
#  ['진짜', '두', '번'],
#  ['여러', '번', '다시'],
#  ['거',
#   '안',
#   '요',
#   '진짜',
#   '최고',
#   '오락',
#   '영화',
#   '가족',
#   '영화',
#   '코믹',
#   '액션',
#   '영화',
#   '임',
#   '관객',
#   '수',
#   '기록',
#   '거품',
#   '안',
#   '영화',
#   '생각',
#   '함',
#   '극장',
#   '티비',
#   '넷',
#   '플로',
#   '가끔',
#   '항상',
#   '웃기',
#   '재미',
#   '짐'],
#  ['대체', '불가', '대한민국', '조미료', '김치찌개', '영화'],
#  ['영화', '흥행', '거', '세상'],
#  ['영화', '처음', '배', '두', '때', '배', '정도', '웃기'],
#  ['재미나', '정말'],
#  ['내', '코미디', '영화', '중단', '컨', '최고', '생각'],
#  ['진짜', '것', '영화', '늨본', '적', '개', '웃기'],
#  ['영화', '안'],
#  ['코', '영화', '중', '최고', '최애', '작'],
#  ['한국영',
#   '중',
#   '최애',
#   '개',
#   '중',
#   '개',
#   '극한',
#   '직업',
#   '금',
#   '자씨',
#   '웰컴',
#   '투',
#   '막골',
#   '몇',
#   '번'],
#  ['다시', '웃기'],
#  ['명성', '았', '연기력'],
#  ['극한', '직업', '당시'],
#  ['라싸', '쌩', '짝짝'],
#  ['때', '최애영'],
#  ['영화', '대해', '사람', '단순', '재미', '도', '평점'],
#  ['조선족', '그냥'],
#  ['이', '게', '수준', '충격', '감동', '지도'],
#  ['원래',
#   '코믹',
#   '영화',
#   '안보',
#   '편',
#   '영화',
#   '억지',
#   '웃음',
#   '게',
#   '요새',
#   '웃',
#   '영화',
#   '내내',
#   '거',
#   '그동안',
#   '안',
#   '게',
#   '정도'],
#  ['한국', '코', '웰', '메이드', '명작'],
#  ['매력', '캐릭터', '코미디', '걸', '감안', '정신'],
#  ['초반', '장면', '중후', '반', '류', '범죄', '물', '전락'],
#  ['패', '것', '게', '더', '도'],
#  ['고급', '식당', '프랜차이즈', '치킨', '느낌'],
#  ['근래', '한국', '코미디', '영화', '중', '제일'],
#  ['이', '천만', '거실', '존', '나'],
#  ['신하균', '오정세', '기억'],
#  ['진짜', '이병헌', '작가', '요즘', '넷플', '하루', '번', '것', '진짜', '존잼'],
#  ['평가', '필요', '시간', '모든', '게'],
#  ['진짜', '계속'],
#  ['극장', '개봉', '보고', '넷', '플로', '처음', '다시', '역시', '명작', '이유'],
#  ['나', '나', '웃음', '코드', '안', '억지', '웃음', '억지', '스토리'],
#  ['생각', '마냥', '볼', '수', '최고', '영화'],
#  ['코미디', '영화', '결정', '판', '끝판', '감독', '특유', '말맛', '한국', '영화'],
#  ['별', '재미', '회피', '함'],
#  ['개봉',
#   '때',
#   '극장',
#   '보고',
#   '최근',
#   '번',
#   '더',
#   '배우',
#   '코믹',
#   '연기',
#   '인상',
#   '치킨',
#   '소재',
#   '활용',
#   '즐',
#   '기기',
#   '다시',
#   '골'],
#  ['억지', '웃음', '데', '난', '잼'],
#  ['내', '취향', '듯', '분명', '요소', '거기', '완성', '도나', '개연', '측면', '거리', '느낌', '이'],
#  ['이'],
#  ['진짜', '존', '나', '웃기', '개', '네미', '용', '완전', '꿀잼꺄륵'],
#  ['진짜',
#   '게',
#   '흥행',
#   '순위',
#   '위',
#   '진짜',
#   '한국',
#   '공중파',
#   '드라마',
#   '개그콘서트',
#   '우리나라',
#   '사람',
#   '존',
#   '나',
#   '유머',
#   '코드',
#   '진짜',
#   '존',
#   '나',
#   '데'],
#  ['다시', '봣', '정말', '재밋다'],
#  ['수원', '갈비', '통닭'],
#  ['나', '영화', '한번'],
#  ['치킨', '갈비', '불륜'],
#  ['이제', '극한', '직업', '내', '인생', '영화', '진심', '볼', '때'],
#  ['연기'],
#  ['진짜', '웃낌', '마을', '버스', '스쿨버스', '마지막', '영웅', '본색', '노래'],
#  ['처음', '끝', '영화', '신파', '생각', '볼', '수', '내', '장르'],
#  ['체고', '하나', '안', '끝', '봄'],
#  ['말', '세긴', '대사'],
#  ['난', '왜', '관객수'],
#  ['데', '추천'],
#  ['만', '영화', '정말'],
#  ['걸', '보고', '평점', '이나', '수', '개존', '잼임'],
#  ['그냥', '시간', '볼', '함'],
#  ['류승룡', '진짜', '개그', '예술'],
#  ['영화관', '값', '영화', '대박', '정도', '거', '소재', '유행어', '시나리오', '최고', '듯'],
#  ['평점', '천만', '일단', '보기'],
#  ['졸', '웃음', '사람', '추천'],
#  ['거', '좀비', '영화인', '줄'],
#  ['잼', '연출', '편집', '대사', '감각', '스토리', '개연', '신경', '티나', '고', '유머', '감각'],
#  ['배우', '이하늬', '탄생', '영화'],
#  ['역대', '코', '영화', '웃음', '포인트', '군더더기', '스토리'],
#  ['존', '나', '웃기', '진짜'],
#  ['다시', '몇', '번'],
#  ['요', '잼', '보기'],
#  ['대서',
#   '프랑',
#   '극장',
#   '첫',
#   '개그',
#   '코드',
#   '웃음',
#   '안',
#   '영화',
#   '수원',
#   '집',
#   '집값',
#   '두',
#   '배'],
#  ['만'],
#  ['또', '영화'],
#  ['몇', '번', '다시'],
#  ['무'],
#  ['간만', '연기', '내용', '인물', '전부'],
#  ['한국', '코미디', '부활', '한국', '코미디', '영화', '편견', '작품'],
#  ['한국영'],
#  ['진짜', '진짜', '꿀잼', '크킄크', '번', '봄', '진짜'],
#  ['진짜', '어캐천', '류', '검사', '외전', '베테'],
#  ['코미디', '영화', '진심', '건', '내', '평생', '처음', '듯'],
#  ['웃기'],
#  ['모처럼', '신파', '교훈', '질', '코미디', '다운', '코미디'],
#  ['영화', '처음'],
#  ['진짜', '배꼽', '짐'],
#  ['웰', '메이드', '한국', '코', '연기', '연출', '최고'],
#  ['넷플릭스', '떳길', '마을', '버스'],
#  ['웃음', '포인트', '광해', '최근', '다시', '보고', '나', '천만', '관객', '바'],
#  ['이', '이', '내', '개그', '코드', '건', '영화', '때', '번', '끝'],
#  ['극장', '두', '번', '봣는데', '넷플', '다시', '웃기'],
#  ['내내', '생각', '안', '기분', '영화', '감동', '의미', '전달', '영화', '코믹', '영화'],
#  ['진선규', '배우', '팬', '영화', '진', '선규', '배우', '청룡영화제', '대상', '가즈'],
#  ['개꿀잼', '진짜', '처음', '끝'],
#  [],
#  [],
#  ['맥락', '코'],
#  ['신파', '억지', '급감', '뭘', '말', '영화', '내', '취향'],
#  ['내', '최애영', '몇', '번'],
#  [],
#  ['번은', '더', '질리', '존', '잼', '진짜'],
#  ['이제', '웃기'],
#  ['진짜', '다시'],
#  ['주간', '생각', '감동', '그냥', '볼', '만', '영화'],
#  ['몇', '번'],
#  ['점', '만점', '제대로', '완전', '영화'],
#  ['잼잼'],
#  ['평점', '게', '코미디'],
#  ['설',
#   '연휴',
#   '시리즈',
#   '온',
#   '구매',
#   '걸',
#   '이제야',
#   '존',
#   '잼',
#   '틈',
#   '요즘',
#   '웃',
#   '거',
#   '동안',
#   '자꾸',
#   '간',
#   '힐링'],
#  ['극하'],
#  ['굿', '시간', '역시'],
#  ['진짜',
#   '정말',
#   '정말',
#   '이',
#   '왜',
#   '평점',
#   '도무지',
#   '이해',
#   '안',
#   '감정',
#   '말',
#   '그',
#   '중',
#   '신하균',
#   '강패',
#   '때',
#   '다른',
#   '건',
#   '정말'],
#  ['네이버',
#   '영화',
#   '평점',
#   '점',
#   '걸',
#   '적',
#   '점',
#   '함',
#   '우리나라',
#   '코미디',
#   '영화',
#   '정도',
#   '신파',
#   '작',
#   '작'],
#  ['간만', '정말', '영화', '군더더기', '연기', '최고', '방금', '또', '보고'],
#  ['줄거리', '생각', '안', '배우', '표정', '연기', '연출', '스토리', '코믹', '상욕', '난무', '건'],
#  ['영화'],
#  ['통닭', '광고인', '줄'],
#  ['만', '빵빵', '영화', '각본', '연기', '연출'],
#  ['정말'],
#  ['코미디', '이', '영화', '점'],
#  ['몇', '번', '존', '잼임'],
#  ['진짜'],
#  ['번', '그냥', '킬링타임', '영화'],
#  ['번', '안', '웃음'],
#  ['완전', '억지', '웃음', '유발', '댓글', '뭐'],
#  ['전형', '킬링타임', '용', '코미디', '영화', '생각', '보기'],
#  ['재미', '추천'],
#  ['볼', '때', '양념치킨', '커플', '불륜', '설정', '부녀', '관계', '여자', '남자', '대로', '데'],
#  ['여러', '번', '정말', '코미디', '영화'],
#  ['거', '후속', '안'],
#  ['예산', '억지', '코미디', '영화'],
#  ['천만', '대서', '작위', '연출', '대사', '말'],
#  ['정도', '관객수', '동원', '이유', '신파', '앞', '한국', '코미디', '영화', '식'],
#  ['말', '필요', '자'],
#  ['범죄',
#   '착',
#   '맛',
#   '맛',
#   '그냥',
#   '맛',
#   '배우',
#   '연기력',
#   '외',
#   '볼',
#   '게',
#   '요소',
#   '치킨',
#   '나름',
#   '외',
#   '요소',
#   '이해',
#   '도저히',
#   '안',
#   '영화'],
#  ['수원', '갈비', '통닭', '머리', '자꾸'],
#  ['영환', '처음', '다다', '뒤', '게', '하나', '내내', '스트레스', '탄산음료', '영화'],
#  ['동안', '번', '안', '쉬', '번'],
#  ['생각', '보기', '개꿀', '잼', '이제'],
#  ['부제', '힘', '숨', '마약', '반', '가족'],
#  ['내', '기준', '젤', '영화', '영화'],
#  ['도랏', '웃', '김'],
#  ['또'],
#  ['코미디', '영화', '라면'],
#  ['초', '중딩', '코믹', '영화'],
#  ['아주', '한참'],
#  ['간만', '영화'],
#  ['사람', '수준', '영화', '천만'],
#  ['음', '지금', '영화', '번', '정도', '볼', '때'],
#  ['나', '인생', '가장', '영화', '꼽자', '영화', '십'],
#  ['병헌',
#   '천만',
#   '니',
#   '실력',
#   '감독',
#   '생각',
#   '진짜',
#   '생각',
#   '어이구',
#   '병헌',
#   '앞',
#   '영화평론',
#   '애',
#   '나라',
#   '영화',
#   '수준',
#   '이',
#   '냥',
#   '내',
#   '누구'],
#  ['이', '급', '최상급'],
#  ['초딩', '용', '영화', '영화', '계속', '한국영', '수준'],
#  [],
#  ['스물', '답', '음'],
#  ['꼭', '욬'],
#  ['간만', '영화', '처음', '끝', '영화'],
#  ['소리', '영화', '진짜'],
#  ['평점', '좀', '자', '천만', '관객'],
#  ['그냥', '만', '감독', '배우', '이병헌', '줄', '착각', '첫', '장면', '무지', '강추'],
#  ['이'],
#  ['오정세', '천', '얼굴', '다작', '전작', '수가', '함글', '극한', '직업', '개띵작'],
#  ['정말',
#   '쓰레기',
#   '돈',
#   '안',
#   '공짜',
#   '나',
#   '행운',
#   '아',
#   '걸',
#   '알',
#   '왓챠',
#   '추석',
#   '쿠폰',
#   '쓰레기',
#   '것'],
#  ['웃음', '영화', '연출', '연기', '볼', '수', '영화'],
#  ['다섯', '번은', '듯', '배우'],
#  ['오십', '후반', '엄마'],
#  ['거', '해', '안감', '새해', '볼', '거', '천만', '듯'],
#  ['진짜', '거짓말', '안치', '내내', '무표정', '봄'],
#  ['영화', '시간', '동안', '계속'],
#  ['진짜', '김', '코미디', '영화', '천만', '관객', '이유'],
#  ['이', '천만', '관객', '이해', '안', '정도', '유치'],
#  ['코미디', '별로', '안', '난리', '때', '안', '이제', '처음', '이제야', '연기'],
#  ['전', '영화', '지금', '사람', '꼭', '번', '보라', '이제야', '만', '새'],
#  ['부모님', '다시', '정말', '영화', '최'],
#  ['공식', '영화'],
#  ['진짜', '부담', '형사물'],
#  [],
#  ['재앙', '마냥', '억지', '웃음', '억지', '감성', '감동', '감흥', '미신', '파', '거품', '영화'],
#  ['자영', '업자', '상공', '목숨', '일', '사기', '억'],
#  [],
#  ['코미디', '무조건', '거르', '이', '뒤통수', '쌔', '준', '영화'],
#  ['도', '안', '가기', '캄탄나옴'],
#  ['진짜', '도', '코믹', '영화로', '강력', '추천'],
#  ['요즘', '시기', '영화', '웃', '수'],
#  ['처음',
#   '웃기',
#   '요',
#   '스토리',
#   '배우',
#   '연기',
#   '진짜',
#   '더',
#   '거',
#   '마지막',
#   '컨테이너',
#   '곳',
#   '제',
#   '곳',
#   '소식',
#   '안',
#   '저',
#   '후회'],
#  ['진짜', '재밋', '봣어', '꿀잼', '웃음', '음'],
#  ['재밋어', '진짜', '또', '봄'],
#  ['나', '별로', '요'],
#  ['꿀잼띠', '꿀잼띠'],
#  ['연기', '별로'],
#  ['정말', '영화', '생각', '계속', '보고', '영화', '고요'],
#  [],
#  ['젤', '잼', '시간', '줄'],
#  ['이', '점', '진심'],
#  ['한국영', '퇴', '행시', '키', '곽경택', '코미디'],
#  ['생각', '안', '보기'],
#  ['이', '정도'],
#  ['이', '올해', '영화', '관람'],
#  ['첬', '류승룡', '아저씨', '개', '웃기', '진', '짴'],
#  [],
#  ['비급', '코', '감상', '포인트', '자꾸', '하라'],
#  ['대체', '어디가', '코미디', '어이', '운', '영화'],
#  ['폭소', '터', '트릴', '준비', '극한', '관람'],
#  ['정말', '극한', '직업', '말', '저따위', '말', '자', '제목', '완전', '러'],
#  ['이', '영화', '니미', '시바'],
#  ['코미디', '영화', '신파', '따위', '필요', '것'],
#  ['집중', '틈', '영화'],
#  ['정말', '부분'],
#  ['대한민국', '영화', '현실', '번방', '선물', '개돼지', '대작'],
#  ['아무', '생각', '보기'],
#  ['여', '번', '봄'],
#  ['진짜', '거짓말', '안치', '내내', '무표정', '봄'],
#  ['시작',
#   '때',
#   '웃음',
#   '보고',
#   '또',
#   '봄',
#   '재미',
#   '짐',
#   '감히',
#   '내',
#   '코미디',
#   '영화',
#   '중',
#   '최고',
#   '수'],
#  ['광고', '역대', '최고', '거품', '영화'],
#  ['영화관', '듯이', '적', '이'],
#  ['뻥', '안치', '언제', '존잼'],
#  ['배우',
#   '연기',
#   '스토리',
#   '죽',
#   '뻔',
#   '우리나라',
#   '욕조',
#   '폭',
#   '마약',
#   '폭력',
#   '영화',
#   '소재',
#   '나라',
#   '미래',
#   '진짜'],
#  ['하늬', '매력', '뿜뿜', '영화'],
#  ['생각', '엔드게임', '겨울왕국', '기생충', '관객수'],
#  ['생각', '인생', '영화'],
#  ['진짜',
#   '걸',
#   '천만',
#   '명',
#   '사람',
#   '게',
#   '따름',
#   '천만',
#   '관객',
#   '영화',
#   '중',
#   '가장',
#   '영화',
#   '자신',
#   '확신',
#   '수'],
#  [],
#  ['건', '그냥', '재미', '하나', '영화'],
#  ['연기', '최고'],
#  ['이제', '클레멘타인', '욕', '게', '천만', '관객', '뭐', '클레멘타인'],
#  ['로', '다가', '개꿀', '잼', '티비', '소장', '번은', '듯', '알바', '개꿀잼', '화평', '점주'],
#  ['데', '한국', '현실', '반영'],
#  ['노잼', '게', '천만'],
#  ['한국영', '극장', '안보', '데', '극장', '볼', '수', '만큼', '값어치'],
#  ['존', '나', '그거', '하나'],
#  ['영화', '천만', '역대', '흥행', '위', '정도', '인', '건가', '함'],
#  ['오버', '연기', '향연', '장면', '곳곳', '포진', '안'],
#  ['명량', '재', '평가', '역대', '최', '관객', '위', '사수', '이순신', '장군', '최민식', '배우', '경의'],
#  ['점', '이유', '놈', '경찰', '검찰', '소재', '한계', '시간', '줄', '국산', '영화'],
#  ['한국영', '수준', '거'],
#  ['억지', '웃음', '유발', '평점', '왜'],
#  ['두', '배우', '억지', '개그', '연기', '점', '감점', '나머진', '두', '명'],
#  ['스토리', '영화', '역대', '위', '진짜', '수준', '국영'],
#  ['별', '도', '움', '억지로', '고용', '모습'],
#  ['처음', '끝', '배꼽', '영화', '최고'],
#  ['인생', '영화'],
#  ['점',
#   '하나',
#   '망작',
#   '원작',
#   '것',
#   '모자라',
#   '억지',
#   '감동',
#   '것',
#   '식',
#   '한국',
#   '영화계',
#   '퇴보',
#   '뿐'],
#  ['누구', '가지', '적', '곳', '세계', '문', '린다'],
#  ['중국산', '싸구려', '영화'],
#  ['주연',
#   '김동욱',
#   '영화',
#   '김동욱',
#   '도경수',
#   '연기',
#   '자칫',
#   '영화로',
#   '듯',
#   '김동욱',
#   '연기',
#   '해도',
#   '과언'],
#  ['난', '지옥', '가면'],
#  ['웹툰', '신', '대한', '모욕', '쭈', '작가', '감독', '생각', '함'],
#  ['신파', '끝', '영화', '천만', '게'],
#  ['정말', '정말', '영'],
#  ['신파', '맨', '영화', '봄왤케', '평점'],
#  ['할머니',
#   '할머니',
#   '아이',
#   '때문',
#   '모습',
#   '안',
#   '커녕',
#   '음악',
#   '감동',
#   '것',
#   '감동',
#   '잔',
#   '할머니',
#   '연기',
#   '별',
#   '점',
#   '줌'],
#  ['도입',
#   '나름',
#   '갈수록',
#   '그냥',
#   '개판',
#   '오',
#   '분',
#   '전',
#   '영상',
#   '미덕',
#   '점',
#   '주지',
#   '도저히',
#   '못',
#   '갈수록',
#   '생각',
#   '얘',
#   '왜',
#   '진짜',
#   '왜'],
#  ['그냥', '슬픔', '그냥', '슬픔', '부모', '자식', '사람', '알', '것', '그냥', '오열', '함'],
#  ['눈물', '나', '눈물', '영화'],
#  ['명작', '웹툰', '신파', '영화로', '화가', '못'],
#  ['지옥', '재판', '정말', '오늘', '맘', '살인', '듯'],
#  ['차태현', '연기', '함', '눈물', '주르륵'],
#  ['소재', '상미', '시간', '줄'],
#  ['신', '쯤'],
#  ['기존',
#   '한국영',
#   '볼',
#   '수',
#   '판타지',
#   '물이',
#   '자',
#   '흥행',
#   '작',
#   '중',
#   '웹툰',
#   '저력',
#   '확인',
#   '수',
#   '작품',
#   '스토리',
#   '전통문화',
#   '오늘날',
#   '컨텐츠',
#   '재탄생',
#   '시도',
#   '함'],
#  ['존재', '지옥', '소재', '인간', '잘못', '가족', '애', '정말', '영화'],
#  ['해', '맥', '캐릭터', '원작', '달리', '비호감', '고정', '안', '간다', '점'],
#  ['편', '먼저', '보고', '편', '이제', '편', '별로', '마지막', '장면', '슬프넹'],
#  ['누구', '감동', '눈물', '거', '진짜', '몰입', '증거'],
#  ['눈물', '겨', '운', '화생방'],
#  ['영화', '하정우'],
#  ['평소', '불구덩이', '정도', '로만', '상상', '지옥', '모습', '연출', '연해', '배우', '캐스팅', '연기력'],
#  ['원작', '부분', '영화', '극적', '연출'],
#  ['티비', '만', '다시', '다시', '감동', '요'],
#  ['한국영', '요하', '안', '요제', '발', '예'],
#  ['효도', '단어', '머리', '준', '영화'],
#  ['신파', '볼', '함'],
#  ['모든', '게', '한국영', '화의', '수작', '블록버스터', '임', '시', '가슴', '스토리', '완벽'],
#  ['마구', '버무린', '신파극'],
#  ['기술', '할리우드', '법정', '토끼', '전', '감성', '심청', '전'],
#  ['어린이', '가족영화', '흥행', '만', '중국화', '판타지', '영화', '중국', '영화'],
#  ['죄', '지옥', '간다'],
#  ['내', '어머니', '위', '영화'],
#  ['진짜', '보고'],
#  ['진짜', '모든', '장면', '전율', '전율', '관람객', '요', '맨', '마지막'],
#  ['국내', '영화', '따위', '수식', '어구', '정말'],
#  ['감동', '유도', '영화', '마련', '죄', '정말', '눈물', '게', '정말', '별로', '영화'],
#  ['밑', '분', '낙태', '지옥', '나태', '지옥'],
#  ['지금',
#   '영화',
#   '중',
#   '일별',
#   '임',
#   '어거지',
#   '감동',
#   '연출',
#   '깨달음',
#   '일',
#   '대사',
#   '눈살',
#   '찌',
#   '짐'],
#  ['영화', '대해', '사람', '단순', '재미', '도', '평점'],
#  ['진짜', '정말', '모로', '레전드', '영화', '생각'],
#  ['영화'],
#  ['신파',
#   '덩어리',
#   '원작',
#   '사람',
#   '영화',
#   '판이',
#   '만화',
#   '작가',
#   '무시',
#   '느낌',
#   '대체',
#   '차태현',
#   '원작',
#   '김자',
#   '홍',
#   '하나',
#   '안'],
#  ['신파', '작렬', '이', '관객', '의문'],
#  ['거', '혜원', '맥', '왜', '저따위', '캐릭터'],
#  ['요도', '경수', '연기', '함'],
#  ['아빠', '거', '보고', '영화관', '눈물', '훌쩍', '훌쩍', '거렸', '쪽'],
#  ['줄'],
#  ['다시', '최고'],
#  ['눈물', '려고', '노력', '신파극'],
#  ['휴지', '필수', '운지'],
#  ['원작', '내용', '개', '노잼'],
#  ['듯', '느낌', '볼거리'],
#  ['어머니', '어머니', '어머니', '어머니'],
#  ['즙', '개'],
#  ['연기력', '연출', '스토리'],
#  ['울', '수', '펑펑', '가슴', '건'],
#  ['여기'],
#  ['전개', '오열', '스타일'],
#  ['재미', '감동', '영화'],
#  ['영화', '보고', '눈물', '단', '방울', '당신', '싸이', '패스'],
#  ['로', '사람', '문', '앞', '듯', '이유', '거'],
#  ['영화', '모든', '사람', '연기', '스토리', '감동'],
#  ['눈물', '바다'],
#  ['개봉', '때', '보고', '두', '줄', '한국', '판', '지영', '수작'],
#  ['배우', '모두', '연기', '사후', '세계', '감동', '현재', '삶', '교훈', '영화'],
#  ['세계',
#   '최고',
#   '스케일',
#   '환타지',
#   '신파',
#   '억지',
#   '눈물',
#   '안',
#   '영화',
#   '못',
#   '만드',
#   '배우',
#   '열연',
#   '예전',
#   '발전',
#   '시각',
#   '효과',
#   '움'],
#  ['기만', '모든', '재판', '통과', '임'],
#  ['신파', '술'],
#  ['개봉',
#   '당시',
#   '극장',
#   '보고',
#   '오늘',
#   '티비',
#   '재방',
#   '거',
#   '진짜',
#   '끝',
#   '엉엉',
#   '거리',
#   '표시',
#   '안',
#   '진짜'],
#  ['만화',
#   '대사',
#   '연기',
#   '크게',
#   '눈물',
#   '가족',
#   '애',
#   '대한',
#   '표현',
#   '그게',
#   '작품',
#   '생각',
#   '점',
#   '사람',
#   '객관'],
#  ['진짜', '스토리', '영화', '옛날', '보고', '중이'],
#  ['차태현', '역시', '시종일관', '연기', '안', '코믹', '빛', '차태현', '미스캐스팅', '주관', '생각', '임'],
#  ['영화', '번', '세계', '낙태', '지옥', '듯'],
#  [],
#  ['시보', '차태현', '케릭', '터', '말', '한마디', '제대로', '샤키', '키'],
#  ['머릿속', '상가', '신파', '스토리', '도', '눈', '눈물'],
#  ['연기력', '점', '개', '타', '영화', '알바', '평점'],
#  ['멋',
#   '구현',
#   '지옥',
#   '테마',
#   '파크',
#   '체험',
#   '묘미',
#   '삶',
#   '보편',
#   '가치',
#   '정서',
#   '공감',
#   '조화',
#   '신파',
#   '강박',
#   '어쨌든',
#   '흥미'],
#  ['한국영', '특', '유의', '신파씬', '난무'],
#  ['워', '너비', '죄', '벌'],
#  ['최악',
#   '영화',
#   '한국',
#   '제일',
#   '거지',
#   '영화',
#   '중',
#   '하나',
#   '임',
#   '진짜',
#   '진짜',
#   '거',
#   '초딩',
#   '못',
#   '봄',
#   '지능',
#   '거나'],
#  ['대박', '영화배우', '연기력', '꼭'],
#  ['감독', '일반', '서민', '삶'],
#  ['판타지',
#   '장르',
#   '그냥',
#   '런가',
#   '마지막',
#   '오열',
#   '어머니',
#   '더',
#   '감정',
#   '더',
#   '요',
#   '기억',
#   '영화'],
#  ['인생', '영화', '해도', '무방'],
#  ['감동', '인위'],
#  ['그냥', '말', '필요', '인생', '영화'],
#  ['영화', '아들'],
#  ['영화', '사후', '세계', '혐생', '고통'],
#  ['인생', '안', '안', '드라마', '개', '안', '듭니'],
#  ['진작', '볼', '걸'],
#  ['영화', '이', '영화', '중독'],
#  ['해도', '볼', '함'],
#  ['작위', '볼', '만'],
#  ['진심', '김동욱', '연기'],
#  ['감동', '지수', '존', '나', '높음옶나', '진짜', '여'],
#  ['억지로', '스토리', '주입', '무대', '밖', '나라', '사람', '걸'],
#  ['속편', '도', '보고', '예상외', '꿀잼', '핵잼'],
#  ['진짜', '이'],
#  ['다시', '알', '연기자', '김동욱', '연기력'],
#  ['영화', '보고', '운', '사람', '영화', '처음'],
#  ['인생', '영화', '감동', '면서', '교훈', '줌'],
#  ['신파', '쓰레기'],
#  ['더', '이상', '말', '삼'],
#  ['인생',
#   '번',
#   '계기',
#   '준',
#   '영화',
#   '이',
#   '영화',
#   '보고',
#   '누군가',
#   '죄',
#   '살',
#   '용서',
#   '생각',
#   '그',
#   '사람',
#   '인생',
#   '무신론자',
#   '평생',
#   '것'],
#  ['배우', '연기', '갑자기', '리뷰', '편'],
#  ['사람', '영화'],
#  ['때'],
#  ['신파', '유치', '연기력', '점', '후속작', '인과', '연', '볼', '만', '점', '감'],
#  ['가장', '영화', '마지막', '이', '정말', '슬펏', '음'],
#  ['전'],
#  ['형',
#   '새끼',
#   '게',
#   '이',
#   '엄마',
#   '집',
#   '못',
#   '일',
#   '돈',
#   '준',
#   '거',
#   '엄마',
#   '자홍',
#   '자홍',
#   '평생',
#   '엄마',
#   '평생'],
#  ['진짜', '틀', '선', '악', '감정', '팔이', '천만', '기생충', '거른다', '앞'],
#  ['차태현', '연기', '별로', '어색', '나름', '국민', '글', '지그', '외', '다른', '사람', '연기'],
#  ['원작', '망치', '기도', '정말', '중국', '영화', '백배', '못'],
#  ['점', '테러', '애', '부모님', '안', '거가', '눈물', '뭐', '사랑', '알'],
#  ['꼭', '주인공', '소방관'],
#  ['개', '짱', '꼭'],
#  ['뭐',
#   '이야기',
#   '자체',
#   '중간',
#   '중간',
#   '뜬금',
#   '장면',
#   '회',
#   '오리',
#   '장면',
#   '땐',
#   '파워레인저',
#   '보나',
#   '확인',
#   '정도',
#   '실감',
#   '개연',
#   '로그',
#   '거',
#   '별개',
#   '배우'],
#  ['작품', '후지', '억지', '신파', '등', '등', '비평', '난', '누룽지', '밥솥'],
#  ['개인', '원작', '만화가', '더', '누룽지', '밥솥', '인상'],
#  ['전', '보고', '배우', '마지막', '눈물', '동연', '움'],
#  ['난', '개인', '별로', '안'],
#  ['만화', '영화', '점', '인', '사람', '화', '안', '봄'],
#  ['작품', '흥행', '거', '보고', '우리나라', '한참', '생각'],
#  ['신', '를', '감독', '포트폴리오', '놈'],
#  ['홍', '다크호스', '눈물샘', '김동욱', '배우', '연기'],
#  ['슬펏어', '스토리', '아이돌', '도', '경수', '연기'],
#  ['누가', '영화', '소릴'],
#  ['원작', '요', '진짜', '별루'],
#  ['신파', '절', '여기', '그냥', '만'],
#  ['개', '쓰레기', '영화', '이동욱', '때', '참고', '신파', '네', '운동장', '토네이도', '경악', '금치'],
#  ['그래픽', '스토리', '정돈'],
#  ['영화', '거'],
#  ['완성', '도', '개연', '성도', '하정우', '연기', '몰입도'],
#  ['눈물', '부분'],
#  ['뭐', '생각', '아이', '눈물', '원작', '안', '원작', '못', '소방관', '가족', '얘기', '개연'],
#  ['노잼'],
#  [],
#  ['김동욱', '배우', '마지막', '장면', '연기력', '최상', '생각', '함', '진짜', '딕션', '감정', '장면'],
#  ['부모님', '살', '때'],
#  ['삶', '죽음', '신', '더'],
#  ['진짜', '몇', '번', '눈물', '안', '영화', '때', '알', '영화'],
#  ['언제', '감동', '적임'],
#  ['걸', '굳이', '돈', '왜', '재미'],
#  ['웹툰', '재밋', '실망'],
#  ['김동욱', '연기', '너', '배우', '연기'],
#  ['김동욱', '님연기', '올해', '눈물', '리', '눈', '퉁퉁', '부어', '출근'],
#  ['내', '인생', '최고', '영화'],
#  ['원작', '만화', '인상', '기대', '배우', '연기', '집중', '김자', '홍', '소방관', '실망'],
#  ['원작', '반도', '못', '영화', '개연', '억지', '감동', '느낌'],
#  ['기대', '이상'],
#  ['인간', '평가', '질'],
#  ['몰입도', '최상', '마지막', '터트려주', '영화', '별', '개'],
#  ['웹툰', '안', '사람', '연기', '스토리'],
#  ['진짜', '거', '쇼맨'],
#  ['이', '천만', '관객'],
#  ['극장', '마지막', '김동욱'],
#  ['침펄', '토론', '낫다', '영화', '보고', '개', '건', '이', '처음'],
#  ['배우', '영화', '감독', '진짜', '반성'],
#  ['김자', '홍', '씨', '부모님', '효도', '정말', '보기', '저', '이제', '어머니', '아버지', '효도'],
#  ['판타지', '블록버스터', '영화', '모성애', '관객', '나라', '한국'],
#  ['인생', '영화'],
#  ['주지훈', '원작', '스토리', '크게', '최소한', '영화'],
#  ['그냥', '우리나라', '퀄', '액션', '판타지', '화일', '뿐', '원작', '감동', '교훈', '작품'],
#  ['본적', '세계', '린다'],
#  [],
#  ['하필', '다크', '나이트', '세', '번', '직후', '영화'],
#  ['지옥', '표현', '하정우', '김동욱', '연기', '정말', '가슴', '린다'],
#  ['차태현', '연기', '진짜', '사도', '티', '노골', '자랑', '마'],
#  ['사람',
#   '생각',
#   '볼',
#   '수',
#   '영화',
#   '영화로',
#   '인간관계',
#   '다시',
#   '생각',
#   '바',
#   '동생',
#   '의',
#   '절',
#   '제',
#   '용서',
#   '다시',
#   '예전',
#   '마음',
#   '부모님',
#   '마음속',
#   '못'],
#  ['중간', '끌', '고민', '마지막'],
#  ['정말',
#   '원작',
#   '장점',
#   '못',
#   '클리셰',
#   '범벅',
#   '억지',
#   '눈물',
#   '구함',
#   '원작',
#   '흥행',
#   '생각',
#   '함',
#   '마지막',
#   '배우',
#   '연기',
#   '정말',
#   '최고',
#   '임',
#   '편',
#   '기승',
#   '전결',
#   '통일',
#   '더'],
#  ['데', '서른', '마흔', '다섯', '번', '한국영', '중', '수작'],
#  ['주지훈',
#   '김향기',
#   '연기',
#   '요',
#   '난',
#   '차태현',
#   '연기',
#   '편',
#   '한번',
#   '편',
#   '때',
#   '기대',
#   '번',
#   '둘'],
#  ['사람',
#   '관점',
#   '거지',
#   '왜',
#   '말',
#   '애',
#   '성공',
#   '못',
#   '거나',
#   '부모님',
#   '돈',
#   '못',
#   '건',
#   '팩트',
#   '듯',
#   '인증',
#   '여'],
#  ['진짜', '이', '극찬', '이해', '원작', '안', '노잼', '억지', '감동'],
#  ['차태현', '아저씨', '연기', '어색'],
#  ['영화', '보고', '욕', '처음', '신파', '집합', '역', '겨움', '관객', '댓글', '답니'],
#  ['원작', '웹툰', '소재', '연출', '소재', '부분', '진짜', '감동', '자체'],
#  ['한국영', '여태', '드라마', '장르', '판타지', '장르'],
#  ['관객',
#   '호소',
#   '게',
#   '감정',
#   '영화',
#   '나름',
#   '마지막',
#   '엔딩',
#   '빛',
#   '번쩍',
#   '거리',
#   '거',
#   '순간',
#   '욕',
#   '최악'],
#  ['원작', '김자', '홍', '회사원', '기선', '소방관'],
#  ['살', '때', '다시', '번', '상기', '산', '수', '부모님', '은혜', '효도'],
#  ['이제', '천만', '이해', '억지', '감성'],
#  ['추석', '특선', '만', '이건', '영화', '진짜'],
#  ['요'],
#  ['기대', '안', '몰입', '봄'],
#  ['소재', '독립영화', '시나리오', '상업', '영화'],
#  ['어머니', '보고', '어머니', '보고', '어머'],
#  ['특선영화',
#   '천만',
#   '영화',
#   '중',
#   '어',
#   '두운',
#   '색채',
#   '듯',
#   '잠깐',
#   '절정',
#   '김동욱',
#   '엄마',
#   '꿈',
#   '씬',
#   '볼',
#   '때',
#   '울',
#   '원작',
#   '파괴',
#   '왕',
#   '주호민',
#   '옹',
#   '생각'],
#  ['마지마씬', '김동욱', '어머니', '하소연', '눈물', '눈물', '나', '게', '정상인', '갱년기'],
#  ['루'],
#  ['와중'],
#  ['원작', '모욕', '수준', '캐릭터', '것', '시작', '함'],
#  ['설', '연휴', '연달', '연', '노잼', '고', '별로', '보고', '동물', '왕국', '중이따뻉반', '겐'],
#  ['집중', '만', '영화인'],
#  ['대중', '영화', '이', '정도'],
#  ['진짜', '감', '함', '데', '진짜', '눈물'],
#  ['걸', '누가', '진심'],
#  ['천만', '게', '신기하', '네', '데'],
#  ['걸', '영화관', '안'],
#  ['연기', '개연', '스토리'],
#  ['영화', '볼', '이유'],
#  ['이',
#   '정말',
#   '진심',
#   '나',
#   '존속살인',
#   '미수',
#   '억지',
#   '눈물',
#   '질질',
#   '연출',
#   '스토리텔링',
#   '포장',
#   '마무리',
#   '관객',
#   '걸',
#   '보고',
#   '감동',
#   '수가'],
#  ['나'],
#  ['신파', '난', '찬성'],
#  ['신', '인간', '진리', '영화'],
#  ['정말', '생각', '영화'],
#  ['점', '시작', '점점', '감점'],
#  ['억지', '감동', '억지', '눈물', '기', '스토리', '전', '개', '원작', '반도', '안', '점', '영화'],
#  [],
#  ['돈', '움', '억지', '눈물', '거부', '감'],
#  ['원작', '안', '보고', '내용', '아쉬웟', '주연', '연기', '한국', '영화', '도전', '이기', '점'],
#  ['평점', '듯', '전개', '신파'],
#  ['난', '지옥', '타'],
#  ['초딩', '점', '영화', '하정우', '못', '개', '실패', '작'],
#  ['내', '여태', '잘못', '계산', '개도', '점도', '점'],
#  ...]

# %% [markdown]
# ### (3) Kkma로 명사 단어 추출

# %%
# 측정 시작
start = time.time()
# 문장 단위로 명사만 추출해 학습 입력 데이터로 만듦
print('형태소에서 명사만 추출 시작')
kkma = Kkma()
kkma_nouns = [kkma.nouns(sentence) for sentence in data['리뷰']]
print('형태소에서 명사만 추출 완료', time.time() - start)
# Out:
# 형태소에서 명사만 추출 시작
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File kr.lucypark.kkma.KkmaInterface.java:-1, in kr.lucypark.kkma.KkmaInterface.extractNoun()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.OutOfMemoryError                Traceback (most recent call last)
# Input In [57], in <cell line: 6>()
#       4 print('형태소에서 명사만 추출 시작')
#       5 kkma = Kkma()
# ----> 6 kkma_nouns = [kkma.nouns(sentence) for sentence in data['리뷰']]
#       7 print('형태소에서 명사만 추출 완료', time.time() - start)
#
# Input In [57], in <listcomp>(.0)
#       4 print('형태소에서 명사만 추출 시작')
#       5 kkma = Kkma()
# ----> 6 kkma_nouns = [kkma.nouns(sentence) for sentence in data['리뷰']]
#       7 print('형태소에서 명사만 추출 완료', time.time() - start)
#
# File ~\anaconda3\envs\nlp_py38\lib\site-packages\konlpy\tag\_kkma.py:54, in Kkma.nouns(self, phrase)
#      51 def nouns(self, phrase):
#      52     """Noun extractor."""
# ---> 54     nouns = self.jki.extractNoun(phrase)
#      55     if not nouns: return []
#      56     return [nouns.get(i).getString() for i in range(nouns.size())]
#
# java.lang.OutOfMemoryError: java.lang.OutOfMemoryError: Java heap space

# %% [markdown]
# ### (4) Word2Vec 모델

# %% [markdown]
# #### 1) 학습

# %%
data['리뷰'].unique()
# Out:
# array(['여기에 말같잖은 평다는 놈들은 매국노 인증인 듯', '다 좋았어요 한산보고 나서 보니 더 좋네요',
#        '2번째 본 역사영화 진짜 이순신은 대단한 영웅 중에 영웅보는 내내 끝까지 긴장 놓을 수 없고 이순신이란 인물이 정말 대단한 영웅임',
#        ..., '나도 멘토가 있었다면', '가장 이상적인 한국형 성장드라마', '멋진 조화사회 문제를 영화에 담아내긴 했다'],
#       dtype=object)

# %%
start = time.time()
# word2vec 모델 학습
print('word2vec 모델 학습 시작')
model = Word2Vec(sentences=texts, vector_size=200, window=4, min_count=1, sg=1)
# skip-gram, window size=4, 벡터 크기 : 200, 최소 2번 이상 발생 단어만 학습
print('word2vec 모델 학습 완료: ', time.time() - start)
# Out:
# word2vec 모델 학습 시작
# word2vec 모델 학습 완료:  21.269087076187134

# %%
model.wv.most_similar('영화')
# Out:
# [('화영', 0.8448615670204163),
#  ('역사영화', 0.7615429162979126),
#  ('화기', 0.758078932762146),
#  ('대작', 0.754793643951416),
#  ('공포영화', 0.7490036487579346),
#  ('화란', 0.7481001615524292),
#  ('만화영화', 0.7445890307426453),
#  ('인건', 0.7434040307998657),
#  ('명화', 0.7412079572677612),
#  ('화이자', 0.7399641275405884)]

# %%
start = time.time()
# word2vec 모델 학습
print('word2vec 모델 학습 시작')
model = Word2Vec(sentences=okt_nouns, vector_size=200, window=4, min_count=2, sg=1)
# skip-gram, window size=4, 벡터 크기 : 200, 최소 2번 이상 발생 단어만 학습
print('word2vec 모델 학습 완료: ', time.time() - start)
# Out:
# word2vec 모델 학습 시작
# word2vec 모델 학습 완료:  7.731443643569946

# %%
model.wv.vectors.shape
# Out:
# (15815, 200)

# %% [markdown]
# #### 2) 저장

# %%
start = time.time()
# 모델 저장
print('학습된 모델 저장 시작')
model.save('./data/okt_nouns.model')     
print('학습된 모델 저장 완료: ', time.time() - start)
# Out:
# 학습된 모델 저장 시작
# 학습된 모델 저장 완료:  0.49311113357543945

# %% [markdown]
# #### 3) 모델 load

# %%
from gensim.models import Word2Vec
# 모델 로딩
model = Word2Vec.load('./data/okt_nouns.model')
model.corpus_total_words
# Out:
# 735777

# %% [markdown]
# ### (4) 단어 유사도 (코사인 유사도)

# %%
# 단어 유사도 계산 (코사인 유사도 기준)
model.wv.similarity(w1='영화', w2='어벤저스')
# Out:
# 0.47109693

# %%
model.wv.similarity(w1='배우', w2='내공')
# Out:
# 0.7428517

# %%
model.wv.most_similar('배우')
# Out:
# [('연기자', 0.8664340376853943),
#  ('조연', 0.7954868078231812),
#  ('배역', 0.7825795412063599),
#  ('주연', 0.748223602771759),
#  ('명품', 0.7479346990585327),
#  ('호흡', 0.744335412979126),
#  ('내공', 0.7428516745567322),
#  ('신인', 0.7415962219238281),
#  ('한몫', 0.7384046316146851),
#  ('궁합', 0.7381974458694458)]
