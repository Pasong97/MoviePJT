# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from konlpy.tag import Okt
from konlpy.tag import Kkma

# %%
data = pd.read_csv('d:/data/project/data/review_data_daum.csv')
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#       movie                                             review  score
# 0        명량              정말 끝내주는 영화네요.한국영화 많이 보는 내가 이걸 인제 봤다니ㅎ     10
# 1        명량                            한산보기전 다시 봤는데 역시 재미있네요!!     10
# 2        명량  명량\n실제로 거북선 불타지 않았구요 배설 해전 후에 죽었구요\n해전에서 백병전이다...      6
# 3        명량                                       명량해전 하나만 좋았다      6
# 4        명량  한산보고 궁금해서봤는데 명량이확실히 스토리도탄탄하고 전투씬도더박진감넘치고리얼하네요\...      8
# ...     ...                                                ...    ...
# 40431   완득이                                            재미나게봤어요     10
# 40432   완득이  자연스런 전개 속에 다문화가정의 소시민적인 삶을 잘 담아냈당.ㅋ 유머도 너무재밌고 ...     10
# 40433   완득이  높은 평점때문에 엄청 수작일꺼라 생각했는데.. 기대치에 한참 못미쳤음; \n그래도 ...      7
# 40434   완득이                          웃겨욬ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ     10
# 40435   완득이                오랜만에 가슴따뜻해지는 제대로된 영화를 본것같아 너무 좋았음.      10
#
# [40436 rows x 3 columns]

# %% [markdown]
# ### 리뷰 길이 및 단어수 파악

# %%
plt.rc('font', family='NanumGothic')

# %%
# 통계 나타내주는 함수
def summary_stats(*series, labels):
    summary = [s.describe() for s in series]
    
    return pd.concat(summary, axis=1, keys=labels)

# 통계 히스토그램, 상자그림 함수
def review_plots(*series, labels):
    nc = int(len(series))
    fig, ax = plt.subplots(nrows=2, ncols=nc, figsize=(10*nc/2, 10))
    
    for i in range(nc):
        ax[0, i].hist(series[i], bins=50)
        ax[0, i].set_title(f'{labels[i]} 히스토그램', size=15)
        
        ax[1, i].boxplot(series[i], vert=False)
        ax[1, i].set_title(f'{labels[i]} 상자그림', size=15)
        ax[1, i].set_xlabel(labels[i])
    
    return ax

# %%
review_len = data['review'].apply(len)
review_words = data['review'].apply(lambda x: len(x.split()))

# %% [markdown]
# ### (1) 통계

# %%
summary_stats(review_len, review_words, labels=['리뷰 길이', '리뷰 당 단어 수'])
# Out:
#               리뷰 길이     리뷰 당 단어 수
# count  40436.000000  40436.000000
# mean      48.467974     10.836779
# std       53.305783     11.991989
# min        2.000000      0.000000
# 25%       14.000000      3.000000
# 50%       30.000000      7.000000
# 75%       63.000000     14.000000
# max      400.000000    115.000000

# %% [markdown]
# ### (2) 그래프

# %%
review_plots(review_len, review_words, labels=['리뷰 길이', '리뷰 당 단어 수'])
# Out:
# array([[<AxesSubplot: title={'center': '리뷰 길이 히스토그램'}>,
#         <AxesSubplot: title={'center': '리뷰 당 단어 수 히스토그램'}>],
#        [<AxesSubplot: title={'center': '리뷰 길이 상자그림'}, xlabel='리뷰 길이'>,
#         <AxesSubplot: title={'center': '리뷰 당 단어 수 상자그림'}, xlabel='리뷰 당 단어 수'>]],
#       dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 전처리 (Preprocessing)
#
# - 데이터 분석과정을 바탕으로 데이터를 모델에 적용시키기 위해 전처리 과정을 진행한다.

# %%
import re
import json
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
data
# Out:
#       movie                                             review  score
# 0        명량              정말 끝내주는 영화네요.한국영화 많이 보는 내가 이걸 인제 봤다니ㅎ     10
# 1        명량                            한산보기전 다시 봤는데 역시 재미있네요!!     10
# 2        명량  명량\n실제로 거북선 불타지 않았구요 배설 해전 후에 죽었구요\n해전에서 백병전이다...      6
# 3        명량                                       명량해전 하나만 좋았다      6
# 4        명량  한산보고 궁금해서봤는데 명량이확실히 스토리도탄탄하고 전투씬도더박진감넘치고리얼하네요\...      8
# ...     ...                                                ...    ...
# 40431   완득이                                            재미나게봤어요     10
# 40432   완득이  자연스런 전개 속에 다문화가정의 소시민적인 삶을 잘 담아냈당.ㅋ 유머도 너무재밌고 ...     10
# 40433   완득이  높은 평점때문에 엄청 수작일꺼라 생각했는데.. 기대치에 한참 못미쳤음; \n그래도 ...      7
# 40434   완득이                          웃겨욬ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ     10
# 40435   완득이                오랜만에 가슴따뜻해지는 제대로된 영화를 본것같아 너무 좋았음.      10
#
# [40436 rows x 3 columns]

# %%
## 문장 하나를 가져오기
review = data['review'][0]
review
# Out:
# '정말 끝내주는 영화네요.한국영화 많이 보는 내가 이걸 인제 봤다니ㅎ'

# %% [markdown]
# #### (1) 한글을 제외한 나머지는 모두 공백처리 - 정규표현식
# * 구두점, 물음표, 따옴표 등등 사라짐

# %%
review_text = re.sub('[^ㄱ-ㅎ가-힣0-9]', ' ', review)      # 한글, 숫자 아닌것들은 공백으로 표시
review_text
# Out:
# '정말 끝내주는 영화네요 한국영화 많이 보는 내가 이걸 인제 봤다니ㅎ'

# %% [markdown]
# #### (2) split 메소드로 단어 분리

# %%
words = review_text.split()    # 단어 리스트
print(words)
# Out:
# ['정말', '끝내주는', '영화네요', '한국영화', '많이', '보는', '내가', '이걸', '인제', '봤다니ㅎ']

# %% [markdown]
# #### (3) 한글 불용어 데이터 가져옴 (stopwords-ko.txt)

# %%
stopwords_data = pd.read_table('d:/data/project/data/stopwords-ko.txt')
s_words = stopwords_data['가'].tolist()
len(s_words), s_words
# Out:
# (594,
#  ['가까스로',
#   '가령',
#   '각',
#   '각각',
#   '각자',
#   '각종',
#   '갖고말하자면',
#   '같다',
#   '같이',
#   '개의치않고',
#   '거니와',
#   '거바',
#   '거의',
#   '것',
#   '것과 같이',
#   '것들',
#   '게다가',
#   '게우다',
#   '겨우',
#   '견지에서',
#   '결과에 이르다',
#   '결국',
#   '결론을 낼 수 있다',
#   '겸사겸사',
#   '고려하면',
#   '고로',
#   '곧',
#   '공동으로',
#   '과',
#   '과연',
#   '관계가 있다',
#   '관계없이',
#   '관련이 있다',
#   '관하여',
#   '관한',
#   '관해서는',
#   '구',
#   '구체적으로',
#   '구토하다',
#   '그',
#   '그들',
#   '그때',
#   '그래',
#   '그래도',
#   '그래서',
#   '그러나',
#   '그러니',
#   '그러니까',
#   '그러면',
#   '그러므로',
#   '그러한즉',
#   '그런 까닭에',
#   '그런데',
#   '그런즉',
#   '그럼',
#   '그럼에도 불구하고',
#   '그렇게 함으로써',
#   '그렇지',
#   '그렇지 않다면',
#   '그렇지 않으면',
#   '그렇지만',
#   '그렇지않으면',
#   '그리고',
#   '그리하여',
#   '그만이다',
#   '그에 따르는',
#   '그위에',
#   '그저',
#   '그중에서',
#   '그치지 않다',
#   '근거로',
#   '근거하여',
#   '기대여',
#   '기점으로',
#   '기준으로',
#   '기타',
#   '까닭으로',
#   '까악',
#   '까지',
#   '까지 미치다',
#   '까지도',
#   '꽈당',
#   '끙끙',
#   '끼익',
#   '나',
#   '나머지는',
#   '남들',
#   '남짓',
#   '너',
#   '너희',
#   '너희들',
#   '네',
#   '넷',
#   '년',
#   '논하지 않다',
#   '놀라다',
#   '누가 알겠는가',
#   '누구',
#   '다른',
#   '다른 방면으로',
#   '다만',
#   '다섯',
#   '다소',
#   '다수',
#   '다시 말하자면',
#   '다시말하면',
#   '다음',
#   '다음에',
#   '다음으로',
#   '단지',
#   '답다',
#   '당신',
#   '당장',
#   '대로 하다',
#   '대하면',
#   '대하여',
#   '대해 말하자면',
#   '대해서',
#   '댕그',
#   '더구나',
#   '더군다나',
#   '더라도',
#   '더불어',
#   '더욱더',
#   '더욱이는',
#   '도달하다',
#   '도착하다',
#   '동시에',
#   '동안',
#   '된바에야',
#   '된이상',
#   '두번째로',
#   '둘',
#   '둥둥',
#   '뒤따라',
#   '뒤이어',
#   '든간에',
#   '들',
#   '등',
#   '등등',
#   '딩동',
#   '따라',
#   '따라서',
#   '따위',
#   '따지지 않다',
#   '딱',
#   '때',
#   '때가 되어',
#   '때문에',
#   '또',
#   '또한',
#   '뚝뚝',
#   '라 해도',
#   '령',
#   '로',
#   '로 인하여',
#   '로부터',
#   '로써',
#   '륙',
#   '를',
#   '마음대로',
#   '마저',
#   '마저도',
#   '마치',
#   '막론하고',
#   '만 못하다',
#   '만약',
#   '만약에',
#   '만은 아니다',
#   '만이 아니다',
#   '만일',
#   '만큼',
#   '말하자면',
#   '말할것도 없고',
#   '매',
#   '매번',
#   '메쓰겁다',
#   '몇',
#   '모',
#   '모두',
#   '무렵',
#   '무릎쓰고',
#   '무슨',
#   '무엇',
#   '무엇때문에',
#   '물론',
#   '및',
#   '바꾸어말하면',
#   '바꾸어말하자면',
#   '바꾸어서 말하면',
#   '바꾸어서 한다면',
#   '바꿔 말하면',
#   '바로',
#   '바와같이',
#   '밖에 안된다',
#   '반대로',
#   '반대로 말하자면',
#   '반드시',
#   '버금',
#   '보는데서',
#   '보다더',
#   '보드득',
#   '본대로',
#   '봐',
#   '봐라',
#   '부류의 사람들',
#   '부터',
#   '불구하고',
#   '불문하고',
#   '붕붕',
#   '비걱거리다',
#   '비교적',
#   '비길수 없다',
#   '비로소',
#   '비록',
#   '비슷하다',
#   '비추어 보아',
#   '비하면',
#   '뿐만 아니라',
#   '뿐만아니라',
#   '뿐이다',
#   '삐걱',
#   '삐걱거리다',
#   '사',
#   '삼',
#   '상대적으로 말하자면',
#   '생각한대로',
#   '설령',
#   '설마',
#   '설사',
#   '셋',
#   '소생',
#   '소인',
#   '솨',
#   '쉿',
#   '습니까',
#   '습니다',
#   '시각',
#   '시간',
#   '시작하여',
#   '시초에',
#   '시키다',
#   '실로',
#   '심지어',
#   '아',
#   '아니',
#   '아니나다를가',
#   '아니라면',
#   '아니면',
#   '아니었다면',
#   '아래윗',
#   '아무거나',
#   '아무도',
#   '아야',
#   '아울러',
#   '아이',
#   '아이고',
#   '아이구',
#   '아이야',
#   '아이쿠',
#   '아하',
#   '아홉',
#   '안 그러면',
#   '않기 위하여',
#   '않기 위해서',
#   '알 수 있다',
#   '알았어',
#   '앗',
#   '앞에서',
#   '앞의것',
#   '야',
#   '약간',
#   '양자',
#   '어',
#   '어기여차',
#   '어느',
#   '어느 년도',
#   '어느것',
#   '어느곳',
#   '어느때',
#   '어느쪽',
#   '어느해',
#   '어디',
#   '어때',
#   '어떠한',
#   '어떤',
#   '어떤것',
#   '어떤것들',
#   '어떻게',
#   '어떻해',
#   '어이',
#   '어째서',
#   '어쨋든',
#   '어쩔수 없다',
#   '어찌',
#   '어찌됏든',
#   '어찌됏어',
#   '어찌하든지',
#   '어찌하여',
#   '언제',
#   '언젠가',
#   '얼마',
#   '얼마 안 되는 것',
#   '얼마간',
#   '얼마나',
#   '얼마든지',
#   '얼마만큼',
#   '얼마큼',
#   '엉엉',
#   '에',
#   '에 가서',
#   '에 달려 있다',
#   '에 대해',
#   '에 있다',
#   '에 한하다',
#   '에게',
#   '에서',
#   '여',
#   '여기',
#   '여덟',
#   '여러분',
#   '여보시오',
#   '여부',
#   '여섯',
#   '여전히',
#   '여차',
#   '연관되다',
#   '연이서',
#   '영',
#   '영차',
#   '옆사람',
#   '예',
#   '예를 들면',
#   '예를 들자면',
#   '예컨대',
#   '예하면',
#   '오',
#   '오로지',
#   '오르다',
#   '오자마자',
#   '오직',
#   '오호',
#   '오히려',
#   '와',
#   '와 같은 사람들',
#   '와르르',
#   '와아',
#   '왜',
#   '왜냐하면',
#   '외에도',
#   '요만큼',
#   '요만한 것',
#   '요만한걸',
#   '요컨대',
#   '우르르',
#   '우리',
#   '우리들',
#   '우선',
#   '우에 종합한것과같이',
#   '운운',
#   '월',
#   '위에서 서술한바와같이',
#   '위하여',
#   '위해서',
#   '윙윙',
#   '육',
#   '으로',
#   '으로 인하여',
#   '으로서',
#   '으로써',
#   '을',
#   '응',
#   '응당',
#   '의',
#   '의거하여',
#   '의지하여',
#   '의해',
#   '의해되다',
#   '의해서',
#   '이',
#   '이 되다',
#   '이 때문에',
#   '이 밖에',
#   '이 외에',
#   '이 정도의',
#   '이것',
#   '이곳',
#   '이때',
#   '이라면',
#   '이래',
#   '이러이러하다',
#   '이러한',
#   '이런',
#   '이럴정도로',
#   '이렇게 많은 것',
#   '이렇게되면',
#   '이렇게말하자면',
#   '이렇구나',
#   '이로 인하여',
#   '이르기까지',
#   '이리하여',
#   '이만큼',
#   '이번',
#   '이봐',
#   '이상',
#   '이어서',
#   '이었다',
#   '이와 같다',
#   '이와 같은',
#   '이와 반대로',
#   '이와같다면',
#   '이외에도',
#   '이용하여',
#   '이유만으로',
#   '이젠',
#   '이지만',
#   '이쪽',
#   '이천구',
#   '이천육',
#   '이천칠',
#   '이천팔',
#   '인 듯하다',
#   '인젠',
#   '일',
#   '일것이다',
#   '일곱',
#   '일단',
#   '일때',
#   '일반적으로',
#   '일지라도',
#   '임에 틀림없다',
#   '입각하여',
#   '입장에서',
#   '잇따라',
#   '있다',
#   '자',
#   '자기',
#   '자기집',
#   '자마자',
#   '자신',
#   '잠깐',
#   '잠시',
#   '저',
#   '저것',
#   '저것만큼',
#   '저기',
#   '저쪽',
#   '저희',
#   '전부',
#   '전자',
#   '전후',
#   '점에서 보아',
#   '정도에 이르다',
#   '제',
#   '제각기',
#   '제외하고',
#   '조금',
#   '조차',
#   '조차도',
#   '졸졸',
#   '좀',
#   '좋아',
#   '좍좍',
#   '주룩주룩',
#   '주저하지 않고',
#   '줄은 몰랏다',
#   '줄은모른다',
#   '중에서',
#   '중의하나',
#   '즈음하여',
#   '즉',
#   '즉시',
#   '지든지',
#   '지만',
#   '지말고',
#   '진짜로',
#   '쪽으로',
#   '차라리',
#   '참',
#   '참나',
#   '첫번째로',
#   '쳇',
#   '총적으로',
#   '총적으로 말하면',
#   '총적으로 보면',
#   '칠',
#   '콸콸',
#   '쾅쾅',
#   '쿵',
#   '타다',
#   '타인',
#   '탕탕',
#   '토하다',
#   '통하여',
#   '툭',
#   '퉤',
#   '틈타',
#   '팍',
#   '팔',
#   '퍽',
#   '펄렁',
#   '하',
#   '하게될것이다',
#   '하게하다',
#   '하겠는가',
#   '하고 있다',
#   '하고있었다',
#   '하곤하였다',
#   '하구나',
#   '하기 때문에',
#   '하기 위하여',
#   '하기는한데',
#   '하기만 하면',
#   '하기보다는',
#   '하기에',
#   '하나',
#   '하느니',
#   '하는 김에',
#   '하는 편이 낫다',
#   '하는것도',
#   '하는것만 못하다',
#   '하는것이 낫다',
#   '하는바',
#   '하더라도',
#   '하도다',
#   '하도록시키다',
#   '하도록하다',
#   '하든지',
#   '하려고하다',
#   '하마터면',
#   '하면 할수록',
#   '하면된다',
#   '하면서',
#   '하물며',
#   '하여금',
#   '하여야',
#   '하자마자',
#   '하지 않는다면',
#   '하지 않도록',
#   '하지마',
#   '하지마라',
#   '하지만',
#   '하하',
#   '한 까닭에',
#   '한 이유는',
#   '한 후',
#   '한다면',
#   '한다면 몰라도',
#   '한데',
#   '한마디',
#   '한적이있다',
#   '한켠으로는',
#   '한항목',
#   '할 따름이다',
#   '할 생각이다',
#   '할 줄 안다',
#   '할 지경이다',
#   '할 힘이 있다',
#   '할때',
#   '할만하다',
#   '할망정',
#   '할뿐',
#   '할수있다',
#   '할수있어',
#   '할줄알다',
#   '할지라도',
#   '할지언정',
#   '함께',
#   '해도된다',
#   '해도좋다',
#   '해봐요',
#   '해서는 안된다',
#   '해야한다',
#   '해요',
#   '했어요',
#   '향하다',
#   '향하여',
#   '향해서',
#   '허',
#   '허걱',
#   '허허',
#   '헉',
#   '헉헉',
#   '헐떡헐떡',
#   '형식으로 쓰여',
#   '혹시',
#   '혹은',
#   '혼자',
#   '훨씬',
#   '휘익',
#   '휴',
#   '흐흐',
#   '흥',
#   '힘입어'])

# %% [markdown]
# #### (4) 불용어 제거

# %%
words = [w for w in words if not w in s_words]
print(len(words), words)
# Out:
# 10 ['정말', '끝내주는', '영화네요', '한국영화', '많이', '보는', '내가', '이걸', '인제', '봤다니ㅎ']

# %% [markdown]
# #### (5) 단어 리스트를 다시 하나의 글로 합치기 (데이터 정제)

# %%
clean_review = ' '.join(words)
len(clean_review), clean_review
# Out:
# (37, '정말 끝내주는 영화네요 한국영화 많이 보는 내가 이걸 인제 봤다니ㅎ')

# %% [markdown]
# #### (6) PyKoSpacing(올바르게 띄어쓰기 하기)

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\win10\appdata\local\temp\pip-req-build-ci114w2o
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit 1f8d11c59ac93525432f164e4c237ece4e298691
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tensorflow==2.9.3
#   Using cached tensorflow-2.9.3-cp38-cp38-win_amd64.whl (444.1 MB)
# Requirement already satisfied: h5py==3.1.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from pykospacing==0.5) (3.1.0)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from h5py==3.1.0->pykospacing==0.5) (1.23.4)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (3.7.4.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (1.50.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (1.12.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (1.12)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (1.1.2)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (0.29.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (1.15.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (14.0.6)
# Collecting tensorboard<2.10,>=2.9
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (3.19.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (65.5.0)
# Requirement already satisfied: packaging in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorflow==2.9.3->pykospacing==0.5) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.9.3->pykospacing==0.5) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (2.14.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from packaging->tensorflow==2.9.3->pykospacing==0.5) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (5.0.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (1.26.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.3->pykospacing==0.5) (3.2.2)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py): started
#   Building wheel for pykospacing (setup.py): finished with status 'done'
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2268651 sha256=49e55bbb56944a58f180f20990821b93f167d83ac77b7534729211fcd6d5d6d4
#   Stored in directory: C:\Users\WIN10\AppData\Local\Temp\pip-ephem-wheel-cache-4xp5mum6\wheels\79\a0\33\16f2cd03d21f76a663f5d69a0b96f0351335385349136fbd03
# Successfully built pykospacing
# Installing collected packages: argparse, absl-py, tensorboard, tensorflow, pykospacing
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.15.0
#     Uninstalling absl-py-0.15.0:
#       Successfully uninstalled absl-py-0.15.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.0
#     Uninstalling tensorboard-2.11.0:
#       Successfully uninstalled tensorboard-2.11.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.6.0
#     Uninstalling tensorflow-2.6.0:
#       Successfully uninstalled tensorflow-2.6.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\WIN10\AppData\Local\Temp\pip-req-build-ci114w2o'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\WIN10\\anaconda3\\envs\\nlp_py38\\Lib\\site-packages\\~ensorflow\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\win10\anaconda3\envs\nlp_py38\lib\site-packages)

# %%
from pykospacing import Spacing

spacing = Spacing()

# 띄어쓰기 없애기
review = clean_review.replace(" ", "")

# 띄어쓰기 변환
new_review = spacing(review)
    
print(new_review)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 정말 끝내주는 영화네요한국 영화 많이 보는 내가 이걸 인제 봤다니ㅎ

# %%
clean_review
# Out:
# '정말 끝내주는 영화네요 한국영화 많이 보는 내가 이걸 인제 봤다니ㅎ'

# %% [markdown]
# #### 위의 과정을 모두 통합

# %%
#################### 과정 정리 #############################
review = data['review'][5]
remove_stopwords = True    ## option
print("<before>\n", review)  

# 1. 한글, 숫자 아닌 특수문자들을 공백(" ")으로 바꾸기
review_text = re.sub("[^ㄱ-ㅎ가-힣0-9]", " ", review)

# 2. 공백단위로 텍스트를 나눠서 리스트로 만든다.
words = review_text.split() 

# 3. 불용어 데이터 가져오기
stopwords_data = pd.read_table('d:/data/project/data/stopwords-ko.txt')
s_words = stopwords_data['가'].tolist()

# 4. 불용어 제거 (불용어가 아닌 단어들로 이루어진 새로운 리스트 생성)
words = [w for w in words if not w in s_words]

# 5. 단어 리스트를 공백을 넣어서 하나의 글로 합친다.
clean_review = ' '.join(words)

# 6. 올바른 띄어쓰기
spacing = Spacing()

# 띄어쓰기 없애기
review = clean_review.replace(" ", "")

# 띄어쓰기 변환
clean_review = spacing(review)

print('\n<after>\n', clean_review)
# Out:
# <before>
#  개인적인 생각이자 바람이지만 노량이 끝난 후에 명량을 전체적으로 손보는 투자가 있기를 희망합니다
# 한산, 노량과 비슷하게 편집을 하고 특수효과도 스타워즈의 사례같이 대대적으로 손보았으면 좋겠습니다
# 8년이라는 시간이 지났는데 최근에 다시 보니 한산에 비해 부족한 부분이 너무 많아서 아쉽습니다
# 명량 VFX 제작진과 배급사나 투자 주체에 따른 이해관계 때문에 못할 가능성도 있겠지만
# 한산과 노량을 제작하면서 시각효과에 쌓인 데이터들을 명량에도 연속해 3부작이 연결됐으면 좋겠네요
# 일본군들의 일본어도 일본 성우들에 의해 정확하게 발음될 수 있도록 일본 DVD판 오디오로 교체했으면 하고
# 이런 여러 가지 부분들을 크게 개선하도록 빅스톤에서 투자해서 재작업에 가까운 결정을 해줬으면 좋겠습니다
# 꿈 같은 일이지만 써봅니다 ^^
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
#
# <after>
#  개인적인 생각이자 바람이지만 노량이 끝난 후에 명량을 전체적으로 손보는 투자가 있기를 희망합니다 한산노량과 비슷하게 편집을 하고 특수효과도 스타워즈의 사례같이 대대적으로 손보았으면 좋겠습니다 8년이라는 시간이 지났는데 최근에 다시 보니 한 산에 비해 부족한 부분이 너무 많아서 아쉽습니다 명량 제작진과 배급사나 투자주체에 따른 이해관계 못할 가능성도 있겠지만 한산과 노량을 제작하면서 시각 효과에 쌓인데이터들을 명량에도 연속해 3부작이 연결됐으면 좋겠네 요일본군들의 일본어도 일본 성우들에 정확하게 발음될 수 있도록 일본판 오디오로 교체했으면 하고 여러 가지 부분들을 크게 개선하도록 빅스톤에서 투자해서 재작업에 가까운 결정을 해줬으면 좋겠습니다 꿈같은 일이지만 써봅니다

# %% [markdown]
# ### 하나의 함수로 정의

# %%
#################### 함수 #############################
def preprocessing(review, remove_stopwords=True):  # 불용어 제거 : option  
    # 1. 한글, 숫자가 아닌 특수문자들을 공백(" ")으로 바꾸기
    review_text = re.sub("[^ㄱ-ㅎ가-힣0-9]", " ", review)

    # 2. 공백단위로 텍스트들 나눠서 리스트로 만든다.
    words = review_text.split()

    # 3. 불용어 데이터 가져오기
    stopwords_data = pd.read_table('d:/data/project/data/stopwords-ko.txt')
    s_words = stopwords_data['가'].tolist()
    
    # 4. 불용어들을 제거
    # 불용어가 아닌 단어들로 이루어진 새로운 리스트 생성 ????
    words = [w for w in words if not w in s_words]

    # 5. 단어 리스트를 공백을 넣어서 하나의 글로 합친다.
    clean_review = ' '.join(words)
    
    # 6. 올바른 띄어쓰기 만들기
    spacing = Spacing()
         
    # 띄어쓰기 없애기
    clean_review = clean_review.replace(" ", "")

    # 띄어쓰기 변환
    clean_review = spacing(clean_review)
        
    return clean_review

# %% [markdown]
# ### 모든 리뷰에 전처리 함수 적용

# %%
data['review'][:5]
# Out:
# 0                정말 끝내주는 영화네요.한국영화 많이 보는 내가 이걸 인제 봤다니ㅎ
# 1                              한산보기전 다시 봤는데 역시 재미있네요!!
# 2    명량\n실제로 거북선 불타지 않았구요 배설 해전 후에 죽었구요\n해전에서 백병전이다...
# 3                                         명량해전 하나만 좋았다
# 4    한산보고 궁금해서봤는데 명량이확실히 스토리도탄탄하고 전투씬도더박진감넘치고리얼하네요\...
# Name: review, dtype: object

# %%
# %%time
reviews = data['review']
clean_train_reviews = []
cnt = 0
for review in reviews:
    clean_train_reviews.append(preprocessing(review, remove_stopwords = True))
    cnt += 1
    print(cnt,'/','40436')

# 전처리한 데이터 출력
clean_train_reviews[:10]
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 2 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 3 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 4 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 5 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 6 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 7 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 8 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 9 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 10 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 11 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 12 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 13 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 14 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 15 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 16 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 17 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 18 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 19 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 20 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 21 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 22 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 23 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 24 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 25 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 26 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 27 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 28 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 29 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 30 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 31 / 40436
# 1/1 [==============================] - 0s 41ms/step
# 32 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 33 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 34 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 35 / 40436
# 1/1 [==============================] - 0s 42ms/step
# 36 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 37 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 38 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 39 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 41 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 42 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 43 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 44 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 45 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 46 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 47 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 48 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 49 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 50 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 51 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 52 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 53 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 54 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 55 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 56 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 57 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 58 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 59 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 60 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 61 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 62 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 63 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 64 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 65 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 66 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 67 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 68 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 69 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 70 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 71 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 72 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 73 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 74 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 75 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 76 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 77 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 78 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 79 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 80 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 81 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 82 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 83 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 84 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 85 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 86 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 87 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 88 / 40436
# 1/1 [==============================] - 0s 34ms/step
# 89 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 90 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 91 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 92 / 40436
# 1/1 [==============================] - 0s 34ms/step
# 93 / 40436
# 1/1 [==============================] - 0s 59ms/step
# 94 / 40436
# 1/1 [==============================] - 0s 40ms/step
# 95 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 96 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 97 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 98 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 99 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 100 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 101 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 102 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 103 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 104 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 105 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 106 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 107 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 108 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 109 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 110 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 111 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 112 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 113 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 114 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 115 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 116 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 117 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 118 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 119 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 120 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 121 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 122 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 123 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 124 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 125 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 126 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 127 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 128 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 129 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 130 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 131 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 132 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 133 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 134 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 135 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 136 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 137 / 40436
# 1/1 [==============================] - 0s 57ms/step
# 138 / 40436
# 1/1 [==============================] - 0s 39ms/step
# 139 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 140 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 141 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 142 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 143 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 144 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 145 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 146 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 147 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 148 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 149 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 150 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 151 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 152 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 153 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 154 / 40436
# 1/1 [==============================] - 0s 33ms/step
# 155 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 156 / 40436
# 1/1 [==============================] - 0s 37ms/step
# 157 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 158 / 40436
# 1/1 [==============================] - 0s 33ms/step
# 159 / 40436
# 1/1 [==============================] - 0s 37ms/step
# 160 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 161 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 162 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 163 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 164 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 165 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 166 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 167 / 40436
# 1/1 [==============================] - 0s 36ms/step
# 168 / 40436
# 1/1 [==============================] - 0s 40ms/step
# 169 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 170 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 171 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 172 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 173 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 174 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 175 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 176 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 177 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 178 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 179 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 180 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 181 / 40436
# 1/1 [==============================] - 0s 35ms/step
# 182 / 40436
# 1/1 [==============================] - 0s 37ms/step
# 183 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 184 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 185 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 186 / 40436
# 1/1 [==============================] - 0s 33ms/step
# 187 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 188 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 189 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 190 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 191 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 192 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 193 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 194 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 195 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 196 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 197 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 198 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 199 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 200 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 201 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 202 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 203 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 204 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 205 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 206 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 207 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 208 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 209 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 210 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 211 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 212 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 213 / 40436
# 1/1 [==============================] - 0s 33ms/step
# 214 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 215 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 216 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 217 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 218 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 219 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 220 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 221 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 222 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 223 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 224 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 225 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 226 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 227 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 228 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 229 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 230 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 231 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 232 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 233 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 234 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 235 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 236 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 237 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 238 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 239 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 240 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 241 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 242 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 243 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 244 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 245 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 246 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 247 / 40436
# 1/1 [==============================] - 0s 35ms/step
# 248 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 249 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 250 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 251 / 40436
# 1/1 [==============================] - 0s 31ms/step
# 252 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 253 / 40436
# 1/1 [==============================] - 0s 31ms/step
# 254 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 255 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 256 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 257 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 258 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 259 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 260 / 40436
# 1/1 [==============================] - 0s 41ms/step
# 261 / 40436
# 1/1 [==============================] - 0s 52ms/step
# 262 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 263 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 264 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 265 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 266 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 267 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 268 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 269 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 270 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 271 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 272 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 273 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 274 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 275 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 276 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 277 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 278 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 279 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 280 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 281 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 282 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 283 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 284 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 285 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 286 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 287 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 288 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 289 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 290 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 291 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 292 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 293 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 294 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 295 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 296 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 297 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 298 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 299 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 300 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 301 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 302 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 303 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 304 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 305 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 306 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 307 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 308 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 309 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 310 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 311 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 312 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 313 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 314 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 315 / 40436
# 1/1 [==============================] - 0s 33ms/step
# 316 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 317 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 318 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 319 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 320 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 321 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 322 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 323 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 324 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 325 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 326 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 327 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 328 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 329 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 330 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 331 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 332 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 333 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 334 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 335 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 336 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 337 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 338 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 339 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 340 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 341 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 342 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 343 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 344 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 345 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 346 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 347 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 348 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 349 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 350 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 351 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 352 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 353 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 354 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 355 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 356 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 357 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 358 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 359 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 360 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 361 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 362 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 363 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 364 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 365 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 366 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 367 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 368 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 369 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 370 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 371 / 40436
# 1/1 [==============================] - 0s 33ms/step
# 372 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 373 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 374 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 375 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 376 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 377 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 378 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 379 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 380 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 381 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 382 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 383 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 384 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 385 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 386 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 387 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 388 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 389 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 390 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 391 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 392 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 393 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 394 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 395 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 396 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 397 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 398 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 399 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 400 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 401 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 402 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 403 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 404 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 405 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 406 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 407 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 408 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 409 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 410 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 411 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 412 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 413 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 414 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 415 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 416 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 417 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 418 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 419 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 420 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 421 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 422 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 423 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 424 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 425 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 426 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 427 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 428 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 429 / 40436
# 1/1 [==============================] - 0s 34ms/step
# 430 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 431 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 432 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 433 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 434 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 435 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 436 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 437 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 438 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 439 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 440 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 441 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 442 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 443 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 444 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 445 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 446 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 447 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 448 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 449 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 450 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 451 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 452 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 453 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 454 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 455 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 456 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 457 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 458 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 459 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 460 / 40436
# 1/1 [==============================] - 0s 39ms/step
# 461 / 40436
# 1/1 [==============================] - 0s 34ms/step
# 462 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 463 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 464 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 465 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 466 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 467 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 468 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 469 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 470 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 471 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 472 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 473 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 474 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 475 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 476 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 477 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 478 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 479 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 480 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 481 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 482 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 483 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 484 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 485 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 486 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 487 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 488 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 489 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 490 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 491 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 492 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 493 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 494 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 495 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 496 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 497 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 498 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 499 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 500 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 501 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 502 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 503 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 504 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 505 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 506 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 507 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 508 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 509 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 510 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 511 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 512 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 513 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 514 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 515 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 516 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 517 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 518 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 519 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 520 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 521 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 522 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 523 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 524 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 525 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 526 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 527 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 528 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 529 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 530 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 531 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 532 / 40436
# 1/1 [==============================] - 0s 34ms/step
# 533 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 534 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 535 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 536 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 537 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 538 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 539 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 540 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 541 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 542 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 543 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 544 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 545 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 546 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 547 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 548 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 549 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 550 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 551 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 552 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 553 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 554 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 555 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 556 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 557 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 558 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 559 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 560 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 561 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 562 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 563 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 564 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 565 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 566 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 567 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 568 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 569 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 570 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 571 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 572 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 573 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 574 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 575 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 576 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 577 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 578 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 579 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 580 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 581 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 582 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 583 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 584 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 585 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 586 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 587 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 588 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 589 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 590 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 591 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 592 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 593 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 594 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 595 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 596 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 597 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 598 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 599 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 600 / 40436
# 1/1 [==============================] - 0s 41ms/step
# 601 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 602 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 603 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 604 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 605 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 606 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 607 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 608 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 609 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 610 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 611 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 612 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 613 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 614 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 615 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 616 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 617 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 618 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 619 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 620 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 621 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 622 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 623 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 624 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 625 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 626 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 627 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 628 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 629 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 630 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 631 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 632 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 633 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 634 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 635 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 636 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 637 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 638 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 639 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 640 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 641 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 642 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 643 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 644 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 645 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 646 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 647 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 648 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 649 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 650 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 651 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 652 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 653 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 654 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 655 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 656 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 657 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 658 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 659 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 660 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 661 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 662 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 663 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 664 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 665 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 666 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 667 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 668 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 669 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 670 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 671 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 672 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 673 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 674 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 675 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 676 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 677 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 678 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 679 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 680 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 681 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 682 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 683 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 684 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 685 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 686 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 687 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 688 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 689 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 690 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 691 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 692 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 693 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 694 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 695 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 696 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 697 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 698 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 699 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 700 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 701 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 702 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 703 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 704 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 705 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 706 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 707 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 708 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 709 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 710 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 711 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 712 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 713 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 714 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 715 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 716 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 717 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 718 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 719 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 720 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 721 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 722 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 723 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 724 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 725 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 726 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 727 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 728 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 729 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 730 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 731 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 732 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 733 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 734 / 40436
# 1/1 [==============================] - 0s 21ms/step
# 735 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 736 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 737 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 738 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 739 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 740 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 741 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 742 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 743 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 744 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 745 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 746 / 40436
# 1/1 [==============================] - 0s 22ms/step
# ...
# 40212 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40213 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40214 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40215 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40216 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40217 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40218 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40219 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40220 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40221 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40222 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40223 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40224 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40225 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40226 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40227 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40228 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40229 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40230 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40231 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40232 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40233 / 40436
# 1/1 [==============================] - 0s 22ms/step
# 40234 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40235 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40236 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40237 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40238 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40239 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40240 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40241 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40242 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40243 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40244 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40245 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40246 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40247 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40248 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40249 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40250 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40251 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40252 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40253 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40254 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40255 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40256 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40257 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40258 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40259 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40260 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40261 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40262 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40263 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40264 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40265 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40266 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40267 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40268 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40269 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40270 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40271 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40272 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40273 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40274 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40275 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40276 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40277 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40278 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40279 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40280 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40281 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40282 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40283 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40284 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40285 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40286 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40287 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40288 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40289 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40290 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40291 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40292 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40293 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40294 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40295 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40296 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40297 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40298 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40299 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40300 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40301 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40302 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40303 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40304 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40305 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40306 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40307 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40308 / 40436
# 1/1 [==============================] - 0s 37ms/step
# 40309 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40310 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40311 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40312 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40313 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40314 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40315 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40316 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40317 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40318 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40319 / 40436
# 1/1 [==============================] - 0s 40ms/step
# 40320 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40321 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40322 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40323 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40324 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40325 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40326 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40327 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40328 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40329 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40330 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40331 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40332 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40333 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40334 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40335 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40336 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40337 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40338 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40339 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40340 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40341 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 40342 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40343 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40344 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40345 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40346 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40347 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40348 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40349 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40350 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40351 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40352 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40353 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40354 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40355 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40356 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 40357 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40358 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40359 / 40436
# 1/1 [==============================] - 0s 23ms/step
# 40360 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40361 / 40436
# 1/1 [==============================] - 0s 24ms/step
# 40362 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40363 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40364 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40365 / 40436
# 1/1 [==============================] - 0s 47ms/step
# 40366 / 40436
# 1/1 [==============================] - 0s 48ms/step
# 40367 / 40436
# 1/1 [==============================] - 0s 37ms/step
# 40368 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40369 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40370 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40371 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40372 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40373 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40374 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40375 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40376 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40377 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40378 / 40436
# 1/1 [==============================] - 0s 31ms/step
# 40379 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40380 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40381 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40382 / 40436
# 1/1 [==============================] - 0s 31ms/step
# 40383 / 40436
# 1/1 [==============================] - 0s 31ms/step
# 40384 / 40436
# 1/1 [==============================] - 0s 31ms/step
# 40385 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40386 / 40436
# 1/1 [==============================] - 0s 35ms/step
# 40387 / 40436
# 1/1 [==============================] - 0s 35ms/step
# 40388 / 40436
# 1/1 [==============================] - 0s 35ms/step
# 40389 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40390 / 40436
# 1/1 [==============================] - 0s 49ms/step
# 40391 / 40436
# 1/1 [==============================] - 0s 45ms/step
# 40392 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40393 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40394 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40395 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40396 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40397 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40398 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40399 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40400 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40401 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40402 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40403 / 40436
# 1/1 [==============================] - 0s 31ms/step
# 40404 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40405 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40406 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40407 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40408 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40409 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 40410 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40411 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40412 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40413 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40414 / 40436
# 1/1 [==============================] - 0s 25ms/step
# 40415 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40416 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40417 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40418 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 40419 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40420 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40421 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40422 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40423 / 40436
# 1/1 [==============================] - 0s 28ms/step
# 40424 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 40425 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40426 / 40436
# 1/1 [==============================] - 0s 32ms/step
# 40427 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40428 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40429 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40430 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40431 / 40436
# 1/1 [==============================] - 0s 30ms/step
# 40432 / 40436
# 1/1 [==============================] - 0s 29ms/step
# 40433 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40434 / 40436
# 1/1 [==============================] - 0s 27ms/step
# 40435 / 40436
# 1/1 [==============================] - 0s 26ms/step
# 40436 / 40436
# CPU times: total: 1h 3min 49s
# Wall time: 42min 40s
# ['정말 끝내주는 영화네요한국 영화 많이 보는 내가 이걸 인제 봤다니ㅎ',
#  '한산보기 전 다시 봤는데 역시 재미있네요',
#  '명량 실제로 거북선 불타지 않았구요 배설해 전후에 죽었구요 해전에서 백병전이 다 이런 적 없구요 화포만 쐈고 세키부 네 크기가 판옥 대선만 하구요충파 안 했구요 이상한 신파씬ㄱ 같구요 나름 해전 씬은 재밌게 봐서 5점입니다 한산실제로 영화처럼 학익진하면 옆에 다 뚤려 있어서 ㅈ되 구요 거북선 충파씬아 타케부네를 반 갈죽 못하구요 거북선이 어디서 등장했는지 애들이 못 보구 요 배 속도가 제트기 여기도 신파씬ㄱ 같구요 명량보단 낫고 변요한 잘 생겨서 7점 댓글 명량평가가 아니라 둘을 비교하고 평점은 평균으로 나눈 거다',
#  '명량해전 하나만 좋았다',
#  '한산보고 궁금해서 봤는데 명량이 확실히 스토리도 탄탄하고 전투씬도 더 박진감 넘치고 리얼하네요 배우들 캐스팅도 괜찮고 갠적으로 최민식 배우님 명량에서 연기가 다른 작품보다 괜찮았어요',
#  '개인적인 생각이자 바람이지만 노량이 끝난 후에 명량을 전체적으로 손보는 투자가 있기를 희망합니다 한산노량과 비슷하게 편집을 하고 특수효과도 스타워즈의 사례같이 대대적으로 손보았으면 좋겠습니다 8년이라는 시간이 지났는데 최근에 다시 보니 한 산에 비해 부족한 부분이 너무 많아서 아쉽습니다 명량 제작진과 배급사나 투자주체에 따른 이해관계 못할 가능성도 있겠지만 한산과 노량을 제작하면서 시각 효과에 쌓인데이터들을 명량에도 연속해 3부작이 연결됐으면 좋겠네 요일본군들의 일본어도 일본 성우들에 정확하게 발음될 수 있도록 일본판 오디오로 교체했으면 하고 여러 가지 부분들을 크게 개선하도록 빅스톤에서 투자해서 재작업에 가까운 결정을 해줬으면 좋겠습니다 꿈같은 일이지만 써봅니다',
#  '졸림',
#  '이순신 자체를 높게 평가하는 것과 영화로서의 평가를 해보자면 명량은 작품성이 기대보다 많이 떨어진 다 이순신의 고뇌와 리얼함을 추구한 스타일은 감정이입을 강요한 느낌이다',
#  '연출력 자체만 보면 5점이 적당함',
#  '지금 다시 보니 이리 슬픈 지 마지막 장면 중에 후손들이 우리가 이렇게 나라 지키려고 개고생했는지 알까 하고 말하는 장면이 기억에 남네 요 많은 날 고생을 잊고 살아간 자신을 용서해 주시길 선조들의 크나큰 노고에 다시 한 번 고개 숙여 감사드립니다']

# %% [markdown]
# ### 전처리 완료된 리뷰 텍스트로 정제된(clean) 데이터프레임 생성
# - 정제된 리뷰데이터를 csv 파일로 저장하기 위해 만들었음!

# %%
clean_train_df = pd.DataFrame({'영화':data['movie'], '리뷰':clean_train_reviews, '평점':data['score']})
clean_train_df
# Out:
#         영화                                                 리뷰  평점
# 0       명량              정말 끝내주는 영화네요한국 영화 많이 보는 내가 이걸 인제 봤다니ㅎ  10
# 1       명량                             한산보기 전 다시 봤는데 역시 재미있네요  10
# 2       명량  명량 실제로 거북선 불타지 않았구요 배설해 전후에 죽었구요 해전에서 백병전이 다 이...   6
# 3       명량                                       명량해전 하나만 좋았다   6
# 4       명량  한산보고 궁금해서 봤는데 명량이 확실히 스토리도 탄탄하고 전투씬도 더 박진감 넘치고...   8
# ...    ...                                                ...  ..
# 40431  완득이                                           재미나게 봤어요  10
# 40432  완득이  자연스런 전개 속에 다문화가정의 소시민적인 삶을 잘 담아냈당 ㅋ 유머도 너무 재밌고...  10
# 40433  완득이  높은 평점 때문에 엄청 수작일꺼라 생각했는데 기대치에 한참 못 미쳤음 김윤석 연기보...   7
# 40434  완득이                         웃겨 욬ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  10
# 40435  완득이              오랜만에 가슴 따뜻해지는 제대로 된 영화를 본 것 같아 너무 좋았음  10
#
# [40436 rows x 3 columns]

# %%
# csv파일로 저장
clean_train_df.to_csv('d:/data/project/data/clean_data_daum.csv')

# %% [markdown]
# ## Okt 형태소 분석기 사용

# %% [markdown]
# # 임베딩 (Embedding)

# %% [markdown]
# ## Word2vec

# %% [markdown]
# ### 토크나이징 (벡터화)
# * tensorflow.keras.preprocessing.text 에서 가져온 Tokenizer 클래스 사용

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_train_reviews)   # 단어장
text_sequences = tokenizer.texts_to_sequences(clean_train_reviews)   # 문장을 벡터화
print(text_sequences[0])  # 첫번째 문장 벡터화
# Out:
# [2321, 19732, 1785, 9388, 2987, 3922, 19733]

# %% [markdown]
# ### 새로운 텍스트 데이터를 벡터화 하기 위해서는...
# (1) 데이터 정제 (소문자--> 불용어 제거, 구두점 제거 등등...)
# (2) 위에서 만든 tokenizer에 texts_to_sequences()에 넣어서 벡터화

# %% [markdown]
# ### 단어 사전 (tokenizer.word_index)

# %%
tokenizer.word_index
# Out:
# {'영화': 1,
#  '너무': 2,
#  '진짜': 3,
#  '정말': 4,
#  '잘': 5,
#  '더': 6,
#  '그냥': 7,
#  '다': 8,
#  '다시': 9,
#  '연기': 10,
#  '보고': 11,
#  '봐도': 12,
#  '수': 13,
#  '영화를': 14,
#  '최고의': 15,
#  '봤는데': 16,
#  '영화가': 17,
#  '영화는': 18,
#  '본': 19,
#  '스토리': 20,
#  '재밌게': 21,
#  '역시': 22,
#  '최고': 23,
#  '있는': 24,
#  '이게': 25,
#  '없는': 26,
#  '이렇게': 27,
#  'ㅋㅋ': 28,
#  '많이': 29,
#  '보는': 30,
#  '지금': 31,
#  '한': 32,
#  '내': 33,
#  '평점': 34,
#  '꼭': 35,
#  '볼': 36,
#  '좋은': 37,
#  '내가': 38,
#  '안': 39,
#  '없다': 40,
#  '다시봐도': 41,
#  '마지막': 42,
#  '재밌다': 43,
#  '가장': 44,
#  '봤습니다': 45,
#  '연출': 46,
#  '하는': 47,
#  '연기가': 48,
#  '액션': 49,
#  '모든': 50,
#  '한국': 51,
#  '보면': 52,
#  '마블': 53,
#  '영화관에서': 54,
#  '만든': 55,
#  'ㅋㅋㅋ': 56,
#  '난': 57,
#  '명작': 58,
#  '중': 59,
#  '말이': 60,
#  '같은': 61,
#  '이거': 62,
#  '평점이': 63,
#  '배우들': 64,
#  '감사합니다': 65,
#  '재밌어요': 66,
#  '재미있게': 67,
#  '솔직히': 68,
#  '재밌음': 69,
#  '제일': 70,
#  '근데': 71,
#  '이건': 72,
#  '계속': 73,
#  '인생': 74,
#  '넘': 75,
#  '감동': 76,
#  '영화다': 77,
#  '연기도': 78,
#  '스토리가': 79,
#  '오랜만에': 80,
#  '좋고': 81,
#  '영화입니다': 82,
#  '배우들의': 83,
#  '봤어요': 84,
#  '재밌고': 85,
#  '완전': 86,
#  '연기는': 87,
#  '할': 88,
#  '영화의': 89,
#  '많은': 90,
#  '하고': 91,
#  '보니': 92,
#  '극장에서': 93,
#  '뭐': 94,
#  '작품': 95,
#  '이걸': 96,
#  '내내': 97,
#  '없이': 98,
#  '끝까지': 99,
#  '스토리도': 100,
#  '처음': 101,
#  'ㅋ': 102,
#  '대한': 103,
#  '특히': 104,
#  '볼때마다': 105,
#  '없고': 106,
#  '엄청': 107,
#  '느낌': 108,
#  '인생영화': 109,
#  '아니라': 110,
#  '위해': 111,
#  'ㅎㅎ': 112,
#  '완벽한': 113,
#  '좋았다': 114,
#  '강동원': 115,
#  '아주': 116,
#  '눈물이': 117,
#  '영화에': 118,
#  '스파이더맨': 119,
#  '대한민국': 120,
#  '좋다': 121,
#  '듯': 122,
#  '아직도': 123,
#  '시리즈': 124,
#  '몇번을': 125,
#  '뭔가': 126,
#  '이제': 127,
#  '마지막에': 128,
#  '배우': 129,
#  '재밌는': 130,
#  '재미': 131,
#  '나오는': 132,
#  '최고다': 133,
#  '나는': 134,
#  '봤다': 135,
#  '게': 136,
#  '10점': 137,
#  '않고': 138,
#  '눈물': 139,
#  '못': 140,
#  '가': 141,
#  '봄': 142,
#  '감독': 143,
#  '보면서': 144,
#  '한번': 145,
#  '있고': 146,
#  '하정우': 147,
#  '스토리는': 148,
#  '1': 149,
#  '아이언맨': 150,
#  '거': 151,
#  '한국영화': 152,
#  '다들': 153,
#  '보다가': 154,
#  '없음': 155,
#  '별로': 156,
#  '보세요': 157,
#  '그런': 158,
#  '역사를': 159,
#  '연기를': 160,
#  '되는': 161,
#  '보기': 162,
#  '감독이': 163,
#  '전': 164,
#  '생각이': 165,
#  'ㅋㅋㅋㅋ': 166,
#  '좋아요': 167,
#  '뻔한': 168,
#  '우리나라': 169,
#  '생각보다': 170,
#  '개인적으로': 171,
#  '당시': 172,
#  '제발': 173,
#  '나름': 174,
#  '재밌네요': 175,
#  '이병헌': 176,
#  '이해가': 177,
#  '굿': 178,
#  '쓰레기': 179,
#  '사람들이': 180,
#  '모르고': 181,
#  '줄': 182,
#  '않는': 183,
#  '연기력': 184,
#  '건': 185,
#  '않은': 186,
#  '제대로': 187,
#  '영화로': 188,
#  '걍': 189,
#  '큰': 190,
#  '전혀': 191,
#  '가슴이': 192,
#  '정도로': 193,
#  '보다': 194,
#  '아닌': 195,
#  '영화라고': 196,
#  '사람이': 197,
#  '어벤져스': 198,
#  '송강호': 199,
#  '같아요': 200,
#  '2': 201,
#  '항상': 202,
#  '절대': 203,
#  '주는': 204,
#  '그렇게': 205,
#  '된': 206,
#  '꿀잼': 207,
#  '봤던': 208,
#  '여운이': 209,
#  '위한': 210,
#  '보게': 211,
#  '장면': 212,
#  '이제야': 213,
#  '4': 214,
#  '역사': 215,
#  '두': 216,
#  '만드는': 217,
#  'ㄹㅇ': 218,
#  '는': 219,
#  '감독의': 220,
#  '좋음': 221,
#  '오늘': 222,
#  '감동적인': 223,
#  '억지': 224,
#  '개': 225,
#  '한다': 226,
#  '마음이': 227,
#  '진심': 228,
#  '영상미': 229,
#  '장면이': 230,
#  '새로운': 231,
#  '캐릭터': 232,
#  '번': 233,
#  '이야기': 234,
#  '좋아하는': 235,
#  '중에': 236,
#  '싶다': 237,
#  '좋았어요': 238,
#  '짱': 239,
#  '매우': 240,
#  '도': 241,
#  '영화중': 242,
#  '유아인': 243,
#  '재미가': 244,
#  '재밌었어요': 245,
#  '충분히': 246,
#  '했는데': 247,
#  '잊지': 248,
#  '아쉽다': 249,
#  '유해진': 250,
#  '입니다': 251,
#  '사람': 252,
#  '있지만': 253,
#  '요즘': 254,
#  '보는데': 255,
#  '말': 256,
#  '연출이': 257,
#  '것이': 258,
#  '1점': 259,
#  '멋진': 260,
#  '코미디': 261,
#  '처음부터': 262,
#  '볼만한': 263,
#  '내용이': 264,
#  '이제서야': 265,
#  '현빈': 266,
#  '좋았음': 267,
#  '믿고': 268,
#  '톰': 269,
#  'ㅎ': 270,
#  '좋겠다': 271,
#  '해서': 272,
#  '너무너무': 273,
#  '대박': 274,
#  '봐서': 275,
#  '별': 276,
#  '감동적이고': 277,
#  '훌륭한': 278,
#  '도대체': 279,
#  '걸': 280,
#  '아니고': 281,
#  '히어로': 282,
#  '아님': 283,
#  '3': 284,
#  '재미는': 285,
#  '것도': 286,
#  '것을': 287,
#  '무조건': 288,
#  '있어서': 289,
#  '긴장감': 290,
#  '좋았고': 291,
#  '아무리': 292,
#  '정도': 293,
#  '아니다': 294,
#  '부분이': 295,
#  '안되는': 296,
#  '나도': 297,
#  '다시보니': 298,
#  '5': 299,
#  '보는내내': 300,
#  '시간이': 301,
#  '재미있다': 302,
#  '대해': 303,
#  '기억에': 304,
#  '모든게': 305,
#  '나온': 306,
#  '기대': 307,
#  '봤네요': 308,
#  '주인공': 309,
#  '그대로': 310,
#  '밖에': 311,
#  '영화임': 312,
#  '좋았습니다': 313,
#  '감동을': 314,
#  '재미있는': 315,
#  '누가': 316,
#  '싶은': 317,
#  '재미있어요': 318,
#  '있는데': 319,
#  '사람들': 320,
#  '재밌었음': 321,
#  '아직': 322,
#  '우리가': 323,
#  '이정도면': 324,
#  '천만': 325,
#  '느낌이': 326,
#  '남는': 327,
#  '않는다': 328,
#  '개연성': 329,
#  '갈수록': 330,
#  '영화네요': 331,
#  '재밌는데': 332,
#  '영화인데': 333,
#  '하나도': 334,
#  '최고입니다': 335,
#  '지금도': 336,
#  '비해': 337,
#  '봐도봐도': 338,
#  '저는': 339,
#  '화려한': 340,
#  '좋은데': 341,
#  '역대': 342,
#  '벌써': 343,
#  '알고': 344,
#  '지난': 345,
#  '잘봤습니다': 346,
#  '수가': 347,
#  '보니까': 348,
#  '너무나': 349,
#  '감동이': 350,
#  '영화도': 351,
#  '장면은': 352,
#  '모르겠다': 353,
#  '재미도': 354,
#  '수작': 355,
#  '있음': 356,
#  '같음': 357,
#  '기억이': 358,
#  '액션도': 359,
#  '소름': 360,
#  '해도': 361,
#  '생각': 362,
#  '지금봐도': 363,
#  '이순신': 364,
#  '캡틴': 365,
#  '재미있고': 366,
#  '엄청난': 367,
#  '존나': 368,
#  '사람들은': 369,
#  '내용': 370,
#  '넘게': 371,
#  '명작이다': 372,
#  '제가': 373,
#  '영화에서': 374,
#  '최악의': 375,
#  '믿고보는': 376,
#  '언제봐도': 377,
#  '나왔으면': 378,
#  '역대급': 379,
#  '수준': 380,
#  '잘만든': 381,
#  '나와서': 382,
#  '진정한': 383,
#  '노잼': 384,
#  '때마다': 385,
#  '개봉': 386,
#  '영화였습니다': 387,
#  '될': 388,
#  '영화였다': 389,
#  '좋네요': 390,
#  '있을까': 391,
#  '액션이': 392,
#  '재밌네': 393,
#  '없어서': 394,
#  '감동도': 395,
#  '봤음': 396,
#  '같은데': 397,
#  '했다': 398,
#  '대단한': 399,
#  '확실히': 400,
#  '보여주는': 401,
#  '봤을': 402,
#  '전형적인': 403,
#  '재밌습니다': 404,
#  '사람은': 405,
#  '봤지만': 406,
#  '8': 407,
#  '음악': 408,
#  '슬프고': 409,
#  '앞으로': 410,
#  '굉장히': 411,
#  '전개': 412,
#  '지금까지': 413,
#  '아깝다': 414,
#  '연출도': 415,
#  '중간중간': 416,
#  '볼만함': 417,
#  '아쉬운': 418,
#  '연기와': 419,
#  '된다': 420,
#  '이영화를': 421,
#  '중간에': 422,
#  '없었다': 423,
#  '액션은': 424,
#  '내용도': 425,
#  '몰입도': 426,
#  '감독은': 427,
#  '대사': 428,
#  '뭔': 429,
#  '신파': 430,
#  '본다': 431,
#  '실제': 432,
#  '갑자기': 433,
#  '했지만': 434,
#  '스토리를': 435,
#  '괜찮은': 436,
#  '봉준호': 437,
#  '나라를': 438,
#  '만들어': 439,
#  '간만에': 440,
#  '라는': 441,
#  '내용은': 442,
#  '저런': 443,
#  '합니다': 444,
#  '그런지': 445,
#  '후': 446,
#  '재밌었다': 447,
#  '스토리에': 448,
#  '디즈니': 449,
#  '10년이': 450,
#  '미친': 451,
#  '그렇고': 452,
#  '하면': 453,
#  '티비에서': 454,
#  '배우의': 455,
#  '스토리와': 456,
#  '결말이': 457,
#  '하지': 458,
#  '더욱': 459,
#  '가볍게': 460,
#  '꽤': 461,
#  '나오면': 462,
#  '대사가': 463,
#  '이유가': 464,
#  '추천': 465,
#  '대체': 466,
#  '이딴': 467,
#  '질리지': 468,
#  '생각함': 469,
#  '배우들이': 470,
#  '말도': 471,
#  '급': 472,
#  '영화라': 473,
#  '준': 474,
#  '가는': 475,
#  '않다': 476,
#  '별점': 477,
#  '생각을': 478,
#  '보지': 479,
#  '돈': 480,
#  '레전드': 481,
#  '않음': 482,
#  '굳이': 483,
#  '마동석': 484,
#  '완벽': 485,
#  '노래': 486,
#  '지루한': 487,
#  '덕분에': 488,
#  '필요': 489,
#  '이미': 490,
#  'ㄷㄷ': 491,
#  '높은': 492,
#  '미쳤다': 493,
#  '연기력이': 494,
#  '추천합니다': 495,
#  '1편': 496,
#  '생각나서': 497,
#  '재난': 498,
#  '것은': 499,
#  '크게': 500,
#  '빨리': 501,
#  '원래': 502,
#  '있었다': 503,
#  '주고': 504,
#  '못한': 505,
#  '사실': 506,
#  '시리즈는': 507,
#  '미션': 508,
#  '모르는': 509,
#  '이영화는': 510,
#  '나의': 511,
#  '그게': 512,
#  '함': 513,
#  '우리의': 514,
#  '말고': 515,
#  '강추': 516,
#  '되게': 517,
#  '재미있음': 518,
#  '집에서': 519,
#  '가지고': 520,
#  '생각합니다': 521,
#  '전에': 522,
#  '사랑해': 523,
#  '겁나': 524,
#  '최악': 525,
#  '마블의': 526,
#  '알': 527,
#  '생각한다': 528,
#  '두번': 529,
#  '지금의': 530,
#  '마음에': 531,
#  '같습니다': 532,
#  '봤는데도': 533,
#  '펑펑': 534,
#  '이영화': 535,
#  '언제나': 536,
#  '전지현': 537,
#  '쥬라기': 538,
#  '평점을': 539,
#  '명작입니다': 540,
#  '눈물을': 541,
#  '가서': 542,
#  '몰입감': 543,
#  '배우가': 544,
#  '좋아서': 545,
#  '처음으로': 546,
#  '이후': 547,
#  '결말': 548,
#  '트랜스포머': 549,
#  '전개가': 550,
#  '정우성': 551,
#  '살짝': 552,
#  '있어': 553,
#  '그럭저럭': 554,
#  '존잼': 555,
#  '캐스팅': 556,
#  '개연성이': 557,
#  '판타지': 558,
#  '있게': 559,
#  '든다': 560,
#  '자체가': 561,
#  '않았다': 562,
#  '아닌가': 563,
#  '지루하지': 564,
#  '명복을': 565,
#  '저렇게': 566,
#  '기분': 567,
#  '특유의': 568,
#  '하다': 569,
#  '영화중에': 570,
#  '만': 571,
#  '안하고': 572,
#  '뭐가': 573,
#  '북한': 574,
#  '원빈': 575,
#  '가슴': 576,
#  '있습니다': 577,
#  '그나마': 578,
#  '뭘': 579,
#  '보여준': 580,
#  '젤': 581,
#  '전체적으로': 582,
#  '눈이': 583,
#  '점점': 584,
#  '나올': 585,
#  '영상': 586,
#  '재개봉': 587,
#  '봐야': 588,
#  '잘하고': 589,
#  '많아서': 590,
#  '빕니다': 591,
#  '우리는': 592,
#  '없을': 593,
#  '탄탄한': 594,
#  '2편': 595,
#  '영화지만': 596,
#  '번을': 597,
#  '재밌어서': 598,
#  '연기에': 599,
#  '않겠습니다': 600,
#  '기대를': 601,
#  '봤었는데': 602,
#  '7': 603,
#  '억지로': 604,
#  '재미없다': 605,
#  '8점': 606,
#  '멋있다': 607,
#  '개꿀잼': 608,
#  '없는데': 609,
#  '황정민': 610,
#  '스파이더맨이': 611,
#  '필요없는': 612,
#  '빼고': 613,
#  '여러번': 614,
#  '울었다': 615,
#  '있을': 616,
#  '대한민국의': 617,
#  '시작': 618,
#  '느낄': 619,
#  '지나도': 620,
#  '자체': 621,
#  '영화보고': 622,
#  '나쁘지': 623,
#  '없네': 624,
#  '만든다': 625,
#  '그걸': 626,
#  '슬프다': 627,
#  '마블은': 628,
#  '아름다운': 629,
#  '시간가는줄': 630,
#  '영화이다': 631,
#  '모두가': 632,
#  '멋있고': 633,
#  '자꾸': 634,
#  '좋았는데': 635,
#  '웃기고': 636,
#  '첫': 637,
#  '시대를': 638,
#  '지금은': 639,
#  '미션임파서블': 640,
#  '볼수록': 641,
#  '만들었다': 642,
#  '1편이': 643,
#  '연출은': 644,
#  '늘': 645,
#  '아포칼립토': 646,
#  '이야기를': 647,
#  '5점': 648,
#  '킬링타임용': 649,
#  '오락영화': 650,
#  '드라마': 651,
#  '사람을': 652,
#  '영화에요': 653,
#  '손예진': 654,
#  '봅니다': 655,
#  '있다는': 656,
#  '봐야할': 657,
#  '지루하고': 658,
#  '가족': 659,
#  '않게': 660,
#  '인간의': 661,
#  '아닌데': 662,
#  '재미와': 663,
#  '놀란': 664,
#  '난다': 665,
#  '생각없이': 666,
#  '연출과': 667,
#  '하는데': 668,
#  '단': 669,
#  '슬픈': 670,
#  '되고': 671,
#  '빨갱이': 672,
#  '와칸다': 673,
#  '실제로': 674,
#  '알게': 675,
#  '1도': 676,
#  '지': 677,
#  '감동과': 678,
#  '다시한번': 679,
#  '감독님': 680,
#  '필요없다': 681,
#  '토니': 682,
#  '깊은': 683,
#  '연기력은': 684,
#  '통해': 685,
#  '상당히': 686,
#  '손에': 687,
#  '눈을': 688,
#  '이해': 689,
#  '액션과': 690,
#  '코믹': 691,
#  '지루할': 692,
#  '너무나도': 693,
#  '아까운': 694,
#  '것이다': 695,
#  '아쉬움': 696,
#  '한국형': 697,
#  '한국의': 698,
#  '힘든': 699,
#  '포에버': 700,
#  '시리즈가': 701,
#  '박보영': 702,
#  '예전에': 703,
#  '해주는': 704,
#  '시대에': 705,
#  '대단하다': 706,
#  '이후로': 707,
#  '아닐까': 708,
#  'ㅉㅉ': 709,
#  '안된다': 710,
#  '평론가': 711,
#  '모습이': 712,
#  '공룡': 713,
#  '재밌어': 714,
#  '준다': 715,
#  '이유': 716,
#  '아픈': 717,
#  '여자': 718,
#  '뿐': 719,
#  '시리즈중': 720,
#  '떠나서': 721,
#  '몰입해서': 722,
#  '남을': 723,
#  '됨': 724,
#  '나만': 725,
#  '다시는': 726,
#  '매력적인': 727,
#  '듯한': 728,
#  '재밌었는데': 729,
#  '주인공이': 730,
#  '전율이': 731,
#  '진심으로': 732,
#  '알았는데': 733,
#  '1편보다': 734,
#  '소재를': 735,
#  '재밌다고': 736,
#  '분들': 737,
#  '같아서': 738,
#  '라고': 739,
#  '배우들도': 740,
#  '3번': 741,
#  '주연': 742,
#  '봤으면': 743,
#  '끝': 744,
#  '유치하고': 745,
#  '처럼': 746,
#  '말로': 747,
#  '마무리': 748,
#  'ㅎㅎㅎ': 749,
#  '조인성': 750,
#  '적당히': 751,
#  '현실을': 752,
#  '이런게': 753,
#  '작품이': 754,
#  '뛰어난': 755,
#  '캐릭터가': 756,
#  '굿굿': 757,
#  '방금': 758,
#  '재미있네요': 759,
#  '아니지만': 760,
#  '보다니': 761,
#  '왜케': 762,
#  '초반에': 763,
#  '내용을': 764,
#  '6': 765,
#  '노래가': 766,
#  '먼저': 767,
#  '나서': 768,
#  '재미를': 769,
#  '왜이리': 770,
#  '9점': 771,
#  '현실': 772,
#  '낫다': 773,
#  '초반': 774,
#  '엔드게임': 775,
#  '시리즈를': 776,
#  '이정재': 777,
#  '임파서블': 778,
#  '강동원의': 779,
#  '단연': 780,
#  '역사적': 781,
#  '나라': 782,
#  '마음을': 783,
#  '현재': 784,
#  '보았습니다': 785,
#  '많고': 786,
#  '한국에서': 787,
#  '그냥저냥': 788,
#  '이병헌의': 789,
#  '윤아': 790,
#  '톰크루즈': 791,
#  '이리': 792,
#  '뒤늦게': 793,
#  '소재로': 794,
#  '영화인': 795,
#  '있었던': 796,
#  'ㅈㄴ': 797,
#  '음': 798,
#  '보고나서': 799,
#  '못하는': 800,
#  '여러': 801,
#  '봐야하는': 802,
#  '나중에': 803,
#  '김수현': 804,
#  '김아중': 805,
#  '배우님': 806,
#  '역사에': 807,
#  '9': 808,
#  '생각했는데': 809,
#  '수준이': 810,
#  '재밌었습니다': 811,
#  '같아': 812,
#  '같네요': 813,
#  '아쉽지만': 814,
#  '막': 815,
#  '울고': 816,
#  '순간': 817,
#  '속': 818,
#  '2편은': 819,
#  '여기서': 820,
#  '탄탄하고': 821,
#  '얼굴': 822,
#  '날': 823,
#  '그들의': 824,
#  '그런가': 825,
#  '수많은': 826,
#  '몰입이': 827,
#  '만들어진': 828,
#  '최고임': 829,
#  '못하고': 830,
#  '몰랐는데': 831,
#  '나온다': 832,
#  '아무': 833,
#  '자신의': 834,
#  '원작': 835,
#  '있었지만': 836,
#  '수도': 837,
#  '눈': 838,
#  '지루함': 839,
#  '무엇보다': 840,
#  '봤는지': 841,
#  '영화보다': 842,
#  '있다면': 843,
#  '봤을까': 844,
#  '봤고': 845,
#  '자체는': 846,
#  '잘함': 847,
#  '없네요': 848,
#  '완벽하다': 849,
#  '7점': 850,
#  '괜히': 851,
#  '보고싶다': 852,
#  '남는다': 853,
#  '최고였다': 854,
#  '표절': 855,
#  '배트맨': 856,
#  '위대한': 857,
#  '몰입도가': 858,
#  '이정도': 859,
#  '사랑해요': 860,
#  '또봐도': 861,
#  '재미없음': 862,
#  '때는': 863,
#  '킬링타임용으로': 864,
#  '부족한': 865,
#  '둘다': 866,
#  '후반부': 867,
#  '1편은': 868,
#  '나오고': 869,
#  '그리': 870,
#  '살고': 871,
#  '살면서': 872,
#  '영화라는': 873,
#  '김윤석': 874,
#  '고인의': 875,
#  '재난영화': 876,
#  '국뽕': 877,
#  '뮤지컬': 878,
#  '없지만': 879,
#  '도저히': 880,
#  '배우분들': 881,
#  '시나리오': 882,
#  '어설픈': 883,
#  '각본': 884,
#  '아저씨': 885,
#  '한국판': 886,
#  '다시봤는데': 887,
#  '그만': 888,
#  '케미': 889,
#  '비슷한': 890,
#  '봐야지': 891,
#  '긴장감이': 892,
#  '굳': 893,
#  '조승우': 894,
#  '강동원이': 895,
#  '분명': 896,
#  '아쉽네요': 897,
#  '이유는': 898,
#  '말할': 899,
#  '그닥': 900,
#  '유쾌한': 901,
#  '사람들의': 902,
#  '삶을': 903,
#  '6점': 904,
#  '잘한다': 905,
#  '넘치는': 906,
#  '느껴지는': 907,
#  '이영화가': 908,
#  '흠': 909,
#  '뭐지': 910,
#  '액션영화': 911,
#  '보시길': 912,
#  '가끔': 913,
#  '아무것도': 914,
#  '웃고': 915,
#  '아는': 916,
#  '평점은': 917,
#  '내인생': 918,
#  '중간': 919,
#  '역시나': 920,
#  '다크나이트': 921,
#  '스파이더맨은': 922,
#  '송중기': 923,
#  '시절': 924,
#  '안보고': 925,
#  '되었다': 926,
#  '감동은': 927,
#  '안에': 928,
#  '애들': 929,
#  '먹고': 930,
#  '영화관': 931,
#  '이야기가': 932,
#  '현실적인': 933,
#  '느끼게': 934,
#  '없어': 935,
#  '모습을': 936,
#  '10년': 937,
#  '아이언맨이': 938,
#  '영화들': 939,
#  '노래도': 940,
#  '오락': 941,
#  '만들고': 942,
#  '전쟁': 943,
#  '기대하고': 944,
#  '않을': 945,
#  '감동입니다': 946,
#  '부분도': 947,
#  '보이는': 948,
#  '생각하고': 949,
#  '즐겁게': 950,
#  '없습니다': 951,
#  '되어': 952,
#  '없어요': 953,
#  '어디서': 954,
#  '본듯': 955,
#  '유치한': 956,
#  '드는': 957,
#  '그만큼': 958,
#  '보며': 959,
#  '재미있었습니다': 960,
#  '어린': 961,
#  '마블이': 962,
#  '재미있습니다': 963,
#  '매력이': 964,
#  '하게': 965,
#  '옛날': 966,
#  '일본': 967,
#  '2시간': 968,
#  '해': 969,
#  '속편': 970,
#  '1점도': 971,
#  '웃음': 972,
#  '신선한': 973,
#  '우리나라의': 974,
#  '마음': 975,
#  '떨어지는': 976,
#  '유쾌하고': 977,
#  '하나하나': 978,
#  '마블영화': 979,
#  '완벽하게': 980,
#  '1이': 981,
#  '보았다': 982,
#  '맘에': 983,
#  '사극': 984,
#  '한국영화의': 985,
#  '감사드립니다': 986,
#  '딱히': 987,
#  '정말로': 988,
#  '반전': 989,
#  '평생': 990,
#  '좋습니다': 991,
#  '유일하게': 992,
#  '18': 993,
#  '보인다': 994,
#  '해준': 995,
#  '안됨': 996,
#  '영원히': 997,
#  '엔딩': 998,
#  '평이': 999,
#  '설정': 1000,
#  ...}

# %%
# 학습된 총 단어 수
len(tokenizer.word_index)
# Out:
# 120098

# %%
max(tokenizer.word_index.values())
# Out:
# 120098

# %% [markdown]
# * 인덱스가 1부터 시작하므로 0번은 '\<PAD\>'라는 문자열로 채움

# %%
## '<PAD>'라는 key를 0으로 설정
word_vocab = tokenizer.word_index
word_vocab["<PAD>"] = 0    # 0번은 <PAD>로 지정
word_vocab["<PAD>"]
# Out:
# 0

# %%
print('전체 단어 개수:', len(word_vocab))
# Out:
# 전체 단어 개수: 120099

# %% [markdown]
# ### 생성된 Vocabulary 정보를 딕셔너리 (data_configs)로 만들어서 json파일로 저장

# %%
data_configs = {}
data_configs['vocab_size'] = len(word_vocab)
data_configs['vocab'] = word_vocab
data_configs   # 단어사전
# Out:
# {'vocab_size': 120099,
#  'vocab': {'영화': 1,
#   '너무': 2,
#   '진짜': 3,
#   '정말': 4,
#   '잘': 5,
#   '더': 6,
#   '그냥': 7,
#   '다': 8,
#   '다시': 9,
#   '연기': 10,
#   '보고': 11,
#   '봐도': 12,
#   '수': 13,
#   '영화를': 14,
#   '최고의': 15,
#   '봤는데': 16,
#   '영화가': 17,
#   '영화는': 18,
#   '본': 19,
#   '스토리': 20,
#   '재밌게': 21,
#   '역시': 22,
#   '최고': 23,
#   '있는': 24,
#   '이게': 25,
#   '없는': 26,
#   '이렇게': 27,
#   'ㅋㅋ': 28,
#   '많이': 29,
#   '보는': 30,
#   '지금': 31,
#   '한': 32,
#   '내': 33,
#   '평점': 34,
#   '꼭': 35,
#   '볼': 36,
#   '좋은': 37,
#   '내가': 38,
#   '안': 39,
#   '없다': 40,
#   '다시봐도': 41,
#   '마지막': 42,
#   '재밌다': 43,
#   '가장': 44,
#   '봤습니다': 45,
#   '연출': 46,
#   '하는': 47,
#   '연기가': 48,
#   '액션': 49,
#   '모든': 50,
#   '한국': 51,
#   '보면': 52,
#   '마블': 53,
#   '영화관에서': 54,
#   '만든': 55,
#   'ㅋㅋㅋ': 56,
#   '난': 57,
#   '명작': 58,
#   '중': 59,
#   '말이': 60,
#   '같은': 61,
#   '이거': 62,
#   '평점이': 63,
#   '배우들': 64,
#   '감사합니다': 65,
#   '재밌어요': 66,
#   '재미있게': 67,
#   '솔직히': 68,
#   '재밌음': 69,
#   '제일': 70,
#   '근데': 71,
#   '이건': 72,
#   '계속': 73,
#   '인생': 74,
#   '넘': 75,
#   '감동': 76,
#   '영화다': 77,
#   '연기도': 78,
#   '스토리가': 79,
#   '오랜만에': 80,
#   '좋고': 81,
#   '영화입니다': 82,
#   '배우들의': 83,
#   '봤어요': 84,
#   '재밌고': 85,
#   '완전': 86,
#   '연기는': 87,
#   '할': 88,
#   '영화의': 89,
#   '많은': 90,
#   '하고': 91,
#   '보니': 92,
#   '극장에서': 93,
#   '뭐': 94,
#   '작품': 95,
#   '이걸': 96,
#   '내내': 97,
#   '없이': 98,
#   '끝까지': 99,
#   '스토리도': 100,
#   '처음': 101,
#   'ㅋ': 102,
#   '대한': 103,
#   '특히': 104,
#   '볼때마다': 105,
#   '없고': 106,
#   '엄청': 107,
#   '느낌': 108,
#   '인생영화': 109,
#   '아니라': 110,
#   '위해': 111,
#   'ㅎㅎ': 112,
#   '완벽한': 113,
#   '좋았다': 114,
#   '강동원': 115,
#   '아주': 116,
#   '눈물이': 117,
#   '영화에': 118,
#   '스파이더맨': 119,
#   '대한민국': 120,
#   '좋다': 121,
#   '듯': 122,
#   '아직도': 123,
#   '시리즈': 124,
#   '몇번을': 125,
#   '뭔가': 126,
#   '이제': 127,
#   '마지막에': 128,
#   '배우': 129,
#   '재밌는': 130,
#   '재미': 131,
#   '나오는': 132,
#   '최고다': 133,
#   '나는': 134,
#   '봤다': 135,
#   '게': 136,
#   '10점': 137,
#   '않고': 138,
#   '눈물': 139,
#   '못': 140,
#   '가': 141,
#   '봄': 142,
#   '감독': 143,
#   '보면서': 144,
#   '한번': 145,
#   '있고': 146,
#   '하정우': 147,
#   '스토리는': 148,
#   '1': 149,
#   '아이언맨': 150,
#   '거': 151,
#   '한국영화': 152,
#   '다들': 153,
#   '보다가': 154,
#   '없음': 155,
#   '별로': 156,
#   '보세요': 157,
#   '그런': 158,
#   '역사를': 159,
#   '연기를': 160,
#   '되는': 161,
#   '보기': 162,
#   '감독이': 163,
#   '전': 164,
#   '생각이': 165,
#   'ㅋㅋㅋㅋ': 166,
#   '좋아요': 167,
#   '뻔한': 168,
#   '우리나라': 169,
#   '생각보다': 170,
#   '개인적으로': 171,
#   '당시': 172,
#   '제발': 173,
#   '나름': 174,
#   '재밌네요': 175,
#   '이병헌': 176,
#   '이해가': 177,
#   '굿': 178,
#   '쓰레기': 179,
#   '사람들이': 180,
#   '모르고': 181,
#   '줄': 182,
#   '않는': 183,
#   '연기력': 184,
#   '건': 185,
#   '않은': 186,
#   '제대로': 187,
#   '영화로': 188,
#   '걍': 189,
#   '큰': 190,
#   '전혀': 191,
#   '가슴이': 192,
#   '정도로': 193,
#   '보다': 194,
#   '아닌': 195,
#   '영화라고': 196,
#   '사람이': 197,
#   '어벤져스': 198,
#   '송강호': 199,
#   '같아요': 200,
#   '2': 201,
#   '항상': 202,
#   '절대': 203,
#   '주는': 204,
#   '그렇게': 205,
#   '된': 206,
#   '꿀잼': 207,
#   '봤던': 208,
#   '여운이': 209,
#   '위한': 210,
#   '보게': 211,
#   '장면': 212,
#   '이제야': 213,
#   '4': 214,
#   '역사': 215,
#   '두': 216,
#   '만드는': 217,
#   'ㄹㅇ': 218,
#   '는': 219,
#   '감독의': 220,
#   '좋음': 221,
#   '오늘': 222,
#   '감동적인': 223,
#   '억지': 224,
#   '개': 225,
#   '한다': 226,
#   '마음이': 227,
#   '진심': 228,
#   '영상미': 229,
#   '장면이': 230,
#   '새로운': 231,
#   '캐릭터': 232,
#   '번': 233,
#   '이야기': 234,
#   '좋아하는': 235,
#   '중에': 236,
#   '싶다': 237,
#   '좋았어요': 238,
#   '짱': 239,
#   '매우': 240,
#   '도': 241,
#   '영화중': 242,
#   '유아인': 243,
#   '재미가': 244,
#   '재밌었어요': 245,
#   '충분히': 246,
#   '했는데': 247,
#   '잊지': 248,
#   '아쉽다': 249,
#   '유해진': 250,
#   '입니다': 251,
#   '사람': 252,
#   '있지만': 253,
#   '요즘': 254,
#   '보는데': 255,
#   '말': 256,
#   '연출이': 257,
#   '것이': 258,
#   '1점': 259,
#   '멋진': 260,
#   '코미디': 261,
#   '처음부터': 262,
#   '볼만한': 263,
#   '내용이': 264,
#   '이제서야': 265,
#   '현빈': 266,
#   '좋았음': 267,
#   '믿고': 268,
#   '톰': 269,
#   'ㅎ': 270,
#   '좋겠다': 271,
#   '해서': 272,
#   '너무너무': 273,
#   '대박': 274,
#   '봐서': 275,
#   '별': 276,
#   '감동적이고': 277,
#   '훌륭한': 278,
#   '도대체': 279,
#   '걸': 280,
#   '아니고': 281,
#   '히어로': 282,
#   '아님': 283,
#   '3': 284,
#   '재미는': 285,
#   '것도': 286,
#   '것을': 287,
#   '무조건': 288,
#   '있어서': 289,
#   '긴장감': 290,
#   '좋았고': 291,
#   '아무리': 292,
#   '정도': 293,
#   '아니다': 294,
#   '부분이': 295,
#   '안되는': 296,
#   '나도': 297,
#   '다시보니': 298,
#   '5': 299,
#   '보는내내': 300,
#   '시간이': 301,
#   '재미있다': 302,
#   '대해': 303,
#   '기억에': 304,
#   '모든게': 305,
#   '나온': 306,
#   '기대': 307,
#   '봤네요': 308,
#   '주인공': 309,
#   '그대로': 310,
#   '밖에': 311,
#   '영화임': 312,
#   '좋았습니다': 313,
#   '감동을': 314,
#   '재미있는': 315,
#   '누가': 316,
#   '싶은': 317,
#   '재미있어요': 318,
#   '있는데': 319,
#   '사람들': 320,
#   '재밌었음': 321,
#   '아직': 322,
#   '우리가': 323,
#   '이정도면': 324,
#   '천만': 325,
#   '느낌이': 326,
#   '남는': 327,
#   '않는다': 328,
#   '개연성': 329,
#   '갈수록': 330,
#   '영화네요': 331,
#   '재밌는데': 332,
#   '영화인데': 333,
#   '하나도': 334,
#   '최고입니다': 335,
#   '지금도': 336,
#   '비해': 337,
#   '봐도봐도': 338,
#   '저는': 339,
#   '화려한': 340,
#   '좋은데': 341,
#   '역대': 342,
#   '벌써': 343,
#   '알고': 344,
#   '지난': 345,
#   '잘봤습니다': 346,
#   '수가': 347,
#   '보니까': 348,
#   '너무나': 349,
#   '감동이': 350,
#   '영화도': 351,
#   '장면은': 352,
#   '모르겠다': 353,
#   '재미도': 354,
#   '수작': 355,
#   '있음': 356,
#   '같음': 357,
#   '기억이': 358,
#   '액션도': 359,
#   '소름': 360,
#   '해도': 361,
#   '생각': 362,
#   '지금봐도': 363,
#   '이순신': 364,
#   '캡틴': 365,
#   '재미있고': 366,
#   '엄청난': 367,
#   '존나': 368,
#   '사람들은': 369,
#   '내용': 370,
#   '넘게': 371,
#   '명작이다': 372,
#   '제가': 373,
#   '영화에서': 374,
#   '최악의': 375,
#   '믿고보는': 376,
#   '언제봐도': 377,
#   '나왔으면': 378,
#   '역대급': 379,
#   '수준': 380,
#   '잘만든': 381,
#   '나와서': 382,
#   '진정한': 383,
#   '노잼': 384,
#   '때마다': 385,
#   '개봉': 386,
#   '영화였습니다': 387,
#   '될': 388,
#   '영화였다': 389,
#   '좋네요': 390,
#   '있을까': 391,
#   '액션이': 392,
#   '재밌네': 393,
#   '없어서': 394,
#   '감동도': 395,
#   '봤음': 396,
#   '같은데': 397,
#   '했다': 398,
#   '대단한': 399,
#   '확실히': 400,
#   '보여주는': 401,
#   '봤을': 402,
#   '전형적인': 403,
#   '재밌습니다': 404,
#   '사람은': 405,
#   '봤지만': 406,
#   '8': 407,
#   '음악': 408,
#   '슬프고': 409,
#   '앞으로': 410,
#   '굉장히': 411,
#   '전개': 412,
#   '지금까지': 413,
#   '아깝다': 414,
#   '연출도': 415,
#   '중간중간': 416,
#   '볼만함': 417,
#   '아쉬운': 418,
#   '연기와': 419,
#   '된다': 420,
#   '이영화를': 421,
#   '중간에': 422,
#   '없었다': 423,
#   '액션은': 424,
#   '내용도': 425,
#   '몰입도': 426,
#   '감독은': 427,
#   '대사': 428,
#   '뭔': 429,
#   '신파': 430,
#   '본다': 431,
#   '실제': 432,
#   '갑자기': 433,
#   '했지만': 434,
#   '스토리를': 435,
#   '괜찮은': 436,
#   '봉준호': 437,
#   '나라를': 438,
#   '만들어': 439,
#   '간만에': 440,
#   '라는': 441,
#   '내용은': 442,
#   '저런': 443,
#   '합니다': 444,
#   '그런지': 445,
#   '후': 446,
#   '재밌었다': 447,
#   '스토리에': 448,
#   '디즈니': 449,
#   '10년이': 450,
#   '미친': 451,
#   '그렇고': 452,
#   '하면': 453,
#   '티비에서': 454,
#   '배우의': 455,
#   '스토리와': 456,
#   '결말이': 457,
#   '하지': 458,
#   '더욱': 459,
#   '가볍게': 460,
#   '꽤': 461,
#   '나오면': 462,
#   '대사가': 463,
#   '이유가': 464,
#   '추천': 465,
#   '대체': 466,
#   '이딴': 467,
#   '질리지': 468,
#   '생각함': 469,
#   '배우들이': 470,
#   '말도': 471,
#   '급': 472,
#   '영화라': 473,
#   '준': 474,
#   '가는': 475,
#   '않다': 476,
#   '별점': 477,
#   '생각을': 478,
#   '보지': 479,
#   '돈': 480,
#   '레전드': 481,
#   '않음': 482,
#   '굳이': 483,
#   '마동석': 484,
#   '완벽': 485,
#   '노래': 486,
#   '지루한': 487,
#   '덕분에': 488,
#   '필요': 489,
#   '이미': 490,
#   'ㄷㄷ': 491,
#   '높은': 492,
#   '미쳤다': 493,
#   '연기력이': 494,
#   '추천합니다': 495,
#   '1편': 496,
#   '생각나서': 497,
#   '재난': 498,
#   '것은': 499,
#   '크게': 500,
#   '빨리': 501,
#   '원래': 502,
#   '있었다': 503,
#   '주고': 504,
#   '못한': 505,
#   '사실': 506,
#   '시리즈는': 507,
#   '미션': 508,
#   '모르는': 509,
#   '이영화는': 510,
#   '나의': 511,
#   '그게': 512,
#   '함': 513,
#   '우리의': 514,
#   '말고': 515,
#   '강추': 516,
#   '되게': 517,
#   '재미있음': 518,
#   '집에서': 519,
#   '가지고': 520,
#   '생각합니다': 521,
#   '전에': 522,
#   '사랑해': 523,
#   '겁나': 524,
#   '최악': 525,
#   '마블의': 526,
#   '알': 527,
#   '생각한다': 528,
#   '두번': 529,
#   '지금의': 530,
#   '마음에': 531,
#   '같습니다': 532,
#   '봤는데도': 533,
#   '펑펑': 534,
#   '이영화': 535,
#   '언제나': 536,
#   '전지현': 537,
#   '쥬라기': 538,
#   '평점을': 539,
#   '명작입니다': 540,
#   '눈물을': 541,
#   '가서': 542,
#   '몰입감': 543,
#   '배우가': 544,
#   '좋아서': 545,
#   '처음으로': 546,
#   '이후': 547,
#   '결말': 548,
#   '트랜스포머': 549,
#   '전개가': 550,
#   '정우성': 551,
#   '살짝': 552,
#   '있어': 553,
#   '그럭저럭': 554,
#   '존잼': 555,
#   '캐스팅': 556,
#   '개연성이': 557,
#   '판타지': 558,
#   '있게': 559,
#   '든다': 560,
#   '자체가': 561,
#   '않았다': 562,
#   '아닌가': 563,
#   '지루하지': 564,
#   '명복을': 565,
#   '저렇게': 566,
#   '기분': 567,
#   '특유의': 568,
#   '하다': 569,
#   '영화중에': 570,
#   '만': 571,
#   '안하고': 572,
#   '뭐가': 573,
#   '북한': 574,
#   '원빈': 575,
#   '가슴': 576,
#   '있습니다': 577,
#   '그나마': 578,
#   '뭘': 579,
#   '보여준': 580,
#   '젤': 581,
#   '전체적으로': 582,
#   '눈이': 583,
#   '점점': 584,
#   '나올': 585,
#   '영상': 586,
#   '재개봉': 587,
#   '봐야': 588,
#   '잘하고': 589,
#   '많아서': 590,
#   '빕니다': 591,
#   '우리는': 592,
#   '없을': 593,
#   '탄탄한': 594,
#   '2편': 595,
#   '영화지만': 596,
#   '번을': 597,
#   '재밌어서': 598,
#   '연기에': 599,
#   '않겠습니다': 600,
#   '기대를': 601,
#   '봤었는데': 602,
#   '7': 603,
#   '억지로': 604,
#   '재미없다': 605,
#   '8점': 606,
#   '멋있다': 607,
#   '개꿀잼': 608,
#   '없는데': 609,
#   '황정민': 610,
#   '스파이더맨이': 611,
#   '필요없는': 612,
#   '빼고': 613,
#   '여러번': 614,
#   '울었다': 615,
#   '있을': 616,
#   '대한민국의': 617,
#   '시작': 618,
#   '느낄': 619,
#   '지나도': 620,
#   '자체': 621,
#   '영화보고': 622,
#   '나쁘지': 623,
#   '없네': 624,
#   '만든다': 625,
#   '그걸': 626,
#   '슬프다': 627,
#   '마블은': 628,
#   '아름다운': 629,
#   '시간가는줄': 630,
#   '영화이다': 631,
#   '모두가': 632,
#   '멋있고': 633,
#   '자꾸': 634,
#   '좋았는데': 635,
#   '웃기고': 636,
#   '첫': 637,
#   '시대를': 638,
#   '지금은': 639,
#   '미션임파서블': 640,
#   '볼수록': 641,
#   '만들었다': 642,
#   '1편이': 643,
#   '연출은': 644,
#   '늘': 645,
#   '아포칼립토': 646,
#   '이야기를': 647,
#   '5점': 648,
#   '킬링타임용': 649,
#   '오락영화': 650,
#   '드라마': 651,
#   '사람을': 652,
#   '영화에요': 653,
#   '손예진': 654,
#   '봅니다': 655,
#   '있다는': 656,
#   '봐야할': 657,
#   '지루하고': 658,
#   '가족': 659,
#   '않게': 660,
#   '인간의': 661,
#   '아닌데': 662,
#   '재미와': 663,
#   '놀란': 664,
#   '난다': 665,
#   '생각없이': 666,
#   '연출과': 667,
#   '하는데': 668,
#   '단': 669,
#   '슬픈': 670,
#   '되고': 671,
#   '빨갱이': 672,
#   '와칸다': 673,
#   '실제로': 674,
#   '알게': 675,
#   '1도': 676,
#   '지': 677,
#   '감동과': 678,
#   '다시한번': 679,
#   '감독님': 680,
#   '필요없다': 681,
#   '토니': 682,
#   '깊은': 683,
#   '연기력은': 684,
#   '통해': 685,
#   '상당히': 686,
#   '손에': 687,
#   '눈을': 688,
#   '이해': 689,
#   '액션과': 690,
#   '코믹': 691,
#   '지루할': 692,
#   '너무나도': 693,
#   '아까운': 694,
#   '것이다': 695,
#   '아쉬움': 696,
#   '한국형': 697,
#   '한국의': 698,
#   '힘든': 699,
#   '포에버': 700,
#   '시리즈가': 701,
#   '박보영': 702,
#   '예전에': 703,
#   '해주는': 704,
#   '시대에': 705,
#   '대단하다': 706,
#   '이후로': 707,
#   '아닐까': 708,
#   'ㅉㅉ': 709,
#   '안된다': 710,
#   '평론가': 711,
#   '모습이': 712,
#   '공룡': 713,
#   '재밌어': 714,
#   '준다': 715,
#   '이유': 716,
#   '아픈': 717,
#   '여자': 718,
#   '뿐': 719,
#   '시리즈중': 720,
#   '떠나서': 721,
#   '몰입해서': 722,
#   '남을': 723,
#   '됨': 724,
#   '나만': 725,
#   '다시는': 726,
#   '매력적인': 727,
#   '듯한': 728,
#   '재밌었는데': 729,
#   '주인공이': 730,
#   '전율이': 731,
#   '진심으로': 732,
#   '알았는데': 733,
#   '1편보다': 734,
#   '소재를': 735,
#   '재밌다고': 736,
#   '분들': 737,
#   '같아서': 738,
#   '라고': 739,
#   '배우들도': 740,
#   '3번': 741,
#   '주연': 742,
#   '봤으면': 743,
#   '끝': 744,
#   '유치하고': 745,
#   '처럼': 746,
#   '말로': 747,
#   '마무리': 748,
#   'ㅎㅎㅎ': 749,
#   '조인성': 750,
#   '적당히': 751,
#   '현실을': 752,
#   '이런게': 753,
#   '작품이': 754,
#   '뛰어난': 755,
#   '캐릭터가': 756,
#   '굿굿': 757,
#   '방금': 758,
#   '재미있네요': 759,
#   '아니지만': 760,
#   '보다니': 761,
#   '왜케': 762,
#   '초반에': 763,
#   '내용을': 764,
#   '6': 765,
#   '노래가': 766,
#   '먼저': 767,
#   '나서': 768,
#   '재미를': 769,
#   '왜이리': 770,
#   '9점': 771,
#   '현실': 772,
#   '낫다': 773,
#   '초반': 774,
#   '엔드게임': 775,
#   '시리즈를': 776,
#   '이정재': 777,
#   '임파서블': 778,
#   '강동원의': 779,
#   '단연': 780,
#   '역사적': 781,
#   '나라': 782,
#   '마음을': 783,
#   '현재': 784,
#   '보았습니다': 785,
#   '많고': 786,
#   '한국에서': 787,
#   '그냥저냥': 788,
#   '이병헌의': 789,
#   '윤아': 790,
#   '톰크루즈': 791,
#   '이리': 792,
#   '뒤늦게': 793,
#   '소재로': 794,
#   '영화인': 795,
#   '있었던': 796,
#   'ㅈㄴ': 797,
#   '음': 798,
#   '보고나서': 799,
#   '못하는': 800,
#   '여러': 801,
#   '봐야하는': 802,
#   '나중에': 803,
#   '김수현': 804,
#   '김아중': 805,
#   '배우님': 806,
#   '역사에': 807,
#   '9': 808,
#   '생각했는데': 809,
#   '수준이': 810,
#   '재밌었습니다': 811,
#   '같아': 812,
#   '같네요': 813,
#   '아쉽지만': 814,
#   '막': 815,
#   '울고': 816,
#   '순간': 817,
#   '속': 818,
#   '2편은': 819,
#   '여기서': 820,
#   '탄탄하고': 821,
#   '얼굴': 822,
#   '날': 823,
#   '그들의': 824,
#   '그런가': 825,
#   '수많은': 826,
#   '몰입이': 827,
#   '만들어진': 828,
#   '최고임': 829,
#   '못하고': 830,
#   '몰랐는데': 831,
#   '나온다': 832,
#   '아무': 833,
#   '자신의': 834,
#   '원작': 835,
#   '있었지만': 836,
#   '수도': 837,
#   '눈': 838,
#   '지루함': 839,
#   '무엇보다': 840,
#   '봤는지': 841,
#   '영화보다': 842,
#   '있다면': 843,
#   '봤을까': 844,
#   '봤고': 845,
#   '자체는': 846,
#   '잘함': 847,
#   '없네요': 848,
#   '완벽하다': 849,
#   '7점': 850,
#   '괜히': 851,
#   '보고싶다': 852,
#   '남는다': 853,
#   '최고였다': 854,
#   '표절': 855,
#   '배트맨': 856,
#   '위대한': 857,
#   '몰입도가': 858,
#   '이정도': 859,
#   '사랑해요': 860,
#   '또봐도': 861,
#   '재미없음': 862,
#   '때는': 863,
#   '킬링타임용으로': 864,
#   '부족한': 865,
#   '둘다': 866,
#   '후반부': 867,
#   '1편은': 868,
#   '나오고': 869,
#   '그리': 870,
#   '살고': 871,
#   '살면서': 872,
#   '영화라는': 873,
#   '김윤석': 874,
#   '고인의': 875,
#   '재난영화': 876,
#   '국뽕': 877,
#   '뮤지컬': 878,
#   '없지만': 879,
#   '도저히': 880,
#   '배우분들': 881,
#   '시나리오': 882,
#   '어설픈': 883,
#   '각본': 884,
#   '아저씨': 885,
#   '한국판': 886,
#   '다시봤는데': 887,
#   '그만': 888,
#   '케미': 889,
#   '비슷한': 890,
#   '봐야지': 891,
#   '긴장감이': 892,
#   '굳': 893,
#   '조승우': 894,
#   '강동원이': 895,
#   '분명': 896,
#   '아쉽네요': 897,
#   '이유는': 898,
#   '말할': 899,
#   '그닥': 900,
#   '유쾌한': 901,
#   '사람들의': 902,
#   '삶을': 903,
#   '6점': 904,
#   '잘한다': 905,
#   '넘치는': 906,
#   '느껴지는': 907,
#   '이영화가': 908,
#   '흠': 909,
#   '뭐지': 910,
#   '액션영화': 911,
#   '보시길': 912,
#   '가끔': 913,
#   '아무것도': 914,
#   '웃고': 915,
#   '아는': 916,
#   '평점은': 917,
#   '내인생': 918,
#   '중간': 919,
#   '역시나': 920,
#   '다크나이트': 921,
#   '스파이더맨은': 922,
#   '송중기': 923,
#   '시절': 924,
#   '안보고': 925,
#   '되었다': 926,
#   '감동은': 927,
#   '안에': 928,
#   '애들': 929,
#   '먹고': 930,
#   '영화관': 931,
#   '이야기가': 932,
#   '현실적인': 933,
#   '느끼게': 934,
#   '없어': 935,
#   '모습을': 936,
#   '10년': 937,
#   '아이언맨이': 938,
#   '영화들': 939,
#   '노래도': 940,
#   '오락': 941,
#   '만들고': 942,
#   '전쟁': 943,
#   '기대하고': 944,
#   '않을': 945,
#   '감동입니다': 946,
#   '부분도': 947,
#   '보이는': 948,
#   '생각하고': 949,
#   '즐겁게': 950,
#   '없습니다': 951,
#   '되어': 952,
#   '없어요': 953,
#   '어디서': 954,
#   '본듯': 955,
#   '유치한': 956,
#   '드는': 957,
#   '그만큼': 958,
#   '보며': 959,
#   '재미있었습니다': 960,
#   '어린': 961,
#   '마블이': 962,
#   '재미있습니다': 963,
#   '매력이': 964,
#   '하게': 965,
#   '옛날': 966,
#   '일본': 967,
#   '2시간': 968,
#   '해': 969,
#   '속편': 970,
#   '1점도': 971,
#   '웃음': 972,
#   '신선한': 973,
#   '우리나라의': 974,
#   '마음': 975,
#   '떨어지는': 976,
#   '유쾌하고': 977,
#   '하나하나': 978,
#   '마블영화': 979,
#   '완벽하게': 980,
#   '1이': 981,
#   '보았다': 982,
#   '맘에': 983,
#   '사극': 984,
#   '한국영화의': 985,
#   '감사드립니다': 986,
#   '딱히': 987,
#   '정말로': 988,
#   '반전': 989,
#   '평생': 990,
#   '좋습니다': 991,
#   '유일하게': 992,
#   '18': 993,
#   '보인다': 994,
#   '해준': 995,
#   '안됨': 996,
#   '영원히': 997,
#   '엔딩': 998,
#   '평이': 999,
#   '설정': 1000,
#   ...}}

# %% [markdown]
# ### 전처리 마지막 단계
# * 각 리뷰 벡터의 길이를 통일
# * 특정 길이를 최대 길이로 정하고
#     * 더 긴 벡터의 경우 뒷부분을 자르고...
#     * 짧은 데이터의 경우 빈 공간을 0으로 패딩

# %%
train_word_counts
# Out:
# 0         7
# 1         5
# 2        15
# 3        14
# 4        14
#          ..
# 49995     9
# 49996     7
# 49997    18
# 49998     5
# 49999     4
# Name: 리뷰, Length: 50000, dtype: int64

# %%
# 정제되지 않은 리뷰 문장을 split으로 분리한 리뷰당 단어 수의 중간값
np.median(train_word_counts)
# Out:
# 7.0

# %%
# 정제된 리뷰 문장 기준 중간값
train_token_counts = np.array([len(vectorized_review) for vectorized_review in text_sequences])
np.median(train_token_counts)
# Out:
# 6.0

# %%
## 리뷰당 단어 수의 중간값을 벡터의 최대 길이로 세팅
MAX_SEQUENCES_LENGTH = 7  # np.median(train_word_counts) = 174

# %%
## PADDING (keras에서 가져온 pad_sequences 활용)
train_inputs = pad_sequences(text_sequences, maxlen=MAX_SEQUENCES_LENGTH, padding='post')   # 뒤쪽을 0으로 패딩
# train_inputs = pad_sequences(text_sequences, maxlen=MAX_SEQUENCES_LENGTH, padding='pre')      # 앞쪽을 0으로 패딩
train_inputs.shape, train_inputs
# Out:
# ((50000, 7),
#  array([[  2321,  19732,   1785, ...,   2987,   3922,  19733],
#         [ 19734,  14347,     92, ...,    390,      0,      0],
#         [     6,      5,    942, ...,   9389,  19735,      1],
#         ...,
#         [120096,      6,  10056, ...,   1206,    188,    465],
#         [   243,   1358,   2605, ...,      0,      0,      0],
#         [   901, 120098,   9245, ...,      0,      0,      0]]))

# %%
## 벡터화된 리뷰 문장 확인
train_inputs[1]
# Out:
# array([19734, 14347,    92,     6,   390,     0,     0])

# %%
train_labels = train_data['sentiment'].to_numpy()
train_labels
# Out:
# array(['긍정', '긍정', '긍정', ..., '긍정', '중립', '중립'], dtype=object)

# %% [markdown]
# ### 정제된 데이터 저장

# %%
DATA_IN_PATH = 'd:/data/project/'

# %%
# 저장할 파일 이름 정의
# TRAIN_INPUT_DATA = 'train_input.npy'  # 벡터화된 데이터 : numpy array를 binary로 저장
# TRAIN_LABEL_DATA = 'train_label.npy'  # 정답 라벨 : numpy array를 binary로 저장
# TRAIN_CLEAN_DATA = 'train_clean.csv'  # 정제된 텍스트 데이터 : CSV 파일
# DATA_CONFIGS = 'data_configs.json'    # 데이터 정보(단어사전, 전체 단어 개수) : JSON 파일

import os
# 저장하는 디렉토리가 존재하지 않으면 생성
if not os.path.exists(DATA_IN_PATH):
    os.makedirs(DATA_IN_PATH)

# %%
## 전처리하여 벡터화된 데이터를 넘파이 형태로 저장 (binary file 형태)
np.save(open(DATA_IN_PATH + 'train_input.npy', 'wb'), train_inputs)  # 벡터화된 데이터 : numpy array를 binary로 저장
np.save(open(DATA_IN_PATH + 'train_label.npy', 'wb'), train_labels)  # 정답 라벨 : numpy array를 binary로 저장

# %%
# 정제된 텍스트를 csv 형태로 저장
clean_train_df.to_csv(DATA_IN_PATH + 'train_clean.csv')  # 정제된 텍스트 데이터 : CSV 파일
clean_train_df
# Out:
#                                                   review sentiment
# 0                             여기에 말같잖은 평 다는 놈들은 매국노 인증인듯        긍정
# 1                                  다좋았어요 한산보고나서 보니 더 좋네요        긍정
# 2      한국영화의 전성기 시절 전무후무한 기록을 남겨준 영화 기대했던 것보다 더 잘 만들고...        긍정
# 3      2번째본 역사영화 진짜 이순신은 대단한 영웅중에 영웅 보는내내 끝까지 긴장놓을수없고...        긍정
# 4      정말 거짓말 안한다 클레멘타인에 대한 평가를 호평으로 오해했으면 관객수가 이리 나왔...        부정
# ...                                                  ...       ...
# 49995                  훈훈하고 괜찮은 영화 김윤석 너무 좋고 유아인도 아주 잘한다        긍정
# 49996                        죽어가는 뻔한 스토리를 두 주연이 인공호흡 해놨다        중립
# 49997  김윤석의 연기 짱 툭툭 던지는 말투가 빵터지게 인간적이네요 전 유아인보다 김윤석씨가...        긍정
# 49998                                    유아인 일부러 찾아서 봤네요        중립
# 49999                                    유쾌한 앙상블을 망치는 연출        중립
#
# [50000 rows x 2 columns]

# %%
## 데이터 사전을 json형태로 저장
f = open(DATA_IN_PATH + 'data_configs.json', 'w')
json.dump(data_configs, f, ensure_ascii=False)
f.close()
# ensure_ascii가 True이면... ascii가 아닌 다른 문자들은 모두 이스케이프 문자(\)로 표현됨
# 반면, ensure_ascii를 False로 하면, Ascii에 포함되지 않는 문자들도 모두 출력
data_configs
# Out:
# {'vocab_size': 120099,
#  'vocab': {'영화': 1,
#   '너무': 2,
#   '진짜': 3,
#   '정말': 4,
#   '잘': 5,
#   '더': 6,
#   '그냥': 7,
#   '다': 8,
#   '다시': 9,
#   '연기': 10,
#   '보고': 11,
#   '봐도': 12,
#   '수': 13,
#   '영화를': 14,
#   '최고의': 15,
#   '봤는데': 16,
#   '영화가': 17,
#   '영화는': 18,
#   '본': 19,
#   '스토리': 20,
#   '재밌게': 21,
#   '역시': 22,
#   '최고': 23,
#   '있는': 24,
#   '이게': 25,
#   '없는': 26,
#   '이렇게': 27,
#   'ㅋㅋ': 28,
#   '많이': 29,
#   '보는': 30,
#   '지금': 31,
#   '한': 32,
#   '내': 33,
#   '평점': 34,
#   '꼭': 35,
#   '볼': 36,
#   '좋은': 37,
#   '내가': 38,
#   '안': 39,
#   '없다': 40,
#   '다시봐도': 41,
#   '마지막': 42,
#   '재밌다': 43,
#   '가장': 44,
#   '봤습니다': 45,
#   '연출': 46,
#   '하는': 47,
#   '연기가': 48,
#   '액션': 49,
#   '모든': 50,
#   '한국': 51,
#   '보면': 52,
#   '마블': 53,
#   '영화관에서': 54,
#   '만든': 55,
#   'ㅋㅋㅋ': 56,
#   '난': 57,
#   '명작': 58,
#   '중': 59,
#   '말이': 60,
#   '같은': 61,
#   '이거': 62,
#   '평점이': 63,
#   '배우들': 64,
#   '감사합니다': 65,
#   '재밌어요': 66,
#   '재미있게': 67,
#   '솔직히': 68,
#   '재밌음': 69,
#   '제일': 70,
#   '근데': 71,
#   '이건': 72,
#   '계속': 73,
#   '인생': 74,
#   '넘': 75,
#   '감동': 76,
#   '영화다': 77,
#   '연기도': 78,
#   '스토리가': 79,
#   '오랜만에': 80,
#   '좋고': 81,
#   '영화입니다': 82,
#   '배우들의': 83,
#   '봤어요': 84,
#   '재밌고': 85,
#   '완전': 86,
#   '연기는': 87,
#   '할': 88,
#   '영화의': 89,
#   '많은': 90,
#   '하고': 91,
#   '보니': 92,
#   '극장에서': 93,
#   '뭐': 94,
#   '작품': 95,
#   '이걸': 96,
#   '내내': 97,
#   '없이': 98,
#   '끝까지': 99,
#   '스토리도': 100,
#   '처음': 101,
#   'ㅋ': 102,
#   '대한': 103,
#   '특히': 104,
#   '볼때마다': 105,
#   '없고': 106,
#   '엄청': 107,
#   '느낌': 108,
#   '인생영화': 109,
#   '아니라': 110,
#   '위해': 111,
#   'ㅎㅎ': 112,
#   '완벽한': 113,
#   '좋았다': 114,
#   '강동원': 115,
#   '아주': 116,
#   '눈물이': 117,
#   '영화에': 118,
#   '스파이더맨': 119,
#   '대한민국': 120,
#   '좋다': 121,
#   '듯': 122,
#   '아직도': 123,
#   '시리즈': 124,
#   '몇번을': 125,
#   '뭔가': 126,
#   '이제': 127,
#   '마지막에': 128,
#   '배우': 129,
#   '재밌는': 130,
#   '재미': 131,
#   '나오는': 132,
#   '최고다': 133,
#   '나는': 134,
#   '봤다': 135,
#   '게': 136,
#   '10점': 137,
#   '않고': 138,
#   '눈물': 139,
#   '못': 140,
#   '가': 141,
#   '봄': 142,
#   '감독': 143,
#   '보면서': 144,
#   '한번': 145,
#   '있고': 146,
#   '하정우': 147,
#   '스토리는': 148,
#   '1': 149,
#   '아이언맨': 150,
#   '거': 151,
#   '한국영화': 152,
#   '다들': 153,
#   '보다가': 154,
#   '없음': 155,
#   '별로': 156,
#   '보세요': 157,
#   '그런': 158,
#   '역사를': 159,
#   '연기를': 160,
#   '되는': 161,
#   '보기': 162,
#   '감독이': 163,
#   '전': 164,
#   '생각이': 165,
#   'ㅋㅋㅋㅋ': 166,
#   '좋아요': 167,
#   '뻔한': 168,
#   '우리나라': 169,
#   '생각보다': 170,
#   '개인적으로': 171,
#   '당시': 172,
#   '제발': 173,
#   '나름': 174,
#   '재밌네요': 175,
#   '이병헌': 176,
#   '이해가': 177,
#   '굿': 178,
#   '쓰레기': 179,
#   '사람들이': 180,
#   '모르고': 181,
#   '줄': 182,
#   '않는': 183,
#   '연기력': 184,
#   '건': 185,
#   '않은': 186,
#   '제대로': 187,
#   '영화로': 188,
#   '걍': 189,
#   '큰': 190,
#   '전혀': 191,
#   '가슴이': 192,
#   '정도로': 193,
#   '보다': 194,
#   '아닌': 195,
#   '영화라고': 196,
#   '사람이': 197,
#   '어벤져스': 198,
#   '송강호': 199,
#   '같아요': 200,
#   '2': 201,
#   '항상': 202,
#   '절대': 203,
#   '주는': 204,
#   '그렇게': 205,
#   '된': 206,
#   '꿀잼': 207,
#   '봤던': 208,
#   '여운이': 209,
#   '위한': 210,
#   '보게': 211,
#   '장면': 212,
#   '이제야': 213,
#   '4': 214,
#   '역사': 215,
#   '두': 216,
#   '만드는': 217,
#   'ㄹㅇ': 218,
#   '는': 219,
#   '감독의': 220,
#   '좋음': 221,
#   '오늘': 222,
#   '감동적인': 223,
#   '억지': 224,
#   '개': 225,
#   '한다': 226,
#   '마음이': 227,
#   '진심': 228,
#   '영상미': 229,
#   '장면이': 230,
#   '새로운': 231,
#   '캐릭터': 232,
#   '번': 233,
#   '이야기': 234,
#   '좋아하는': 235,
#   '중에': 236,
#   '싶다': 237,
#   '좋았어요': 238,
#   '짱': 239,
#   '매우': 240,
#   '도': 241,
#   '영화중': 242,
#   '유아인': 243,
#   '재미가': 244,
#   '재밌었어요': 245,
#   '충분히': 246,
#   '했는데': 247,
#   '잊지': 248,
#   '아쉽다': 249,
#   '유해진': 250,
#   '입니다': 251,
#   '사람': 252,
#   '있지만': 253,
#   '요즘': 254,
#   '보는데': 255,
#   '말': 256,
#   '연출이': 257,
#   '것이': 258,
#   '1점': 259,
#   '멋진': 260,
#   '코미디': 261,
#   '처음부터': 262,
#   '볼만한': 263,
#   '내용이': 264,
#   '이제서야': 265,
#   '현빈': 266,
#   '좋았음': 267,
#   '믿고': 268,
#   '톰': 269,
#   'ㅎ': 270,
#   '좋겠다': 271,
#   '해서': 272,
#   '너무너무': 273,
#   '대박': 274,
#   '봐서': 275,
#   '별': 276,
#   '감동적이고': 277,
#   '훌륭한': 278,
#   '도대체': 279,
#   '걸': 280,
#   '아니고': 281,
#   '히어로': 282,
#   '아님': 283,
#   '3': 284,
#   '재미는': 285,
#   '것도': 286,
#   '것을': 287,
#   '무조건': 288,
#   '있어서': 289,
#   '긴장감': 290,
#   '좋았고': 291,
#   '아무리': 292,
#   '정도': 293,
#   '아니다': 294,
#   '부분이': 295,
#   '안되는': 296,
#   '나도': 297,
#   '다시보니': 298,
#   '5': 299,
#   '보는내내': 300,
#   '시간이': 301,
#   '재미있다': 302,
#   '대해': 303,
#   '기억에': 304,
#   '모든게': 305,
#   '나온': 306,
#   '기대': 307,
#   '봤네요': 308,
#   '주인공': 309,
#   '그대로': 310,
#   '밖에': 311,
#   '영화임': 312,
#   '좋았습니다': 313,
#   '감동을': 314,
#   '재미있는': 315,
#   '누가': 316,
#   '싶은': 317,
#   '재미있어요': 318,
#   '있는데': 319,
#   '사람들': 320,
#   '재밌었음': 321,
#   '아직': 322,
#   '우리가': 323,
#   '이정도면': 324,
#   '천만': 325,
#   '느낌이': 326,
#   '남는': 327,
#   '않는다': 328,
#   '개연성': 329,
#   '갈수록': 330,
#   '영화네요': 331,
#   '재밌는데': 332,
#   '영화인데': 333,
#   '하나도': 334,
#   '최고입니다': 335,
#   '지금도': 336,
#   '비해': 337,
#   '봐도봐도': 338,
#   '저는': 339,
#   '화려한': 340,
#   '좋은데': 341,
#   '역대': 342,
#   '벌써': 343,
#   '알고': 344,
#   '지난': 345,
#   '잘봤습니다': 346,
#   '수가': 347,
#   '보니까': 348,
#   '너무나': 349,
#   '감동이': 350,
#   '영화도': 351,
#   '장면은': 352,
#   '모르겠다': 353,
#   '재미도': 354,
#   '수작': 355,
#   '있음': 356,
#   '같음': 357,
#   '기억이': 358,
#   '액션도': 359,
#   '소름': 360,
#   '해도': 361,
#   '생각': 362,
#   '지금봐도': 363,
#   '이순신': 364,
#   '캡틴': 365,
#   '재미있고': 366,
#   '엄청난': 367,
#   '존나': 368,
#   '사람들은': 369,
#   '내용': 370,
#   '넘게': 371,
#   '명작이다': 372,
#   '제가': 373,
#   '영화에서': 374,
#   '최악의': 375,
#   '믿고보는': 376,
#   '언제봐도': 377,
#   '나왔으면': 378,
#   '역대급': 379,
#   '수준': 380,
#   '잘만든': 381,
#   '나와서': 382,
#   '진정한': 383,
#   '노잼': 384,
#   '때마다': 385,
#   '개봉': 386,
#   '영화였습니다': 387,
#   '될': 388,
#   '영화였다': 389,
#   '좋네요': 390,
#   '있을까': 391,
#   '액션이': 392,
#   '재밌네': 393,
#   '없어서': 394,
#   '감동도': 395,
#   '봤음': 396,
#   '같은데': 397,
#   '했다': 398,
#   '대단한': 399,
#   '확실히': 400,
#   '보여주는': 401,
#   '봤을': 402,
#   '전형적인': 403,
#   '재밌습니다': 404,
#   '사람은': 405,
#   '봤지만': 406,
#   '8': 407,
#   '음악': 408,
#   '슬프고': 409,
#   '앞으로': 410,
#   '굉장히': 411,
#   '전개': 412,
#   '지금까지': 413,
#   '아깝다': 414,
#   '연출도': 415,
#   '중간중간': 416,
#   '볼만함': 417,
#   '아쉬운': 418,
#   '연기와': 419,
#   '된다': 420,
#   '이영화를': 421,
#   '중간에': 422,
#   '없었다': 423,
#   '액션은': 424,
#   '내용도': 425,
#   '몰입도': 426,
#   '감독은': 427,
#   '대사': 428,
#   '뭔': 429,
#   '신파': 430,
#   '본다': 431,
#   '실제': 432,
#   '갑자기': 433,
#   '했지만': 434,
#   '스토리를': 435,
#   '괜찮은': 436,
#   '봉준호': 437,
#   '나라를': 438,
#   '만들어': 439,
#   '간만에': 440,
#   '라는': 441,
#   '내용은': 442,
#   '저런': 443,
#   '합니다': 444,
#   '그런지': 445,
#   '후': 446,
#   '재밌었다': 447,
#   '스토리에': 448,
#   '디즈니': 449,
#   '10년이': 450,
#   '미친': 451,
#   '그렇고': 452,
#   '하면': 453,
#   '티비에서': 454,
#   '배우의': 455,
#   '스토리와': 456,
#   '결말이': 457,
#   '하지': 458,
#   '더욱': 459,
#   '가볍게': 460,
#   '꽤': 461,
#   '나오면': 462,
#   '대사가': 463,
#   '이유가': 464,
#   '추천': 465,
#   '대체': 466,
#   '이딴': 467,
#   '질리지': 468,
#   '생각함': 469,
#   '배우들이': 470,
#   '말도': 471,
#   '급': 472,
#   '영화라': 473,
#   '준': 474,
#   '가는': 475,
#   '않다': 476,
#   '별점': 477,
#   '생각을': 478,
#   '보지': 479,
#   '돈': 480,
#   '레전드': 481,
#   '않음': 482,
#   '굳이': 483,
#   '마동석': 484,
#   '완벽': 485,
#   '노래': 486,
#   '지루한': 487,
#   '덕분에': 488,
#   '필요': 489,
#   '이미': 490,
#   'ㄷㄷ': 491,
#   '높은': 492,
#   '미쳤다': 493,
#   '연기력이': 494,
#   '추천합니다': 495,
#   '1편': 496,
#   '생각나서': 497,
#   '재난': 498,
#   '것은': 499,
#   '크게': 500,
#   '빨리': 501,
#   '원래': 502,
#   '있었다': 503,
#   '주고': 504,
#   '못한': 505,
#   '사실': 506,
#   '시리즈는': 507,
#   '미션': 508,
#   '모르는': 509,
#   '이영화는': 510,
#   '나의': 511,
#   '그게': 512,
#   '함': 513,
#   '우리의': 514,
#   '말고': 515,
#   '강추': 516,
#   '되게': 517,
#   '재미있음': 518,
#   '집에서': 519,
#   '가지고': 520,
#   '생각합니다': 521,
#   '전에': 522,
#   '사랑해': 523,
#   '겁나': 524,
#   '최악': 525,
#   '마블의': 526,
#   '알': 527,
#   '생각한다': 528,
#   '두번': 529,
#   '지금의': 530,
#   '마음에': 531,
#   '같습니다': 532,
#   '봤는데도': 533,
#   '펑펑': 534,
#   '이영화': 535,
#   '언제나': 536,
#   '전지현': 537,
#   '쥬라기': 538,
#   '평점을': 539,
#   '명작입니다': 540,
#   '눈물을': 541,
#   '가서': 542,
#   '몰입감': 543,
#   '배우가': 544,
#   '좋아서': 545,
#   '처음으로': 546,
#   '이후': 547,
#   '결말': 548,
#   '트랜스포머': 549,
#   '전개가': 550,
#   '정우성': 551,
#   '살짝': 552,
#   '있어': 553,
#   '그럭저럭': 554,
#   '존잼': 555,
#   '캐스팅': 556,
#   '개연성이': 557,
#   '판타지': 558,
#   '있게': 559,
#   '든다': 560,
#   '자체가': 561,
#   '않았다': 562,
#   '아닌가': 563,
#   '지루하지': 564,
#   '명복을': 565,
#   '저렇게': 566,
#   '기분': 567,
#   '특유의': 568,
#   '하다': 569,
#   '영화중에': 570,
#   '만': 571,
#   '안하고': 572,
#   '뭐가': 573,
#   '북한': 574,
#   '원빈': 575,
#   '가슴': 576,
#   '있습니다': 577,
#   '그나마': 578,
#   '뭘': 579,
#   '보여준': 580,
#   '젤': 581,
#   '전체적으로': 582,
#   '눈이': 583,
#   '점점': 584,
#   '나올': 585,
#   '영상': 586,
#   '재개봉': 587,
#   '봐야': 588,
#   '잘하고': 589,
#   '많아서': 590,
#   '빕니다': 591,
#   '우리는': 592,
#   '없을': 593,
#   '탄탄한': 594,
#   '2편': 595,
#   '영화지만': 596,
#   '번을': 597,
#   '재밌어서': 598,
#   '연기에': 599,
#   '않겠습니다': 600,
#   '기대를': 601,
#   '봤었는데': 602,
#   '7': 603,
#   '억지로': 604,
#   '재미없다': 605,
#   '8점': 606,
#   '멋있다': 607,
#   '개꿀잼': 608,
#   '없는데': 609,
#   '황정민': 610,
#   '스파이더맨이': 611,
#   '필요없는': 612,
#   '빼고': 613,
#   '여러번': 614,
#   '울었다': 615,
#   '있을': 616,
#   '대한민국의': 617,
#   '시작': 618,
#   '느낄': 619,
#   '지나도': 620,
#   '자체': 621,
#   '영화보고': 622,
#   '나쁘지': 623,
#   '없네': 624,
#   '만든다': 625,
#   '그걸': 626,
#   '슬프다': 627,
#   '마블은': 628,
#   '아름다운': 629,
#   '시간가는줄': 630,
#   '영화이다': 631,
#   '모두가': 632,
#   '멋있고': 633,
#   '자꾸': 634,
#   '좋았는데': 635,
#   '웃기고': 636,
#   '첫': 637,
#   '시대를': 638,
#   '지금은': 639,
#   '미션임파서블': 640,
#   '볼수록': 641,
#   '만들었다': 642,
#   '1편이': 643,
#   '연출은': 644,
#   '늘': 645,
#   '아포칼립토': 646,
#   '이야기를': 647,
#   '5점': 648,
#   '킬링타임용': 649,
#   '오락영화': 650,
#   '드라마': 651,
#   '사람을': 652,
#   '영화에요': 653,
#   '손예진': 654,
#   '봅니다': 655,
#   '있다는': 656,
#   '봐야할': 657,
#   '지루하고': 658,
#   '가족': 659,
#   '않게': 660,
#   '인간의': 661,
#   '아닌데': 662,
#   '재미와': 663,
#   '놀란': 664,
#   '난다': 665,
#   '생각없이': 666,
#   '연출과': 667,
#   '하는데': 668,
#   '단': 669,
#   '슬픈': 670,
#   '되고': 671,
#   '빨갱이': 672,
#   '와칸다': 673,
#   '실제로': 674,
#   '알게': 675,
#   '1도': 676,
#   '지': 677,
#   '감동과': 678,
#   '다시한번': 679,
#   '감독님': 680,
#   '필요없다': 681,
#   '토니': 682,
#   '깊은': 683,
#   '연기력은': 684,
#   '통해': 685,
#   '상당히': 686,
#   '손에': 687,
#   '눈을': 688,
#   '이해': 689,
#   '액션과': 690,
#   '코믹': 691,
#   '지루할': 692,
#   '너무나도': 693,
#   '아까운': 694,
#   '것이다': 695,
#   '아쉬움': 696,
#   '한국형': 697,
#   '한국의': 698,
#   '힘든': 699,
#   '포에버': 700,
#   '시리즈가': 701,
#   '박보영': 702,
#   '예전에': 703,
#   '해주는': 704,
#   '시대에': 705,
#   '대단하다': 706,
#   '이후로': 707,
#   '아닐까': 708,
#   'ㅉㅉ': 709,
#   '안된다': 710,
#   '평론가': 711,
#   '모습이': 712,
#   '공룡': 713,
#   '재밌어': 714,
#   '준다': 715,
#   '이유': 716,
#   '아픈': 717,
#   '여자': 718,
#   '뿐': 719,
#   '시리즈중': 720,
#   '떠나서': 721,
#   '몰입해서': 722,
#   '남을': 723,
#   '됨': 724,
#   '나만': 725,
#   '다시는': 726,
#   '매력적인': 727,
#   '듯한': 728,
#   '재밌었는데': 729,
#   '주인공이': 730,
#   '전율이': 731,
#   '진심으로': 732,
#   '알았는데': 733,
#   '1편보다': 734,
#   '소재를': 735,
#   '재밌다고': 736,
#   '분들': 737,
#   '같아서': 738,
#   '라고': 739,
#   '배우들도': 740,
#   '3번': 741,
#   '주연': 742,
#   '봤으면': 743,
#   '끝': 744,
#   '유치하고': 745,
#   '처럼': 746,
#   '말로': 747,
#   '마무리': 748,
#   'ㅎㅎㅎ': 749,
#   '조인성': 750,
#   '적당히': 751,
#   '현실을': 752,
#   '이런게': 753,
#   '작품이': 754,
#   '뛰어난': 755,
#   '캐릭터가': 756,
#   '굿굿': 757,
#   '방금': 758,
#   '재미있네요': 759,
#   '아니지만': 760,
#   '보다니': 761,
#   '왜케': 762,
#   '초반에': 763,
#   '내용을': 764,
#   '6': 765,
#   '노래가': 766,
#   '먼저': 767,
#   '나서': 768,
#   '재미를': 769,
#   '왜이리': 770,
#   '9점': 771,
#   '현실': 772,
#   '낫다': 773,
#   '초반': 774,
#   '엔드게임': 775,
#   '시리즈를': 776,
#   '이정재': 777,
#   '임파서블': 778,
#   '강동원의': 779,
#   '단연': 780,
#   '역사적': 781,
#   '나라': 782,
#   '마음을': 783,
#   '현재': 784,
#   '보았습니다': 785,
#   '많고': 786,
#   '한국에서': 787,
#   '그냥저냥': 788,
#   '이병헌의': 789,
#   '윤아': 790,
#   '톰크루즈': 791,
#   '이리': 792,
#   '뒤늦게': 793,
#   '소재로': 794,
#   '영화인': 795,
#   '있었던': 796,
#   'ㅈㄴ': 797,
#   '음': 798,
#   '보고나서': 799,
#   '못하는': 800,
#   '여러': 801,
#   '봐야하는': 802,
#   '나중에': 803,
#   '김수현': 804,
#   '김아중': 805,
#   '배우님': 806,
#   '역사에': 807,
#   '9': 808,
#   '생각했는데': 809,
#   '수준이': 810,
#   '재밌었습니다': 811,
#   '같아': 812,
#   '같네요': 813,
#   '아쉽지만': 814,
#   '막': 815,
#   '울고': 816,
#   '순간': 817,
#   '속': 818,
#   '2편은': 819,
#   '여기서': 820,
#   '탄탄하고': 821,
#   '얼굴': 822,
#   '날': 823,
#   '그들의': 824,
#   '그런가': 825,
#   '수많은': 826,
#   '몰입이': 827,
#   '만들어진': 828,
#   '최고임': 829,
#   '못하고': 830,
#   '몰랐는데': 831,
#   '나온다': 832,
#   '아무': 833,
#   '자신의': 834,
#   '원작': 835,
#   '있었지만': 836,
#   '수도': 837,
#   '눈': 838,
#   '지루함': 839,
#   '무엇보다': 840,
#   '봤는지': 841,
#   '영화보다': 842,
#   '있다면': 843,
#   '봤을까': 844,
#   '봤고': 845,
#   '자체는': 846,
#   '잘함': 847,
#   '없네요': 848,
#   '완벽하다': 849,
#   '7점': 850,
#   '괜히': 851,
#   '보고싶다': 852,
#   '남는다': 853,
#   '최고였다': 854,
#   '표절': 855,
#   '배트맨': 856,
#   '위대한': 857,
#   '몰입도가': 858,
#   '이정도': 859,
#   '사랑해요': 860,
#   '또봐도': 861,
#   '재미없음': 862,
#   '때는': 863,
#   '킬링타임용으로': 864,
#   '부족한': 865,
#   '둘다': 866,
#   '후반부': 867,
#   '1편은': 868,
#   '나오고': 869,
#   '그리': 870,
#   '살고': 871,
#   '살면서': 872,
#   '영화라는': 873,
#   '김윤석': 874,
#   '고인의': 875,
#   '재난영화': 876,
#   '국뽕': 877,
#   '뮤지컬': 878,
#   '없지만': 879,
#   '도저히': 880,
#   '배우분들': 881,
#   '시나리오': 882,
#   '어설픈': 883,
#   '각본': 884,
#   '아저씨': 885,
#   '한국판': 886,
#   '다시봤는데': 887,
#   '그만': 888,
#   '케미': 889,
#   '비슷한': 890,
#   '봐야지': 891,
#   '긴장감이': 892,
#   '굳': 893,
#   '조승우': 894,
#   '강동원이': 895,
#   '분명': 896,
#   '아쉽네요': 897,
#   '이유는': 898,
#   '말할': 899,
#   '그닥': 900,
#   '유쾌한': 901,
#   '사람들의': 902,
#   '삶을': 903,
#   '6점': 904,
#   '잘한다': 905,
#   '넘치는': 906,
#   '느껴지는': 907,
#   '이영화가': 908,
#   '흠': 909,
#   '뭐지': 910,
#   '액션영화': 911,
#   '보시길': 912,
#   '가끔': 913,
#   '아무것도': 914,
#   '웃고': 915,
#   '아는': 916,
#   '평점은': 917,
#   '내인생': 918,
#   '중간': 919,
#   '역시나': 920,
#   '다크나이트': 921,
#   '스파이더맨은': 922,
#   '송중기': 923,
#   '시절': 924,
#   '안보고': 925,
#   '되었다': 926,
#   '감동은': 927,
#   '안에': 928,
#   '애들': 929,
#   '먹고': 930,
#   '영화관': 931,
#   '이야기가': 932,
#   '현실적인': 933,
#   '느끼게': 934,
#   '없어': 935,
#   '모습을': 936,
#   '10년': 937,
#   '아이언맨이': 938,
#   '영화들': 939,
#   '노래도': 940,
#   '오락': 941,
#   '만들고': 942,
#   '전쟁': 943,
#   '기대하고': 944,
#   '않을': 945,
#   '감동입니다': 946,
#   '부분도': 947,
#   '보이는': 948,
#   '생각하고': 949,
#   '즐겁게': 950,
#   '없습니다': 951,
#   '되어': 952,
#   '없어요': 953,
#   '어디서': 954,
#   '본듯': 955,
#   '유치한': 956,
#   '드는': 957,
#   '그만큼': 958,
#   '보며': 959,
#   '재미있었습니다': 960,
#   '어린': 961,
#   '마블이': 962,
#   '재미있습니다': 963,
#   '매력이': 964,
#   '하게': 965,
#   '옛날': 966,
#   '일본': 967,
#   '2시간': 968,
#   '해': 969,
#   '속편': 970,
#   '1점도': 971,
#   '웃음': 972,
#   '신선한': 973,
#   '우리나라의': 974,
#   '마음': 975,
#   '떨어지는': 976,
#   '유쾌하고': 977,
#   '하나하나': 978,
#   '마블영화': 979,
#   '완벽하게': 980,
#   '1이': 981,
#   '보았다': 982,
#   '맘에': 983,
#   '사극': 984,
#   '한국영화의': 985,
#   '감사드립니다': 986,
#   '딱히': 987,
#   '정말로': 988,
#   '반전': 989,
#   '평생': 990,
#   '좋습니다': 991,
#   '유일하게': 992,
#   '18': 993,
#   '보인다': 994,
#   '해준': 995,
#   '안됨': 996,
#   '영원히': 997,
#   '엔딩': 998,
#   '평이': 999,
#   '설정': 1000,
#   ...}}
